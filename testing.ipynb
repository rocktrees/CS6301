# %%
import torch
import KoBart
import dataset
from torch.utils.data import DataLoader
from tqdm import tqdm

# device
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Data file path
dev_path = '/home/josh/Desktop/school/data/dev.tsv'

# config
batch_size = 16

# model, tokenizer init
model = KoBart.KoBARTConditionalGeneration().to(device)
model.load_state_dict(torch.load('/home/josh/Desktop/school/models/kobart/kobart_step_18000.pth'))
tokenizer = model.tokenizer

# dataset
dev_dataset = dataset.KoBARTQGDataset(dev_path, tokenizer)
dev_dataloader = DataLoader(dev_dataset, batch_size)


with open('/home/josh/Desktop/school/outputs/output_18000.txt', 'w', encoding='utf-8') as f:
    for step_index, batch_data in tqdm( enumerate(dev_dataloader), f"[GENERATE]", total=len(dev_dataloader)):

        input_ids, decoder_input_ids, labels = tuple(value.to(device) for value in batch_data.values())

        output = model.model.generate(input_ids=input_ids, eos_token_id=tokenizer.eos_token_id, max_length=100, num_beams=5)

        for o in output:
            output = tokenizer.decode(o, skip_special_tokens=True)
            f.write(output+'\n')
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# [GENERATE]: 100%|██████████| 361/361 [01:59<00:00,  3.03it/s]

# %% [markdown]
# # Check BLEU SCORES

# %%
from nltk.translate.bleu_score import corpus_bleu, sentence_bleu, SmoothingFunction
import nltk
import pandas as pd
import numpy as np
from konlpy.tag import Mecab

# import language_evaluation
from typing import List
from collections import defaultdict, Counter
import re
import math
import sys
from transformers import PreTrainedTokenizerFast

tokenizer = PreTrainedTokenizerFast.from_pretrained('Sehong/kobart-QuestionGeneration')

#import mecab_ko_dic
#mecab = Mecab(mecab_ko_dic.MECAB_ARGS)

def mean(lst):
    return sum(lst) / len(lst)


def _calc_ngram_dict(tokens: List[str], ngram: int, dict_ref=None):
    ngram_dict = defaultdict(int) if dict_ref is None else dict_ref
    total = len(tokens)
    for i in range(0, total - ngram + 1):
        item = tuple(tokens[i:i + ngram])
        ngram_dict[item] += 1
    return ngram_dict


def _calc_cover(cand, gold, ngram):
    cand_dict = _calc_ngram_dict(cand, ngram)
    gold_dict = _calc_ngram_dict(gold, ngram)
    cover = 0
    total = 0
    for token, freq in cand_dict.items():
        if token in gold_dict:
            cover += min(freq, gold_dict[token])
        total += freq
    return cover, total


def _calc_cover_rate(cands, golds, ngram):
    """
    calc_cover_rate
    """
    cover = 0.0
    total = 0.000001
    for cand_tokens, gold_tokens in zip(cands, golds):
        cur_cover, cur_total = _calc_cover(cand_tokens, gold_tokens, ngram)
        cover += cur_cover
        total += cur_total
    return cover / total


def _calc_bp(cands, golds):
    c_count = 0.000001
    r_count = 0.0
    for cand_tokens, gold_tokens in zip(cands, golds):
        c_count += len(cand_tokens)
        r_count += len(gold_tokens)
    bp = 1
    if c_count < r_count:
        bp = math.exp(1 - r_count / c_count)
    return bp


def calc_corpus_bleu(cands, golds):
    bp = _calc_bp(cands, golds)
    cover_rate1 = _calc_cover_rate(cands, golds, 1)
    cover_rate2 = _calc_cover_rate(cands, golds, 2)
    cover_rate3 = _calc_cover_rate(cands, golds, 3)
    bleu1 = 0
    bleu2 = 0
    bleu3 = 0
    if cover_rate1 > 0:
        bleu1 = bp * math.exp(math.log(cover_rate1))
    if cover_rate2 > 0:
        bleu2 = bp * math.exp((math.log(cover_rate1) + math.log(cover_rate2)) / 2)
    if cover_rate3 > 0:
        bleu3 = bp * math.exp((math.log(cover_rate1) + math.log(cover_rate2) + math.log(cover_rate3)) / 3)
    return bleu1, bleu2, bleu3


def calc_sentence_bleu(cands, golds):
    bleu1 = []
    bleu2 = []
    bleu3 = []
    sf = SmoothingFunction().method7
    for hyp, ref in zip(cands, golds):
        try:
            b1 = sentence_bleu([ref], hyp, smoothing_function=sf, weights=[1, 0, 0, 0])
        except ZeroDivisionError:
            b1 = 0.0
        try:
            b2 = sentence_bleu([ref], hyp, smoothing_function=sf, weights=[0.5, 0.5, 0, 0])
        except ZeroDivisionError:
            b2 = 0.0
        try:
            b3 = sentence_bleu([ref], hyp, smoothing_function=sf, weights=[0.34, 0.33, 0.33, 0])
        except ZeroDivisionError:
            b3 = 0.0
        bleu1.append(b1)
        bleu2.append(b2)
        bleu3.append(b3)
    return mean(bleu1), mean(bleu2), mean(bleu3)


def calc_corpus_bleu_new(hypothesis, references):
    # hypothesis = [normalize_answer(hyp).split(" ") for hyp in hypothesis]
    # references = [[normalize_answer(ref).split(" ")] for ref in references]
    references = [[gold] for gold in references]
    sf = SmoothingFunction(epsilon=1e-12).method1
    b1 = corpus_bleu(references, hypothesis, weights=(1.0 / 1.0,), smoothing_function=sf)
    b2 = corpus_bleu(references, hypothesis, weights=(1.0 / 2.0, 1.0 / 2.0), smoothing_function=sf)
    b3 = corpus_bleu(references, hypothesis, weights=(1.0 / 3.0, 1.0 / 3.0, 1.0 / 3.0), smoothing_function=sf)
    b4 = corpus_bleu(references, hypothesis, weights=(1.0 / 4.0, 1.0 / 4.0, 1.0 / 4.0, 1.0 / 4.0),
                     smoothing_function=sf)
    return b1, b2, b3, b4


def _calc_distinct_ngram(cands, ngram):
    ngram_total = 0.00001
    ngram_distinct_count = 0.00001
    pred_dict = defaultdict(int)
    for cand_tokens in cands:
        _calc_ngram_dict(cand_tokens, ngram, pred_dict)
    for key, freq in pred_dict.items():
        ngram_total += freq
        ngram_distinct_count += 1
    return ngram_distinct_count / ngram_total


def _calc_sent_distinct_ngram(cand, ngram):
    ngram_total = 0.0000000001
    ngram_distinct_count = 0.0
    ngram_dict = defaultdict(int)
    for i in range(0, len(cand) - ngram + 1):
        item = tuple(cand[i:i + ngram])
        ngram_dict[item] += 1
    for _, freq in ngram_dict.items():
        ngram_total += freq
        ngram_distinct_count += 1
    return ngram_distinct_count / ngram_total


def calc_corpus_distinct(cands):
    distinct1 = _calc_distinct_ngram(cands, 1)
    distinct2 = _calc_distinct_ngram(cands, 2)
    return distinct1, distinct2


def calc_sentence_distinct(cands):
    distinct1 = mean([_calc_sent_distinct_ngram(c, 1) for c in cands])
    distinct2 = mean([_calc_sent_distinct_ngram(c, 2) for c in cands])
    return distinct1, distinct2


def calc_corpus_f1(cands, golds):
    golden_word_total = 0.00000001
    pred_word_total = 0.00000001
    hit_word_total = 0.00000001
    for response, golden_response in zip(cands, golds):
        common = Counter(response) & Counter(golden_response)
        hit_word_total += sum(common.values())
        golden_word_total += len(golden_response)
        pred_word_total += len(response)
    p = hit_word_total / pred_word_total
    r = hit_word_total / golden_word_total
    f1 = 2 * p * r / (p + r)
    return f1


def normalize_answer(s):
    """Lower text and remove punctuation, articles and extra whitespace."""
    re_art = re.compile(r'\b(a|an|the)\b')
    re_punc = re.compile(r'[!"#$%&()*+,-./:;<=>?@\[\]\\^`{|}~_\']')

    def remove_articles(text):
        return re_art.sub(' ', text)

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        return re_punc.sub(' ', text)  # convert punctuation to spaces

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s)))).split(' ')


def dialogue_evaluation(ori_cands, ori_golds):
    assert len(ori_cands) == len(ori_golds), f"num cand: {len(ori_cands)}, num gold: {len(ori_golds)}"
    cands = []
    golds = []
    
    # 둘 중 원하는 토크나이저로 성능 평가하세요
    
    #help_tokenize = lambda x: mecab.morphs(x.lower())         # Mecab
    help_tokenize = lambda x: tokenizer.encode(x.lower())     # 학습에 사용한 토크나이저
    
    for cand, gold in zip(ori_cands, ori_golds):
        cands.append(help_tokenize(str(cand).lower()))
        golds.append(help_tokenize(str(gold).lower()))
    cbleu1, cbleu2, cbleu3, cbleu4 = calc_corpus_bleu_new(cands, golds)
    sbleu1, sbleu2, sbleu3 = calc_sentence_bleu(cands, golds)
    cdiv1, cdiv2 = calc_corpus_distinct(cands)
    sdiv1, sdiv2 = calc_sentence_distinct(cands)
    cf1 = calc_corpus_f1(cands, golds)
    # rouge_result = calc_rouge(cands, golds)
    result = {
        'cf1': cf1,
        'bleu1': cbleu1,
        'bleu2': cbleu2,
        'bleu3': cbleu3,
        'bleu4': cbleu4,
        'dist1': cdiv1,
        'dist2': cdiv2,
    }
    # result.update(rouge_result)
    result = {k: round(100 * v, 6) for k, v in result.items()}
    return result


def file_dialogue_evaluation(cand_file, gold_file):
    print(f"cand file: {cand_file}, gold file: {gold_file}")
    cands = []
    golds = []
    with open(cand_file, 'r', encoding='utf-8') as f:
        for line in f:
            cands.append(line.strip())
    with open(gold_file, 'r', encoding='utf-8') as f:
        for line in f:
            golds.append(line.strip())
    results = dialogue_evaluation(cands, golds)
    print(results)

# %% [markdown]
# # BLEU

# %%
test_data_path = '/home/josh/Desktop/school/data/dev.tsv' # .tsv
output_path = '/home/josh/Desktop/school/outputs/output_18000.txt' # .txt

# %%
test_data_path = '/home/josh/Desktop/school/data/dev.tsv' # .tsv
output_path = '/home/josh/Desktop/school/outputs/output_18000.txt' # .txt

from tqdm import tqdm
#df = pd.read_csv(test_data_path, encoding='cp949', sep='\t')
df = pd.read_csv(test_data_path, encoding='utf-8', sep='\t')
question = list(df['question'])

generated_question = []


with open(output_path, 'r', encoding='utf-8') as f:
    for line in f.readlines():
        print(line)
        generated_question.append(line)

# save info
pd.DataFrame(generated_question, question)

len_question = len(question)

score_list_1 = np.zeros(len_question)
score_list_2 = np.zeros(len_question)
score_list_3 = np.zeros(len_question)
score_list_4 = np.zeros(len_question)

for i in tqdm(range(len_question)):
    
    matrix = dialogue_evaluation([generated_question[i]], [question[i]])
    score_list_1[i] = matrix['bleu1']
    score_list_2[i] = matrix['bleu2']
    score_list_3[i] = matrix['bleu3']
    score_list_4[i] = matrix['bleu4']
    

#score_list = np.array(score_list)
print('bleu1: ', np.mean(score_list_1))
print('bleu2: ', np.mean(score_list_2))
print('bleu3: ', np.mean(score_list_3))
print('bleu4: ', np.mean(score_list_4))
# Out:
# 서울지방검찰청에서 임종석의 사전구속영장을 발부 받은 날짜는?
#
# 서울지방검찰청 공안부가 임종석의 사전구속영장을 발부받은 날짜는?
#
# 서울지방검찰청에서 임종석의 사전구속영장을 발부받은 날짜는?
#
# 서울지방검찰청 공안부가 임종석의 사전구속영장을 발부받은 날짜는?
#
# 서울지방검찰청이 임종석의 사전구속영장을 발부 받은 날짜는?
#
# 서울지방검찰청 공안부가 임종석의 사전구속영장을 발부받은 날짜는?
#
# 서울지방검찰청이 임종석의 사전구속영장을 발부 받은 날짜는?
#
# 정부의 헌법개정안 준비 과정에 대해 청와대가 아닌 국무회의 중심으로 했어야 된다고 지적한 원로 헌법학자는?
#
# 헌법 규정에 충실하지 않은 민정수석이 개정안을 설명하는 게 이해가 안 든다고 지적한 사람은?
#
# 정부의 헌법개정안 준비 과정에 대해 헌법 규정에 충실하지 않았다고 지적한 사람은?
#
# 국무총리 선출 방식에 대한 기자의 질문에 문 대통령은 취임 전까지 총리에게 실질적 권한을 주겠다고 했지만 그전에는 어떤 권한을 주었나?
#
# 알렉산더 메이그스 헤이그 2세가 미국 군대에서 2번째로 높은 직위는?
#
# 알렉산더 메이그스 헤이그 2세가 미국 군대에서 2번째로 높은 직위는?
#
# 알렉산더 메이그스 헤이그 2세의 회고록의 저자는?
#
# 알렉산더 메이그스 헤이그 2세가 미국 군대에서 2번째로 높은 직위는?
#
# 알렉산더 메이그스 헤이그 2세가 미국 군대에서 2번째로 높은 직위인 미국 육군 부참모 총장은?
#
# 알렉산더 메이그스 헤이그 2세가 미국 군대에서 2번째로 높은 직위인 미국 육군 부참모 총장과 미국 군대의 유럽연합군 최고사령관이었던 직위는?
#
# 알렉산더 메이그스 헤이그 2세의 회고록의 제목은?
#
# 알렉산더 메이그스 헤이그 2세가 미국 군대에서 2번째로 높은 직위를 가진 직위는?
#
# 미국 육군사관학교로 임명을 획득한 해는?
#
# 미국 육군사관학교로 임명을 획득한 해는?
#
# 헤이그는 1947년 310의 동기병에서 몇번째 사관으로서 졸업했는가?
#
# 미국 육군사관학교에 임명을 획득한 해는?
#
# 헤이그는 몇살에 소위로 기갑 훈련소로 갔는가?
#
# 미국 육군사관학교로 임명을 획득한 해는?
#
# 헤이그는 1950년 5월에 누구와 결혼하였는가?
#
# 미국 육군사관학교로 임명을 획득한 해는?
#
# 헤이그가 대통령 특별 보좌관을 지낸 해는?
#
# 닉슨 대통령이 사성 장군과 육군 부참모로 진급한 사람은?
#
# 닉슨 대통령이 사성 장군과 육군 부참모로 진급한 사람은?
#
# 닉슨 대통령이 사성 장군과 육군 부참모로 진급한 인물은?
#
# 닉슨 대통령이 사성 장군과 육군 부참모로 진급한 사람은?
#
# 닉슨 대통령이 사성 장군과 육군 부참모로 진급한 사람은?
#
# 닉슨 대통령이 사성 장군과 육군 부참모로 진급한 사람은?
#
# 헤이그는 Worldwide Associates Inc.의 무엇에 의하여 기용되었는가?
#
# Worldwide Associates Inc.의 국제적 상담 회사에 의하여 기용된 헤이그의 직책은?
#
# Worldwide Associates Inc.의 국제적 상담회 회사의 이름은?
#
# Worldwide Associates Inc.의 국제적 상담회사는?
#
# Worldwide Associates Inc.의 국제적 상담회사에 의하여 기용된 헤이그의 직책은?
#
# Worldwide Associates Inc.의 국제적 상담회사는?
#
# 노아는 하나님의 명령에 따라 배를 만들고 짐승 암수 몇 마리를 실었는가?
#
# 노아는 하나님의 명령에 따라 배를 만들고 짐승 암수를 몇 마리씩 싣고 홍수를 피했나?
#
# 하나님의 명령에 따라 배를 만들고 부정한 짐승 암수 일곱 마리를 싣고 밀어닥친 홍수를 피한 노아는 누구인가?
#
# 노아는 하나님의 명령에 따라 배를 만들고 부정한 짐승 암수 몇 마리를 싣고 홍수를 피했나?
#
# 노아는 하나님의 명령에 따라 배를 만들고 짐승 암수를 몇 마리씩 싣고 밀어닥친 홍수를 피했나?
#
# 노아는 하나님의 명령에 따라 배를 만들고 짐승 암수 몇 마리씩을 싣고 밀어닥친 홍수를 피했나?
#
# 노아는 하나님의 명령에 따라 배를 만들고 짐승 암수 몇 마리씩을 싣고 누구를 피했나?
#
# 하나님의 명령에 따라 배를 만들고 부정한 짐승 암수 몇 마리씩을 싣고 밀어닥친 홍수의 이름은?
#
# 노아는 하나님의 명령에 따라 배를 만들고 짐승 암수를 몇 마리씩 싣고 홍수를 피했나?
#
# 역사학과 과학이 발달하지 않았던 과거 전통 신학계에서는 어떤 시각을 받아들여 노아의 방주를 역사적 사실로 기술하려 했는가?
#
# 전통 신학계에서는 어떤 시각을 받아들여 노아의 방주를 역사적 사실로 기술하려 했는가?
#
# 전통 신학계에서는 어떤 시각을 받아들여 노아의 방주를 역사적 사실로 기술하려 했는가?
#
# 전통적 신학계에서는 어떤 시각을 받아들여 노아의 방주를 역사적 사실로 기술하려 했는가?
#
# 역사학과 과학이 발달하지 않았던 과거 전통 신학계에서는 어떤 시각을 받아들여 노아의 방주를 역사적 사실로 기술하려 했는가?
#
# 전통 신학계에서는 어떤 시각을 받아들여 노아의 방주를 역사적 사실로 기술하려 했는가?
#
# 역사학과 과학이 발달하지 않았던 전통 신학계에서는 어떤 시각을 받아들여 노아의 방주를 역사적 사실로 기술하려 했나?
#
# 제칠일안식교에서 비롯된 유사지질학은?
#
# 제칠일안식교에서 비롯된 의사과학의 한 종류는?
#
# 제칠일안식교에서 비롯된 의사과학의 한 종류는?
#
# 제칠일안식교에서 비롯된 의사과학의 한 종류는?
#
# 제칠일안식교에서 비롯된 의사과학의 한 종류인 유사지질학은?
#
# 제칠일안식교에서 비롯된 의사과학의 한 종류는?
#
# 제칠일안식교에서 비롯된 의사과학의 한 종류는?
#
# 제칠일안식교를 기반으로 한 홍수지질학적 주장들을 내어 놓은 곳은 어디인가?
#
# 현재 노아의 방주가 실존한다는 주장은 누구에게 인정받지 못하고 있는가?
#
# 스페인의 임업 연구소에서 목재의 특성을 토대로 5000년 전의 것이라고 밝힌 목재 파편의 이름은?
#
# 스페인의 임업 연구소에서 목재의 특성을 토대로 5000년 전의 것이라 밝힌 목재 파편의 발견 년도는?
#
# 스페인의 임업 연구소에서 발견한 목재 파편의 시기는?
#
# 스페인의 임업 연구소에서 발견한 목재 파편의 연도는?
#
# 아라랏산을 발견한 탐험가는?
#
# 스페인의 임업 연구소에서 발견한 목재 파편의 연대는?
#
# 성경 내용에는 모든 종들을 방주에 태운다고 이야기 하고 있지만 어류나 수중 생물은 언급하지 않았던 것은?
#
# 성경에서 모든 종들을 방주에 태운다고 이야기하고 있는 것은?
#
# 성경 내용에서는 모든 종들을 방주에 태운다고 이야기하고 있지만 어류나 수중 생물은 언급하지 않은 것은?
#
# 성경 내용에는 모든 종들을 방주에 태운다고 이야기하고 있지만, 어류나 수중 생물은 언급하지 않은 것은?
#
# 성경에서 모든 종을 방주에 태운다고 이야기하고 있는 것은?
#
# 성경 내용에는 모든 종들을 방주에 태운다고 이야기하고 있지만 어류나 수중 생물은 언급하지 않은 것은?
#
# 성경 내용에는 모든 종들을 방주에 태운다고 이야기하고 있지만 어류나 수중 생물은 언급하지 않은 것은?
#
# 노아의 방주는 항해가 불가능한 설계에 가깝다고 주장한 단체는?
#
# 창조과학회에서 주장한 방주의 크기와 철제 부품을 사용하지 않은 목재 선박 중 가장 큰 수준의 선박을 비교하여 배수량이 두배 이상 차이난 것은?
#
# 노아의 방주는 항해가 불가능한 설계에 가깝다고 주장한 단체는?
#
# 노아의 방주가 안정적인 구조라고 주장한 단체는?
#
# 노아의 방주는 항해가 불가능한 설계에 가깝다고 주장한 단체는?
#
# 노아의 방주는 항해가 불가능한 설계에 가깝다고 주장한 단체는?
#
# 노아의 방주가 안정적인 구조라고 주장한 단체는?
#
# 하코다테 전쟁에서 에노모토 해군의 주력함이 되었던 나라는?
#
# 도쿠가와 요시노부를 슨푸 번에 이송할때 사용한 함선은?
#
# 하코다테 전쟁에서 에노모토 해군의 주력함이 되었던 전쟁은?
#
# 에도 성 무혈 개성을 한 후 신정부 군에게 양도가 약속된 해는?
#
# 시나가와 해역을 탈출한 막부 해군은?
#
# 1868년 에도 성 무혈 개성을 한 후 신정부 군에게 양도가 약속되었던 인물은?
#
# 하코다테 전쟁에서 에노모토 해군의 주력함이 된 해는?
#
# 하코다테 전쟁에서 에노모토 해군의 주력함이 되었던 전쟁은?
#
# 하코다테 전쟁은 적아 쌍방의 문서에 누구의 능란한 조함 능력과 냉정한 지휘만이 기록되어 있는가?
#
# 마쓰오카 바키치 함장의 능란한 조함 능력과 냉정한 지휘가 기록되어 있는 전쟁은?
#
# 하코다테 전쟁은 적아 쌍방의 문서에 누구의 능란한 조함 능력과 냉정한 지휘만이 기록되어 있는가?
#
# 하코다테 전쟁에서 바키치 함장의 능란한 조함 능력과 냉정한 지휘만이 기록된 전쟁은?
#
# 마쓰오카 바키치 함장의 능란한 조함 능력과 냉정한 지휘만이 기록되어 있는 전쟁은?
#
# 마쓰오카 바키치 함장의 능란한 조함 능력과 냉정한 지휘만이 기록되어 있는 전쟁은?
#
# 하코다테 전쟁에서 바키치 함장의 능란한 조함 능력과 냉정한 지휘만이 기록되어 있는 전쟁은?
#
# 하코다테 전쟁에서 바키치 함장의 능란한 조함 능력과 함께 하코다테로 돌아올 수 있었던 것은 철갑선의 사정거리에 들어간 순간에 무엇이 불기 시작했기 때문인가?
#
# 5월 11일 하코다테 총공격에서 기관 고장으로 움직일 수 없는 떠 있는 포대가 된 것은 누구의 원호를 받았기 때문인가?
#
# 가이텐마루의 원호를 받으며 신정부 군 함대와 응전을 벌인 해전은?
#
# 가이텐마루의 원호를 받고 신정부 군 함대와 응전을 벌인 해전은?
#
# 가이텐마루의 원호를 받으며 신정부 군 함대와 응전을 벌인 해는?
#
# 가이텐마루의 원호를 받으며 신정부 군 함대와 응전을 벌인 년도는?
#
# 벤텐 다이바와 기관 고장으로 움직일 수 없는 떠 있는 포대가 된 가이텐마루의 원호를 받으며 신정부 군 함대와 응전을 벌인 전투는?
#
# 가이텐마루의 원호를 받으며 신정부 군 함대와 응전을 벌인 해전은?
#
# 가이텐마루의 원호를 받으며 신정부 군 함대와 응전을 벌인 년도는?
#
# 서양 철학이라는 용어는 무엇을 포함하는 지구의 넓은 영역에 퍼진 사유를 말하는가?
#
# 서양에서 철학적인 생각과 관련된 용어로 동양의 토착철학과 대비되는 용어는?
#
# 서양철학이라는 용어는 어디에서 유래되었는가?
#
# 서양 철학이라는 용어는 누구와 대비되는가?
#
# 서양 철학이라는 용어는 누구의 철학과 대비되는가?
#
# 서양 철학이라는 용어는 누구의 철학적 사고와 관련된 것인가?
#
# 고대 학문의 분화와 과학 기술의 빠른 발전이 학문과 학문으로 분리되는데 기여한 학문은?
#
# 학문의 분화와 과학 기술의 빠른 발전이 과학과 학문으로 분리되는데 기여한 학문은?
#
# 학문의 분화와 과학 기술의 빠른 발전이 학문으로 분리되는데 기여한 학문은?
#
# 학문의 분화와 과학 기술의 빠른 발전이 학문으로 분리되는데 기여한 학문은?
#
# 철학의 범위에 대한 고대의 이해와 고대 철학자의 글쓰기를 통틀어 어떻게 하는가?
#
# 오늘날 철학의 문제라고 생각하는 것도 포함하지만 다른 분과에 속하는 것도 같이 다루고 있는 것은?
#
# 서양이라는 용어의 경계는 몇 세기 동안 형성되었는가?
#
# 서양 철학이라는 용어의 지정학적 경계가 형성된 시기는?
#
# 서양 철학이라는 용어의 지정학적 경계가 형성된 시기는?
#
# 서양철학이라는 용어의 지정학적 경계가 형성된 시기는?
#
# 서양 철학이라는 용어의 지정학적 경계가 형성된 시기는?
#
# 서양 철학이라는 용어의 경계는 언제 형성되었는가?
#
# 아리스토텔레스가 신학을 철학의 중심 분야로 간주한 시기는?
#
# 신학을 형이상학에서 뻗어나온 가지로서 철학의 중심 분야로 간주한 사람은 누구인가?
#
# 신학을 형이상학에서 뻗어나온 가지로서 철학의 중심 분야로 간주한 사람은 누구인가?
#
# 아리스토텔레스가 신학을 철학의 중심 분야로 간주한 것은 언제까지인가?
#
# 신학을 형이상학에서 뻗어나온 가지로 간주하고 철학의 중심 분야로 간주한 사람은?
#
# 신학적인 질문에 답하려고 노력한 서양철학자는 언제까지 신학적인 질문에 답하려고 노력하였는가?
#
# 임세영이 무예를 연마할 뜻을 품고 가입한 곳은 어디인가?
#
# 임세영이 무예를 배우기 위해 가입한 곳은 어디인가?
#
# 임세영을 불렀던 호칭은?
#
# 중국 광동성 남해현 출신으로 정육점을 경영하던 사람은?
#
# 임세영을 불렀던 호칭은?
#
# 중국 광동성 남해현 출신으로 정육점을 경영하던 사람은?
#
# 임세영이 무예를 배우기 위해 가입한 곳은 어디인가?
#
# 임세영은 누구의 일대종사였는가?
#
# 임세영과 깡패들과 시비가 붙은 임세영의 무공은?
#
# 임세영의 스승은 누구인가?
#
# 임세영의 스승은 누구인가?
#
# 임세영의 스승은 누구인가?
#
# 임세영의 스승은 누구인가?
#
# 임세영의 스승은 누구인가?
#
# 깡패들과 시비가 붙은 임세영의 무공은?
#
# 임세영이 중화민국 수립 후 어디를 피해 다른 지역으로 달아났다가 어느 나라를 멸망시켰는가?
#
# 황비홍이 죽지 않은 것을 다행으로 알라며 훈계한 사람은?
#
# 임세영이 광주로 도장을 열게 된 계기는?
#
# 임세영이 광주로 떠나 도장을 열게 된 곳은?
#
# 임세영이 광주에서 수련하던 중 도장을 닫게 된 곳은 어디인가?
#
# 임세영이 광주로 떠나 도장을 열게 된 곳은?
#
# 임세영이 자신의 도장을 닫은곳은 어디인가?
#
# 미국 적십자사에서 주최하는 영어경시대회에서 최고점수를 받은 학년은?
#
# 김규식이 미국 연수 및 봉사활동에서 존 F. 케네디 대통령을 만난 것은 언제인가?
#
# 충주중학교를 졸업한 해는?
#
# 미국 적십자사에서 주최하는 영어경시대회에서 최고점수를 받은 이 학생의 이름은?
#
# 미국 적십자사에서 주최하는 영어경시대회에서 최고점수를 받은 충주고등학교의 학과는?
#
# 충주고등학교 2학년 때 미국 적십자사에서 주최하는 영어경시대회에서 최고점수를 받은 학교는?
#
# 2003년 2월 11일 기준 한국의 국가신용등급은?
#
# 2003년 참여정부에서 외교안보보좌관을 지낸 인물은?
#
# 2003년 참여정부에서 외교안보보좌관을 지낸 인물은?
#
# 2003년 2월 11일 기준 한국의 국가신용등급은?
#
# 2003년 2월 11일 무디스가 한국의 국가신용등급을 부정적으로 낮춘 이유는?
#
# 2003년 2월 11일 기준 한국의 국가신용등급은?
#
# 2003년 2월 11일 기준 미국의 신용평가기관은?
#
# 2003년 2월 11일 기준 미국의 신용평가기관은?
#
# 2003년 2월 11일 기준 한국의 국가신용등급 등급은?
#
# 미국이 기존의 정전협정 체제를 무엇으로 바꾸자는 조선민주주의인민공화국의 주장을 심도있게 검토하였는가?
#
# 미국이 기존의 정전협정 체제를 무엇으로 바꾸자는 주장을 했는가?
#
# 미국이 기존의 정전협정 체제를 무엇으로 바꾸자는 조선민주주의인민공화국의 주장을 심도있게 검토하였는가?
#
# 미국이 기존의 정전협정 체제를 무엇으로 바꾸자는 조선민주주의인민공화국의 주장을 제안하였는가?
#
# 미국이 기존 정전협정 체제를 무엇으로 바꾸자는 주장을 했는가?
#
# 미국이 기존의 정전협정 체제를 무엇으로 바꾸자는 조선민주주의인민공화국의 주장을 비판하였는가?
#
# 미국이 기존 정전협정 체제를 무엇으로 바꾸자는 주장을 했는가?
#
# 2006년 조선민주주의인민공화국이 미사일을 발사한 것은 몇 월 몇 일에 해당하는가?
#
# 2006년 7월에 조선민주주의인민공화국이 발사한 것은?
#
# 2005년 9월 6자회담에서 조선민주주의인민공화국이 모든 핵무기를 파기하고 NPT와 IAEA로 복귀한다는 내용이 타결될 때 외교부에 파견한 사람은?
#
# 2006년 7월 조선민주주의인민공화국이 발사한 것은?
#
# 2006년 7월 조선민주주의인민공화국이 발사한 것은?
#
# 2006년 7월 조선민주주의인민공화국이 발사한 것은?
#
# 외교부에 박선원 당시 행정관을 파견한 인물은?
#
# 외교부에 박선원 당시 행정관을 파견한 년도는?
#
# 정동영 당시 국가안전보장회의 상임위원장으로부터 냉전적 시각으로 외교를 제대로 하겠냐는 질책을 들은 인물은?
#
# 한국인으로서는 최초로 유엔 사무총장에 당선된 인물은?
#
# 그가 유엔 사무총장 출마를 공식 선언한 날짜는?
#
# 그가 유엔 사무총장에 당선된 년도는?
#
# 그가 유엔 사무총장직을 놓고 경쟁한 나라는 몇개국인가?
#
# 그가 유엔 사무총장 출마를 공식 선언한 날짜는?
#
# 한국인으로서는 최초로 유엔 사무총장에 당선된 해는?
#
# 그가 유엔 사무총장 선거에서 당선된 것은 언제인가?
#
# 그가 유엔 사무총장직을 놓고 경쟁한 나라는 몇 개국인가?
#
# 한국인으로 최초로 유엔 사무총장에 당선된 인물은?
#
# 2007년 유엔 안전 보장 이사회에서 아프리카 연합군과 합세해 분쟁 지역으로 진입하는 것을 승인한 유엔 평화유지군의 병력은 몇 명인가?
#
# 2007년 반기문이 아프리카 연합 정상회의로 최초 외부 순방을 한 곳은?
#
# 2007년 아프리카 연합 정상회의가 열린 곳은 어디인가?
#
# 2007년 아프리카 연합 정상회의는 어디에서 열렸는가?
#
# 반기문이 아프리카 연합 정상회의로 최초 외부 순방을 한 곳은?
#
# 2007년 7월 31일 유엔 안전 보장 이사회에서 유엔 평화유지군 병력이 아프리카 연합군과 합세해 분쟁 지역으로 진입하는 것을 승인한 날짜는?
#
# 2007년 반기문이 아프리카 연합 정상회의로 최초 외부 순방을 한 곳은 어디인가?
#
# 2007년 아프리카 연합 정상회의는 어디에서 열렸는가?
#
# 2007년 7월 31일 유엔 안전 보장 이사회에서 아프리카 연합군과 합세해 분쟁 지역으로 진입을 승인한 유엔 평화유지군의 수는?
#
# 2016년 반기문은 이스라엘과 팔레스타인 양측 모두에 어떤 종교적 연결점이 있음을 강조하였는가?
#
# 2016년 반기문이 이스라엘과 팔레스타인 양측을 만나 분쟁 해결을 위한 중재를 한 인물은?
#
# 2016년 반기문이 팔레스타인과 유대인 정착촌을 확대하는 것은 이스라엘의 증오를 부추기고 국제사회를 모욕하는 행동이라고 지적한 회의는?
#
# 반기문이 이스라엘과 팔레스타인 양측 모두 이 땅에 역사적 종교적 연결점이 있음을 강조하면서 다시 상기시킨 법은?
#
# 2016년 반기문이 이스라엘과 팔레스타인을 방문하여 분쟁 해결을 위한 중재를 한 인물은?
#
# 2016년 반기문이 이스라엘과 팔레스타인 양측을 만나 분쟁 해결을 위한 중재를 한 인물은?
#
# 2016년 반기문이 이스라엘과 팔레스타인 양측을 만나 분쟁 해결을 위한 중재를 한 인물은?
#
# 2016년 9월 15일 미국을 방문한 정세균 국회의장과 새누리당 정진석,국민의당 박지원 원내대표를 뉴욕 사무총장 사무실에서 만나 박대통령이 한반도 주변 4강 정상들과 소통하고 정상외교도 잘하고 있다고 말한 인물은?
#
# 2016년 9월 15일 정세균 국회의장, 새누리당 정진석, 더불어민주당 우상호.국민의당 박지원 원내대표를 만난 사람은?
#
# 제 3지대가 지금 반기문 총장을 옹립하고 새로운 당을 만드는 데 이사장으로서의 노력을 다하고 있다고 말한 사람은?
#
# 2016년 9월 15일 미국을 방문한 정세균 국회의장, 새누리당 정진석,국민의당 박지원 원내대표를 만난 인물은?
#
# 2016년 9월 15일 정세균 국회의장, 새누리당 정진석, 국민의당 박지원 원내대표를 만나 박대통령이 한반도 주변 4강들과 소통하고 정상외교도 잘하고 있다고 말한 사람은?
#
# 2016년 9월 15일 미국을 방문한 반기문은 정세균 국회의장, 새누리당 정진석, 국민의당 박지원 원내대표를 만난 곳은?
#
# 2016년 9월 15일 미국을 방문한 정세균 국회의장, 새누리당 정진석, 국민의당 박지원 원내대표를 뉴욕 사무총장 사무실에서 만나 박 대통령이 한반도 주변 4강들과 소통하고 정상외교도 잘하고 있다고 말한 사람은?
#
# 신천지 예수교 증거장막성전 측은 김남희가 신천지 신자인 것은 맞지만 IWPG와 전혀 무관하다고 주장했다. 이는 누구와 무관하다고 하였는가?
#
# 김남희 대표와 같이 사진을 찍은 인물은?
#
# 신천지 예수교 증거장막성전 측은 김남희 대표가 신천지 신자인 것은 맞지만 IWPG와 전혀 무관하다며 누구와 사진을 찍었나?
#
# IWPG와 신천지가 친밀한 관계를임을 주장한 당은?
#
# 김남희가 신천지와 친밀한 관계를 맺었다는 의혹과 관련하여 반기문에게 해명을 요구한 당은?
#
# IWPG와 신천지가 친밀한 관계라는 의혹과 관련하여 반기문에게 해명을 요구한 당은?
#
# IWPG와 신천지가 친밀한 관계라는 의혹과 관련하여 반기문에게 해명을 요구한 당은?
#
# 반기문 유엔 사무총장이 강하고 인간적인 지도자라고 평가한 미국의 경제 전문지 이름은?
#
# 반기문이 유엔 안전보장이사회를 비판한 사실을 언급하며 강하고 인간적인 지도자라고 보도한 미국의 경제 전문지는?
#
# 반기문 유엔 사무총장이 강하고 인간적인 지도자라고 보도한 미국의 경제 전문지 이름은?
#
# 반기문 유엔 사무총장이 강하고 인간적인 지도자라고 보도한 매체는?
#
# 반기문 유엔 사무총장이 강하고 인간적인 지도자라고 보도한 미국 경제 전문지는?
#
# 2016년 11월 미국의 경제 전문지 <포브스>가 반기문 유엔 사무총장을 강하고 인간적인 지도자라고 평가한 인물은?
#
# 반기문 유엔 사무총장이 강하고 인간적인 지도자라고 보도한 미국의 경제 전문지 이름은?
#
# 2016년 반기문 유엔 사무총장이 강하고 인간적인 지도자라고 보도한 미국의 경제 전문지는?
#
# 외금강의 남쪽 지역을 무엇으로 분류하는가?
#
# 외금강,해금강으로 분류되기도 하는 산 이름은?
#
# 내금강, 외금강, 해금강으로 나뉘고 때로는 신금강으로 분류되기도 하는 산은?
#
# 내금강, 외금강, 해금강으로 나뉘고 때로는 신금강으로 분류되기도 하는 산은?
#
# 내금강, 외금강, 해금강으로 나뉘는 산은?
#
# 내금강, 외금강, 해금강으로 나뉘는 산은?
#
# 내금강, 외금강, 해금강으로 나뉘며 때로는 신금강으로 분류되기도 하는 강은?
#
# 내금강, 외금강, 해금강으로 나뉘며 때로는 신금강으로 분류되기도 하는 산은?
#
# 내금강, 외금강, 해금강으로 나뉘며 때로는 신금강으로 분류되기도 하는 산은?
#
# 금강산의 별칭은 모두 몇 가지 인가?
#
# 많은 이름을 가진 산이 금강산으로 널리 알려진 이유는 어디의 영지이기 때문인가?
#
# 전국의 명산, 명소들이 금강산에 빗대어 붙여진 별명은?
#
# 많은 이름을 가진 산이 금강산으로 널리 알려진 이유는 무엇으로 알려져 있기 때문인가?
#
# 여러 이름을 가진 금강산의 별칭은 모두 몇가지인가?
#
# 금강산의 별칭은 모두 몇가지인가?
#
# 많은 이름을 가진 금강산의 별칭은 모두 몇 가지인가?
#
# 여러 이름을 가진 금강산의 별칭은 모두 몇 가지인가?
#
# 금강산의 지질층 중 가장 널리 분표된 암석은?
#
# 금강산의 지질층 중 가장 널리 분표된 암석은?
#
# 금강산의 지질층 중 가장 널리 분표된 암석은?
#
# 금강산의 지질층 중 가장 널리 분표된 암석은?
#
# 금강산 일대의 지질층은 태고계로부터 신생계에 걸친 오랜 지질시대에 속하는 어떤 암석으로 이루어져 있는가?
#
# 금강산의 지질층 중 운모가 섞이고, 화강-편마암 수정 지대가 형성된 암석은?
#
# 금강산의 지질층 중 가장 널리 분표된 암석은?
#
# 남한산성 내금강은 주로 무엇을 의미하는가?
#
# 내금강에 있는 봉은 비로봉과 무엇으로 나뉘는가?
#
# 금강산의 주봉인 비로봉과 여러 폭포가 있는 곳은?
#
# 금강산의 주봉인 비로봉과 여러 폭포가 있는 곳은?
#
# 주분서령에 있는 금강산의 주봉은?
#
# 금강산의 주봉은?
#
# 내금강에 있는 봉은 비로봉과 무엇으로 나뉘는가?
#
# 조선 3대 폭포로 꼽히는 것은?
#
# 조선 3대 폭포로 꼽히는 것은?
#
# 조선 3대 폭포로 꼽히는 폭포의 높이는?
#
# 조선 3대 폭포로 꼽히는 구룡폭포의 높이는?
#
# 조선 3대 폭포로 꼽히는 구룡폭포의 높이는?
#
# 조선 3대 폭포로 꼽히는 구룡폭포의 높이는?
#
# 조선 3대 폭포로 꼽히는 것은?
#
# 조선 3대 폭포로 꼽히는 것은?
#
# 남한의 화진포와 송지호 같은 남한의 화랑들이 경치가 좋아 3일 동안 머물렀던 삼일포의 이름은?
#
# 남한의 화진포와 송지호 같은 석호의 총 길이는?
#
# 삼일포와 향로봉이 개방된 곳은?
#
# 삼일포와 향로봉이 개방되어 있지 않은 곳은?
#
# 남한의 화진포와 송지호는 무슨 호수인가?
#
# 삼일포와 향로봉이 개방되어 있지 않은 곳은?
#
# 삼일포와 향로봉이 개방되어 있지 않은 곳은?
#
# 삼일포와 향로봉이 개방되어 있지 않은 곳은?
#
# 신증동국여지승람에 따르면 금강산에는 총 몇개의 사찰이 있었는가?
#
# 신증동국여지승람에 기록된 금강산에는 총 몇개의 사찰이 있었는가?
#
# 금강산에는 총 몇개의 사찰이 있었는가?
#
# 신증동국여지승람에 기록된 금강산에는 총 몇개의 사찰이 있었는가?
#
# 신증동국여지승람에 따르면 금강산에는 총 몇개의 사찰이 있었는가?
#
# 신증동국여지승람에 기록된 금강산에는 총 몇개의 사찰이 있었나?
#
# 신증동국여지승람에 따르면 금강산에는 총 몇개의 사찰이 있었는가?
#
# 신증동국여지승람에 따르면 금강산에는 총 몇개의 사찰이 있었는가?
#
# 금강산 관광지구법이 채택된 날짜는?
#
# 금강산 관광지구법이 채택된 날짜는?
#
# 금강산 관광지구법이 채택된 날짜는?
#
# 금강산 관광지구법이 채택된 날짜는?
#
# 금강산 관광지구법이 채택된 날짜는?
#
# 금강산 관광지구법에 따라 엄격히 보호되고 있는 산은?
#
# 현대그룹의 창업자 정주영이 금강산 관광개발 의정서를 체결한 해는?
#
# 금강산 관광개발 의정서를 체결한 해는?
#
# 금강산 관광개발 의정서를 체결한 해는?
#
# 정주영이 금강산 관광개발 의정서를 체결한 해는?
#
# 현대그룹의 금강산 관광개발 의정서를 체결한 해는?
#
# 금강산 관광개발 의정서를 체결한 해는?
#
# 정주영이 금강산 관광개발의정서를 체결한 년도는?
#
# 정주영이 금강산 관광개발 의정서를 체결한 해는?
#
# 금강산 관광개발 의정서를 체결한 해는?
#
# 금강산 관광이 가이드를 통해 이루어지는 형태는?
#
# 금강산 관광이 가이드를 통해 이루어지는 형태는?
#
# 남측 강원도가 2008년 7월에 발족해 운영하고 있는 것은?
#
# 금강산 관광이 가이드를 통해 이루어지는 형태는?
#
# 금강산 관광이 가이드를 통해 이루어지는 형태는?
#
# 금강산 관광이 가이드를 통해 이루어지는 형태는?
#
# 체스보드에서 1부터 8까지의 숫자가 붙여지고 붙여지는 알파벳은?
#
# 체스보드에서 1부터 8까지의 숫자가 붙여지고 "행"은 파일이라고 불리는 것은?
#
# 체스보드에서 1부터 8까지의 숫자가 붙여지고 붙여진 알파벳은?
#
# 체스보드에서 1부터 8까지의 숫자가 붙여지고 붙어진 알파벳은?
#
# 체스보드의 32개의 정사각형 중 흰색과 검은색이 번갈아가며 칠해져 있는 것은?
#
# 체스보드에서 1부터 8까지의 숫자가 붙여지고 붙여지는 알파벳은?
#
# 체스를 두는 사람의 가장 오른쪽 아래에 위치한 정사각형의 색은?
#
# 체스보드에서 1부터 8까지의 숫자가 붙여지고 붙여진 것은?
#
# 체스보드에서 1부터 8까지의 숫자가 붙여지고 붙여진 알파벳은?
#
# 흑의 폰이 두칸 전진했을 때 바로 옆 파일의 몇번째 랭크에 백색 폰이 존재하는가?
#
# 흑의 폰이 두칸 전진했을 때 바로 옆 파일의 5번째 랭크에 백색 폰이 존재한다면 앙파상 규칙으로 백색 폰을 잡을 수 있는 것은?
#
# 흑의 폰이 두칸 전진했을 때 바로 옆 파일의 몇번째 랭크에 흑색폰이 존재하는가?
#
# 흑의 폰이 두칸 전진했을 때 바로 옆 파일의 흑색 폰은 어떤 규칙을 이용하여 잡을 수 있나?
#
# 8번째 랭크까지 전진시키면 그 폰은 무엇을 하게 되는가?
#
# 퀸은 몇번째 랭크까지 전진하는가?
#
# 퀸은 몇번째 랭크까지 전진시키는가?
#
# 퀸이 8번째 랭크로 전진할 때 한 선수가 동시에 몇 개의 룩을 가지고 프로모션을 하는가?
#
# 8번째 랭크로 전진할 때 한 선수가 동시에 9개의 퀸과 10개의 룩을 가지고 있는 것은?
#
# 퀸은 몇번째 랭크까지 전진하는가?
#
# 퀸으로 프로모션을 진행하는 스타일은?
#
# 상대의 기물에 의해 체크를 당하고 있으며, 어떠한 방법으로도 체크를 피할 수 없을 때 그 기물은 무엇을 당했다고 하는가?
#
# 백의 킹이 상대의 기물에 의해 체크를 당하고 있을 때, 상대의 기물은 무엇을 당했다고 하는가?
#
# 백의 킹이 상대의 기물에 의해 체크를 당하고 있을 때, 상대의 기물에 의해 체크를 피할 수 없을 때 그 기물은 무엇을 당했다고 하는가?
#
# 백의 킹이 상대의 기물에 의해 체크를 당하고 있을 때, 그 기물은 무엇을 당했다고 하는가?
#
# 상대의 기물에 의해 체크를 당하고 있고 어떠한 방법으로도 체크를 피할 수 없을때 그 기물은 무엇을 당했다고 하는가?
#
# 상대의 기물에 의해 체크를 당하고 있고 어떠한 방법으로도 체크를 피할 수 없을 때, 그 기물은 무엇을 당했다고 하는가?
#
# 백의 킹이 상대의 기물에 의해 체크를 당하고 있을 때, 어떠한 방법으로 체크를 피할 수 없을때 그 기물은 무엇을 당했다고 하는가?
#
# 상대 선수가 악수의 의미를 기권이 아닌 요청으로 받아들일 수 있는 것은?
#
# 상대 선수가 악수의 의미를 기권이 아닌 무엇으로 받아들일 수 있는가?
#
# 상대 선수가 악수의 의미를 기권이 아닌 무엇으로 받아들이는가?
#
# 상대 선수가 악수의 의미를 기권이 아닌 어떤 요청으로 받아들일 수 있는가?
#
# 상대 선수가 악수의 의미를 기권이 아닌 무엇으로 받아들이는가?
#
# 상대 선수가 악수의 의미를 기권이 아닌 무엇으로 받아들일 수 있는가?
#
# 상대 선수가 악수의 의미를 기권이 아닌 무엇으로 받아들일 수 있는가?
#
# 시간제한이 주어진 대국에 적용된 것은?
#
# 시간제한이 주어진 대국에 대해서 적용된 것은?
#
# 각 선수마다 경기 전체에 대한 시간을 할당 받을 수도 있고, 몇 수마다 시간을 할당 받을 수 있는 것은?
#
# 시간제한이 주어진 대국에 대해서 적용된 것은?
#
# 각 선수마다 경기 전체에 대한 시간을 할당 받을 수 있는 수단은?
#
# 시간제한이 주어진 대국에 대해서 적용된 것은?
#
# 미국의 체스 협회는 룩부터 만진 경우에도 캐슬링의 의도가 있었으면 무엇을 허용하는가?
#
# 룩을 먼저 이동 시킬 경우 캐슬링의 의도가 성립되는 것은?
#
# 룩부터 만진 경우에도 캐슬링의 의도가 있었으면 허용되는 것은?
#
# 룩부터 만진 경우에도 캐슬링을 허용하는 협회는?
#
# 룩을 먼저 이동 시킬 경우 주위로 2칸 이상 갈 수 없는 것은?
#
# 미국의 체스 협회가 규칙에 어긋난 경우에도 캐슬링을 허용하는 이유는?
#
# 룩이 주위로 2칸 이상 갈 수 없으므로 캐슬링의 의도가 성립되는 것은?
#
# 룩을 먼저 이동 시킬 경우 룩이 캐슬링의 의도가 아닐 수 있는 것은?
#
# 각 선수가 자신에게 주어진 시간 안에 수를 두어야 하며 자신의 시간을 모두 사용한 경우 패배하게 되는 것은 무엇인가?
#
# 상대 선수의 시계가 멈춘 후 시계가 멈춘 후 추가시간만큼 잠시 시계가 멈추는 경우는 어떤 경우인가?
#
# 각 선수는 자신에게 주어진 시간 안에 무엇을 두어야 하는가?
#
# 토너먼먼트는 시간제 안에서 이루어지는 경기로 각 선수는 자신에게 주어진 시간 안에 무엇을 두어야 하는가?
#
# USCF 규칙 14E에 따르면 시간초과로 승리하기에 기물이 부족한 경우를 뭐라고 하는가?
#
# USCF에서는 남은 기물로 무엇을 강제할 수 있는지 기준으로 판단하는가?
#
# USCF규칙 14E에서 시간초과로 승리하기에 부족한 경우 두개의 나이트는 무엇이 없는 상태인가?
#
# USCF규칙 14E에 따르면 시간초과로 승리하기에 부족한 상태는 무엇인가?
#
# USCF규칙 14E에 따르면 시간초과로 승리하기 위해 필요한 조건은 무엇인가?
#
# 랭크마다 1부터 8까지의 숫자가 붙어있는 법은?
#
# 대수기보법에서 랭크마다 1부터 8까지의 숫자가 붙어있는 것을 무엇이라 하는가?
#
# 대수기보법에서 랭크마다 1부터 8까지의 숫자가 붙어있는 것을 무엇이라 하는가?
#
# 랭크마다 1부터 8까지의 숫자가 붙어 있고 그 열은 무엇이라고 불리는가?
#
# 랭크마다 1부터 8까지의 숫자가 붙어있는 것을 무엇이라 하는가?
#
# 랭크마다 1부터 8까지의 숫자가 붙어있는 것을 무엇이라 하는가?
#
# 대수기보법에서 랭크마다 1부터 8까지의 숫자가 붙어있는 것을 무엇이라 하는가?
#
# 게임 도중 게임의 시작 포지션이 규칙에 어긋난 사실이 발견되면 게임은 무엇에 재시작되는가?
#
# 게임 도중 게임의 시작 포지션이 규칙에 어긋난 사실이 발견되면 게임은 언제 재시작되는가?
#
# 게임 도중 게임의 시작 포지션이 규칙에 어긋난 사실이 발견되면 게임은 재시작되는 것은?
#
# 게임 도중 게임의 시작 포지션이 규칙에 어긋난 사실이 발견되면 언제 재시작되는가?
#
# 체스보드 안의 각 정사각형의 한 변의 길이는 킹의 지름의 몇 배인가?
#
# 정사각형의 한 변의 길이는 킹의 지름의 몇 배정도로 적합한가?
#
# 체스보드 안의 각 정사각형의 한 변의 길이는?
#
# 체스보드 안의 각 정사각형의 한 변의 길이는 킹의 지름의 몇배정도 되는가?
#
# 체스보드 안의 각 정사각형의 한 변의 길이는 킹의 지름의 몇 배정도로 적합한가?
#
# 체스보드 안의 각 정사각형의 한 변의 길이는 킹의 지름의 몇 배정도가 적당하는가?
#
# 정사각형의 한 변의 길이는?
#
# 15세기~16세기 초에 이르러서 널리 사용된 현대적인 체스 규칙이 만들어진 도시는?
#
# 퀸은 무엇을 제외한 기물들 중 가장 약한 기물이었는가?
#
# 13세기 이탈리아에서 처음 만들어진 현대적인 체스 규칙은?
#
# 13세기 이탈리아에서 처음 만들어진 현대적인 체스 규칙은 어디서 처음 사용되었는가?
#
# 13세기 이탈리아에서 처음 만들어진 현대적인 체스 규칙은 어디에서 처음 사용되었는가?
#
# 13세기 이탈리아에서 처음 만들어진 현대적인 체스 규칙은?
#
# 13세기 이탈리아에서 처음 만들어진 현대적인 체스 규칙은 몇백년 동안 계속 발전해 왔는가?
#
# 티베트 고원은 세계에서 가장 높고 그 면적이 약 250만 평방 킬로미터에 달하는 고원은?
#
# 티베트 고원의 평균 기온은 영하 몇도로 떨어지는가?
#
# 유목민들이 목초지에서 유목 생활을 하며 서리가 내리는 목초지에서 유목한 기간은?
#
# 티베트 고원의 평균 높이는?
#
# 티베트 고원은 세계에서 가장 높고 크며 면적이 약 몇 미터인가?
#
# 티베트 고원은 세계에서 가장 높고 크며 면적이 약 몇 미터인가?
#
# 티베트 고원의 평균 기온은 영하 몇C까지 떨어지는가?
#
# 커커시리는 전 아시아에서 몇 번째로 인구밀도가 희박한 지역으로 잘 알려져 있는가?
#
# 전 아시아에서 가장 인구밀도가 희박한 지역으로 알려진 고원은?
#
# 전 아시아에서 가장 인구밀도가 희박한 고원은?
#
# 커커시리는 전 아시아에서 몇 번째로 인구밀도가 희박한 지역인가?
#
# 전 아시아에서 가장 인구밀도가 희박한 지역으로 잘 알려진 곳은?
#
# 전 아시아에서 가장 인구밀도가 희박한 지역으로 잘 알려진 곳은?
#
# 전 아시아에서 가장 인구밀도가 희박한 지역으로 알려진 곳은 어디인가?
#
# 티베트 고원은 신생대 초기(약 5500만 년 전)에 인도-오스트레일리아판과 무엇의 충돌로 형성되기 시작했는가?
#
# 티베트 고원은 신생대 초기(약 5500만 년 전)에 인도-오스트레일리아판과 무엇의 충돌로 형성되었는가?
#
# 티베트 고원에서 유라시아판의 충돌로 형성된 고원은?
#
# 티베트 고원은 언제 형성되기 시작했는가?
#
# 티베트 고원은 신생대 초기에 어떤판의 충돌로 형성되었는가?
#
# 티베트 고원은 언제 형성되기 시작했는가?
#
# 티베트 고원은 신생대 초기 어느 대륙의 충돌로 형성되었는가?
#
# 티베트 고원은 언제 형성되기 시작했는가?
#
# 김정남이 조선콤퓨터쎈터 위원장을 맡았던 기간은?
#
# 1998년 김정남이 숙청된 후 임명된 직책은?
#
# 김정남이 도미니카 공화국 위조 여권으로 일본에 밀입국하려다 적발된 해는?
#
# 김정남이 도미니카 공화국 위조 여권으로 일본에 밀입국하려다 적발된 해는?
#
# 김정남이 도미니카 공화국 위조 여권으로 일본에 밀입국을 시도하다 적발된 해는?
#
# 김정남이 도미니카 공화국 위조 여권으로 일본에 밀입국 시도를 하다 적발된 해는?
#
# 김정남이 도미니카 공화국 위조 여권으로 일본에 밀입국을 시도하다 적발된 해는?
#
# 김정남 암살은 언제부터 진행되었는가?
#
# 김정남이 암살을 실행한 인도네시아,베트남 출신 여성 2명을 배후에서 사주한 일당이 모두 조선민주주의인민공화국 국적이라 발표한 것은 언제인가?
#
# 김정남 암살은 누구의 최순위 목표였나?
#
# 김정남 암살은 누구의 최순위 목표였나?
#
# 김정남 암살은 언제부터 진행되었나?
#
# 김정남 암살은 언제부터 진행되었는가?
#
# 김정남 암살은 언제부터 진행되었는가?
#
# 김정남 암살은 김정은이 권력을 승계받은 이후 정찰총국 등 북한 정보당국의 최순위 목표였다고 국가정보원이 밝힌 날짜는?
#
# 박형식은 초등학교 몇학년 때 검도를 배우기 시작하였는가?
#
# 박형식의 생년월일은?
#
# 박형식 아버지의 직업은?
#
# 박형식 아버지의 직업은?
#
# 박형식은 현재 디지털서울문화예술대학교 경영학과에 재학중인 것으로 알려진 학년은?
#
# 박형식의 생년월일은?
#
# 박형식이라는 이름은 누구의 이름인가?
#
# 박형식의 학년은?
#
# see-through HMD를 발전시킨 것은 누구인가?
#
# seee-through HMD를 발전시킨 사람은?
#
# see-through HMD를 발전시킨 사람은?
#
# see-through HMD를 발전시킨 사람은?
#
# see-through HMD를 발전시킨 사람은?
#
# see-through HMD를 발전시킨 것은 누구인가?
#
# 가상 현실의 한 분야로 가상 현실과 다른 의미를 가지는 것은?
#
# 역산에 따르면 하늘의 계시를 해석해 군주의 죽음이나 전쟁, 자연재해 등 국가의 중대사를 점치는 기술로서도 사용된 것은?
#
# 역산에 따라 실제 예측을 하기 위해 행하는 계산을 부르는 말은?
#
# 역산에 따라 실제 예측을 하기 위해 행하는 계산을 부르는 말은?
#
# 역산에 따라 실제 예측을 하는 계산을 부르는 말은?
#
# 1 삭망월의 평균치는 약 몇일인가?
#
# 태음태양력의 달이 차고 지는 것은 차츰 시간이 가면서 어떤 것과 맞지않기 때문인가?
#
# 태음태양력의 달이 차고 지는 것은 차츰 시간이 가면서 계절과 맞지 않기 시작하는 이유는?
#
# 달이 차고 지는 것은 차츰 시간이 가면서 계절과 맞지 않기 시작하는 이유는?
#
# 매 월의 일수는 무엇을 기준으로 정하나?
#
# 달이 차고 지는 것은 차츰 시간이 가면서 계절과 맞지않는 이유는?
#
# 기존의 역법의 폐기 및 새로운 역법을 편찬하는 것을 무엇이라고 하는가?
#
# 기존의 역법의 폐기 및 새로운 역법을 편찬하는 것을 무엇이라고 하는가?
#
# 기존의 역법을 폐기하고 새로운 역법을 편찬하는 것을 무엇이라고 하는가?
#
# 기존의 역법의 폐기 및 새로운 역법을 편찬하는 것을 무엇이라 하는가?
#
# 기존의 역법의 폐기 및 새로운 역법을 편찬하는 것을 무엇이라 하는가?
#
# 달력을 제작할때 기초가 되는 계산법과 천문상수의 체계를 무엇이라 하는가?
#
# 기존의 역법의 폐기 및 새로운 역법을 편찬하는 것을 무엇이라 하는가?
#
# 달력을 제작할 때에 기초가 되는 계산법과 천문상수의 체계를 무엇이라 하는가?
#
# 기존의 역법을 폐기하고 새로운 역법을 편찬하는 것을 무엇이라고 하는가?
#
# 태초력은 누구에 의해 증보되어 삼통력이 되었는가?
#
# 달의 운행에 대한 새로운 연구 결과를 역법에 적용한 사람은 누구인가?
#
# 태초력은 누구에 의해 증보되어 삼통력이 되었는가?
#
# 앞에서의 연대배치법과 치윤법이 확립되어 역법의 기본 원리가 확립된 시기는?
#
# 태양과 달의 운행을 연구한 결과 달의 운행속도가 일정하지 않다는 것을 발견한 시대는?
#
# 연대배치법과 치윤법이 확립되어 역법의 기본 원리가 확립된 시대는?
#
# 태초력은 누구에 의해 증보되어 삼통력이 되었는가?
#
# 조충지가 도입에 있었던 법은?
#
# 조충지는 1태양년에 얼마를 삽입해야 한다고 주장했는가?
#
# 태양의 운행속도가 일정하지않을 때, 북조에서 태양의 운행속도가 일정하지 않다는 것이 밝혀진 것은?
#
# 조충지가 개력을 주장하기 위해 도입된 법은?
#
# 조충지가 원가력이 시행된 지 얼마 안 된 것을 지적하고 개력을 주장하였는가?
#
# 태양의 운행속도가 일정하지 않은 것이 밝혀져 수나라가 망할 때까지 시행된 것은?
#
# 원가력이 시행된 지 얼마 만에 개력을 주장하였는가?
#
# 세차운동으로 1 태양년의 길이가 짧아지는 현상을 역법에 도입해 채택한 계산법은?
#
# 개력이 빈번하게 일어난 시대는?
#
# 세차운동 때문에 1 태양년의 길이가 서서히 짧아지는 현상을 역법에 도입해 채택한 것은?
#
# 세차운동으로 1 태양년의 길이가 서서히 짧아지는 현상을 역법에 도입한 것은?
#
# 세차운동으로 태양년의 길이가 서서히 짧아지는 현상을 역법에 도입한 것은?
#
# 세차운동으로 1 태양년의 길이가 짧아지는 현상을 역법에 도입해 채택한 계산법은?
#
# 세차운동 때문에 1 태양년의 길이가 줄어드는 현상을 역법에 도입해 채택한 것은?
#
# 소토마요르가 첫 세계 주니어 기록을 세운 년도는?
#
# 소토마요르의 첫 국제 타이틀은?
#
# 소토마요르는 1984년 5월 19일 무엇을 제거하여 첫 세계 주니어 기록을 세웠는가?
#
# 소토마요르가 세계 선수권 대회에서 획득한 메달은?
#
# 소토마요르가 1984년 5월 19일 제거한 것은?
#
# 소토마요르가 처음으로 세계 주니어 기록을 세운 것은 언제인가?
#
# 소토마요르가 1984년 5월 19일 제거한 것은?
#
# 소토마요르의 첫 국제 타이틀은?
#
# 국제 아마추어 육상 연맹이 주최한 세계 실내 선수권 대회에서 소토마요르가 제거한 구간은?
#
# 국제 아마추어 육상 연맹이 주최한 세계 실내 선수권 대회에서 자신이 첫 시도 2.43m를 제거하면서 기록을 깬 선수의 이름은?
#
# 국제 아마추어 육상 연맹이 주최한 세계 실내 선수권 대회에서 처음 시도 2.43m를 제거하면서 기록을 깬 선수의 이름은?
#
# 국제 아마추어 육상 연맹이 주최한 세계 실내 선수권 대회에서 자신의 첫 시도 2.43m를 제거하면서 기록을 깬 선수의 이름은?
#
# 국제 아마추어 육상 연맹이 주최한 대회에서 자신의 첫 시도 2.43m를 제거하면서 기록을 깬 선수의 이름은?
#
# 국제 아마추어 육상 연맹이 주최한 대회에서 자신의 첫 시도 2.43m를 제거하면서 기록을 깬 선수의 이름은?
#
# 소토마요르가 우승한 올림픽은?
#
# 바르셀로나 올림픽에서 소토마요르가 우승한 종목은?
#
# 소토마요르가 결승전에서 획득한 메달은?
#
# 바르셀로나 올림픽에서 소토마요르가 우승한 종목은?
#
# 바르셀로나 올림픽에서 소토마요르가 우승한 종목은?
#
# 바르셀로나 올림픽에서 소토마요르가 우승한 종목은?
#
# 바르셀로나 올림픽에서 소토마요르가 우승한 종목은?
#
# 소토마요르는 1996년 애틀랜타 올림픽에서 무엇을 유지하려고 시도하였는가?
#
# 소토마요르는 1996년 애틀랜타 올림픽에서 자신의 무엇을 유지하려 시도하였는가?
#
# 소토마요르가 자신의 올림픽 타이틀을 유지하려는 시도를 한 올림픽은?
#
# 1996년 애틀랜타 올림픽에서 소토마요르가 자신의 무엇을 유지하려 시도하였는가?
#
# 1996년 애틀랜타 올림픽에서 소토마요르가 자신의 타이틀을 유지하기 위해 시도한 것은?
#
# 소토마요르가 애틀랜타 올림픽에서 올림픽 타이틀을 유지하려고 한 년도는?
#
# 소토마요르가 애틀랜타 올림픽에서 자신의 타이틀을 유지하려고 시도한 년도는?
#
# 국제 아마추어 육상 연맹은 소토마요르를 몇살까지 출전할 수 있도록 하였는가?
#
# 국제 아마추어 육상 연맹이 소토마요르를 참가할 수 있도록 한 나이는?
#
# 소토마요르가 시드니 올림픽에 참가할 수 있도록 한 연맹은?
#
# 국제 아마추어 육상 연맹이 소토마요르를 참가할 수 있도록 한 때는?
#
# 국제 아마추어 육상 연맹이 소토마요르의 소토마요르를 참가할 수 있도록 한 나이는?
#
# 국제 아마추어 육상 연맹이 소토마요르를 참가할 수 있도록 한 때는?
#
# 국제 아마추어 육상 연맹이 소토마요르의 출전 금지를 줄이지 말아야 했다고 호소한 선수의 이름은?
#
# 조양호 회장의 세 자녀가 싸이버스카이 지분을 어디에 팔았는가?
#
# 대한항공 기내면세점 운영을 주력으로 하는 회사는?
#
# 대한항공 기내면세점 운영을 주력으로 하는 회사의 이름은?
#
# 대한항공 기내면세점 운영을 주력으로 하는 회사의 이름은?
#
# 대한항공 기내면세점 운영을 주력으로 하는 회사로 오너3세의 편법 재산 증식과 일감 몰아주기 논란을 빚어왔던 회사는?
#
# 조양호 회장의 세 자녀가 싸이버스카이 지분을 어디에 모두 팔았는가?
#
# 대한항공 기내면세점 운영을 주력으로 하는 회사는?
#
# 조양호 회장의 세명의 자녀가 싸이버스카이 지분을 어디에 팔았는가?
#
# 1974년 민청학련 사건에 연루되어 구금되었던 사람은?
#
# 5.18 군사쿠데타에 관해서 권력을 잡는 방법은 비정상적이었지만 권력을 잡은 측면과 전체를 한꺼번에 봐야한다고 말한 사람은?
#
# 1980년 5월 5.18 항쟁 시민군을 태운 버스 운전사에게 사형을 선고한 사람은?
#
# 1980년 5월 5.18 항쟁 시민군을 태운 버스 운전사에게 사형을 선고한 사람은?
#
# 1980년 5월 5.18 항쟁 시민군을 태운 버스 운전사에게 사형을 선고한 새누리당 의원은?
#
# 1980년 5월 5.18 항쟁에서 시민군을 태운 버스 운전사에게 사형을 선고한 사람은?
#
# 1980년 5월 법무사 군법관으로 임관해 5.18 항쟁 시민군을 태운 버스 운전사에게 사형을 선고한 사람은?
#
# 1980년 5월 5.18 항쟁 시민군을 태운 버스 운전사에게 사형을 선고한 새누리당 의원은?
#
# 1980년 5월 5.18 항쟁 시민군을 태운 버스 운전사에게 사형을 선고한 사람은?
#
# 이정미 재판관의 퇴임 후 김이수는 무엇으로 선출되었는가?
#
# 이정미 재판관의 퇴임 후 김이수가 권한대행을 맡은 직책은?
#
# 이정미 재판관의 퇴임 후 김이수는 무엇으로 선출되었는가?
#
# 이정미 재판관의 퇴임 후 무엇으로 선출되었는가?
#
# 이정미 재판관의 퇴임 후 김이수는 무엇으로 선출되었는가?
#
# 이정미 재판관의 퇴임 후 무엇으로 선출되었는가?
#
# 이정미 재판관의 퇴임 후 김이수는 무엇으로 선출되었는가?
#
# 이정미 재판관의 퇴임 후 김이수가 맡은 직책은?
#
# 1930년 한 공동주택이 세워진 곳은?
#
# 1930년 한 공동주택이 세워진 곳은?
#
# 1930년 한 공동주택이 세워진 곳은?
#
# 1930년 한 공동주택이 세워진 곳은?
#
# 1930년 한 공동주택이 세워진 곳은?
#
# 1930년 회현동에 세워진 공동주택의 위치는?
#
# 1930년 한 공동주택이 세워진 곳은?
#
# 한 공동주택이 세워진 연도는?
#
# 조선주택영단이 여러가지 주택 유형을 연구하기 위하여 우리나라에 여러 대안을 실현하게 된 해는?
#
# 조선주택영단이 여러가지 주택 유형을 연구하기 위해 우리나라에 여러 대안을 실현하게 된 연도는?
#
# 조선주택영단이 여러가지 주택 유형을 연구하기 위해 대한민국에 여러 대안을 실현하게 된 해는?
#
# 조선주택영단이 여러가지 주택 유형을 연구하기 위하여 대한민국에 여러 대안을 실현하게 된 연도는?
#
# 조선주택영단이 여러가지 주택 유형을 연구하기 위해 대한민국에 여러 대안을 실현하게 된 해는?
#
# 조선주택영단이 여러가지 주택 유형을 연구하기 위하여 대한민국에 여러 대안을 실현하게 된 해는?
#
# 조선주택영단이 여러가지 주택 유형을 연구하기 위하여 우리나라에 여러 대안을 실현하게 된 해는?
#
# 청풍장-소화장아파트는 부산광역시에 지어진 최초의 몇층 짜리 아파트인가?
#
# 청풍장-소화장아파트는 부산광역시에 지어진 최초의 몇층 짜리 아파트인가?
#
# 청풍장-소화장아파트는 부산광역시에 지어진 최초의 몇층 짜리 아파트인가?
#
# 청풍장-소화장아파트는 부산광역시에 지어진 최초의 몇층 짜리 아파트인가?
#
# 청풍장-소화장아파트는 부산광역시에 지어진 최초의 4층 짜리 아파트인가?
#
# 청풍장-소화장아파트는 부산광역시에 지어진 최초의 몇층 짜리 아파트인가?
#
# 청풍장-소화장아파트가 건립된 해는?
#
# 최초의 계단실형 아파트로 건축된 단지의 용적률은?
#
# 대한주택공사가 아파트를 지은 것은 언제인가?
#
# 엘리베이터 가동용 전기와 건설비용을 절약하기 위해 건설된 건축방식은?
#
# 서울특별시에 현존하는 아파트 중 2번째로 오래된 동대문아파트를 미래유산으로 선정하려다 무산된 이유는?
#
# 대한주택공사가 지은 아파트로 연예인들이 많이 살았던 아파트의 별명은?
#
# 동대문아파트의 7층짜리 중앙정원형 아파트로 초기에는 연예인들이 많이 살았던 아파트의 별명은?
#
# 1965년 완공된 동대문아파트의 층수는?
#
# 동대문아파트의 중앙정원형 아파트로 초기에는 연예인들이 많이 살아 어떤 별명이 있었는가?
#
# 동대문아파트가 완공된 해는?
#
# 대한주택공사가 지은 아파트로 초기에는 연예인들이 많이 살았던 아파트의 별명은?
#
# 세운상가가 세워진 해는?
#
# 세운상가가 지어지기 시작한 해는?
#
# 세운상가의 세운상가가 지어지기 시작한 해는?
#
# 세운상가가 지어지기 시작한 해는?
#
# 세운상가가 세워진 해는?
#
# 세운상가가 지어질 당시 세운상가의 개발자는 누구였는가?
#
# 세운상가의 세운상가의 세운상가는 몇 년도에 지어졌는가?
#
# 한남동 힐탑아파트가 고층아파트라는 수식어를 지니고 있는 이유는?
#
# 우리나라 최초의 고층아파트라는 수식어를 지니고 있는 힐탑아파트의 지상 층수는?
#
# 우리나라 최초의 고층아파트라는 수식어를 지니고 있는 건설사는?
#
# 우리나라 최초의 고층아파트라는 수식어를 지니고 있는 건설사는?
#
# 우리나라 최초의 고층아파트라는 수식어를 지니고 있는 건설사는?
#
# 우리나라 최초의 고층아파트라는 수식어를 지니고 있는 건설사는?
#
# 우리나라 최초의 고층아파트라는 수식어를 지니고 있는 것은?
#
# 남산외인아파트가 철거된 년도는?
#
# 남산외인아파트가 철거된 년도는?
#
# 남산외인아파트가 철거된 년도는?
#
# 남산외인아파트는 남산을 가로막는 어떤 이유로 1994년 철거되었는가?
#
# 남산외인아파트가 철거된 년도는?
#
# 남산외인아파트가 철거된 년도는?
#
# 남산외인아파트가 철거된 년도는?
#
# 빈민주택의 불량함을 제거하고 환경파괴나 불법점거 등의 주택단지 등을 없애기 위해 세운상가의 와우시민아파트 건립을 추진한 년도는?
#
# 서울시가 환경파괴나 불법점거 등의 주택단지 등을 없애기 위해 추진한 것은?
#
# 서울시가 빈민주택의 불량함을 제거하고 환경파괴나 불법점거등의 주택단지 등을 없애기 위해 추진한 것은?
#
# 1969년 서울시는 빈민주택의 불량함을 제거하고, 환경파괴나 불법점거 등의 주택단지 등을 없애기 위해 어떤 계획을 추진하였는가?
#
# 와우시민아파트가 철거된 해는?
#
# 서울시는 환경파괴나 불법점거 등의 주택단지 등을 없애기 위해 무엇을 추진하였는가?
#
# 서울시는 1969년 빈민주택의 불량함을 제거하고 환경파괴나 불법점거등의 주택단지 등을 없애기 위해 어떤 계획을 추진하였는가?
#
# 회현 제2시민아파트가 완공된 년도는?
#
# 회현 제2시민아파트가 완공된 년도는?
#
# 회현 제2 시민아파트가 완공된 년도는?
#
# 회현 제2 시민아파트가 완공된 년도는?
#
# 회현 제2 시민아파트가 완공된 해는?
#
# 회현 제2 시민아파트가 완공된 해는?
#
# 회현 제2 시민아파트가 완공된 년도는?
#
# 여의도 시범아파트의 규모는?
#
# 여의도 시범아파트의 규모는?
#
# 여의도 시범아파트가 지어질 당시 가장대표되는 기둥식 아파트로 알려진 아파트는?
#
# 여의도 시범아파트의 규모는?
#
# 여의도 시범아파트가 완공된 년도는?
#
# 여의도 시범아파트의 규모는?
#
# 여의도 시범아파트가 완공된 해는?
#
# 서소문아파트가 지은 하천을 따라 115m 길이로 지어진 아파트의 이름은?
#
# 1972년 서대문구에 지어졌으며 1971년에 입주한 아파트의 선형식 아파트의 이름은?
#
# 서대문구 미근동에 있는 선형식 아파트로 1972년에 입주한 서소문아파트의 주소는?
#
# 서소문아파트가 지은 곳은?
#
# 서소문아파트는 하천을 따라 몇m 길이로 지어진 아파트인가?
#
# 1971년 서소문아파트가 입주한 곳은 어디인가?
#
# 1971년 서소문아파트가 지은 하천복개지역이라는 주소가 만들어진 곳은?
#
# 서울 중림동 149번지 성요셉 아파트를 지은곳은?
#
# 성요셉아파트는 몇 층까지 주거 시설로 이용되고 있는가?
#
# 성요셉 아파트는 몇 층까지 주거 시설로 이용되고 있는가?
#
# 성요셉아파트는 몇 층까지 주거 시설로 이용되고 있는가?
#
# 초기 약현성당이 성당 성도들에게 아파트를 제공하기 위해 시작한 사업은?
#
# 성요셉 아파트는 몇 층까지 주거 시설로 이용되고 있는가?
#
# 초기 약현성당이 성당 성도들에게 아파트를 제공하기 위해 시작한 사업은?
#
# 반포주공아파트가 대한민국을 '아파트공화국'으로 만드는데 큰 기여를 한 것은?
#
# 대한민국 최초의 주공아파트 대단지인 반포주공아파트를 건설한 곳은?
#
# 반포주공아파트는 대한민국 최초의 주공아파트 대단지인가?
#
# 반포주공아파트는 대한민국 최초의 주공아파트 대단지인가?
#
# 반포주공아파트는 대한민국 최초의 주공아파트 대단지인가?
#
# 반포주공아파트 1개동을 마을 박물관으로 조성한다고 밝힌 년도는?
#
# 반포주공아파트는 대한민국 최초의 주공아파트 대단지인데, 22평~62평 3786가구로 지은 대단지인가?
#
# 1981년 개포주공아파트를 지은 건설사는?
#
# 1981년 개포주공아파트를 지은 건설사는?
#
# 개포주공아파트는 1단지에서 몇단지까지 지어졌는가?
#
# 1981년 개포주공아파트를 지은 건설사는?
#
# 1981년 개포주공아파트를 지은 건설사는?
#
# 1981년 개포주공아파트를 지은 건설사는?
#
# 1981년 개포주공아파트를 지은 건설사는?
#
# 압구정 현대아파트의 분양가는?
#
# 압구정동 현대아파트의 분양가는 3.3m2당 얼마인가?
#
# 압구정 현대아파트는 몇 년도에 건설되었는가?
#
# 압구정 현대아파트의 고층 아파트 성장의 흔적을 압축적으로 보여준 한남대교와 1970년 개통된 고속도로는?
#
# 압구정 현대아파트가 건설된 년도는?
#
# 압구정 현대아파트의 분양가는 3.3m2당 얼마인가?
#
# 압구정 현대아파트의 분양가는 3.3m2당 얼마인가?
#
# 서울시는 근현대 문물 보존 프로잭트인 미래문화유산화의 일부보존 대상으로 아파트 몇 군데를 후보로 지정하였는가?
#
# 서울시는 근현대 문물 보존 프로잭트인 미래문화유산화의 일부보존 대상으로 아파트 몇 군데를 후보로 지정하였는가?
#
# 서울시는 근현대 문물 보존 프로잭트인 미래문화유산화의 일부보존 대상으로 아파트 몇 군데를 후보로 지정하였는가?
#
# 서울시는 근현대 문물 보존 프로잭트인 미래문화유산화의 일부보존 대상으로 아파트 몇 군데를 후보로 지정하였는가?
#
# 서울시는 근현대 문물 보존 프로잭트인 미래문화유산화의 일부보존 대상으로 아파트 몇 군데를 후보로 지정하였는가?
#
# 최근 근현대 문물 보존 프로잭트인 미래문화유산화의 일부보존 대상으로 아파트 10군데를 후보로 지정한 곳은?
#
# 100년 주택인 장수명 아파트 인증제 도입을 추진한다고 보도한 곳은 어디인가?
#
# 디지털화폐와 암호화폐는 무엇에 속하는가?
#
# 은행권 동전과 같은 물질인 방식 아닌 디지털방식으로만 사용될 수 있는 유형의 화폐를 가리키는 용어는?
#
# 은행권 동전과 같은 물질인 방식 아닌 디지털방식으로만 사용될 수 있는 유형의 화폐를 가리키는 용어는?
#
# 은행권 동전과 같은 물질인 방식 아닌 디지털방식으로만 사용될 수 있는 유형의 화폐를 가리키는 용어는?
#
# 은행권 동전과 같은 물질인 방식 아닌 디지털방식으로만 사용될 수 있는 유형의 화폐를 가리키는 용어는?
#
# 대한민국의 경우 전자화폐가 되기 위해서는 어떤 요건이 갖춰져야 하는가?
#
# 은행권 동전과 같은 물질인 방식 아닌 디지털방식으로만 사용될 수 있는 화폐를 가리키는 용어는?
#
# 가상화폐를 개발자에 의해 발행되고 수령되는 디지털화폐의 한 유형이라고 정의한 은행은?
#
# 가상화폐란 정부에 의해 통제되지 않는 무엇의 하나인가?
#
# 2013년 미국 재무부 금융범죄규제망은 무엇을 화폐로 지정하였는가?
#
# 비트코인, 이더리움,리플 등 비트코인 이더리움,리플 등 암호화폐를 가리킬 때 가상화폐라는 단어를 쓰지 않는 나라는?
#
# 가상화폐란 특정 가상커뮤니티 회원들 간에 사용되고 수령되는 디지털화폐의 한 유형이라고 정의한 은행은?
#
# 가상화폐는 무엇에 의해 통제되지 않는 디지털화폐의 일종인가?
#
# 비트코인 이더리움 리플 등 비트코인 암호화폐를 가리킬 때 쓰지 않는 단어는?
#
# 분산발행되고 일정한 네트워크에서 화폐로 사용할 수 있는 전자정보는?
#
# 중앙은행이 발행하지 않고 블록체인 기술에 기초하여 금전적 가치가 디지털방식으로 표시된 전자정보는?
#
# 중앙은행이 발행하지 않고 블록체인 기술에 기초하여 금전적 가치가 디지털방식으로 표시된 전자정보는?
#
# 중앙은행이 발행하지 않고 블록체인 기술에 기초하여 금전적 가치가 디지털방식으로 표시된 전자정보는?
#
# 중앙은행이 발행하지 않고 블록체인 기술에 기초하여 금전적 가치가 디지털방식으로 표시된 전자정보는?
#
# 중앙은행이 발행하지 않고 블록체인 기술에 기초하여 금전적 가치가 디지털방식으로 표시된 전자정보는?
#
# 암호화폐의 분산형 통제는 무엇을 통하여 운용되는가?
#
# 암호화폐를 발행하고 관리하는 핵심기법은?
#
# 암호화폐를 발행하고 관리하는 핵심기법은?
#
# 가상화폐를 발행하고 관리하는 핵심기법은?
#
# 가상화폐를 발행하고 관리하는 핵심기법은?
#
# 가상화폐를 발행하고 관리하는 핵심 기법은?
#
# 암호화폐를 발행하고 관리하는 핵심기법은?
#
# 암호화폐를 발행하고 관리하는 핵심기법은?
#
# 비트코인이 화폐로 인정되지 않을 경우 어떤 세금이 과세되지 못하는가?
#
# 비트코인이 소득세 부과 항목에 포함되지 않아, 소득세 부과 항목에 포함되지 않은 것은 무엇인가?
#
# 화폐로 인정될 경우 개인이 환 차익을 통해 얻은 수익은 무엇으로 간주하는가?
#
# 비트코인이 화폐로 인정될 경우 법인의 환 차익은 무엇으로 보는가?
#
# 비트코인을 화폐로 인정해 제도권으로 끌어들임과 동시에 런던을 디지털 금융의 중심지로 육성하는 정책을 채택한 나라는?
#
# 비트코인이 재산이나 투자재와 같은 것으로 간주될 경우 양도소득세 과세 대상이 되지 못하는 세금은?
#
# 마이크로소프트사의 제논 소프트웨어 플랫폼에 대한 계획이 마이크로소프트 부사장 제임스 알라드의 지휘 하에 이루어진 것은 언제인가?
#
# 제논 소프트웨어 플랫폼에 대한 계획이 마이크로소프트사의 개발자 채용을 위해 워싱턴 주, 벨뷰에서 개최한 행사는?
#
# 마이크로소프트사가 개발자 채용을 위해 워싱턴 주, 벨뷰에서 개최한 행사는?
#
# 마이크로소프트사의 제논 소프트웨어 플랫폼에 대한 계획이 마이크로소프트사의 개발자 채용을 위해 워싱턴 주, 벨뷰에서 개최한 행사는?
#
# 제논 소프트웨어 플랫폼에 대한 계획이 마이크로소프트사의 개발자 채용을 위해 워싱턴 주, 벨뷰에서 개최한 행사는?
#
# 2003년 8월 12일 마이크로소프트사와 새로운 콘솔 제품에 대한 그래픽 프로세서 공급 계약을 맺은 회사는?
#
# 제논 소프트웨어 플랫폼에 대한 계획이 마이크로소프트사의 개발자 채용을 위해 워싱턴 주, 벨뷰에서 개최한 행사는?
#
# 제논 소프트웨어 개발에 대한 계획이 마이크로소프트 부사장의 지휘 아래 제논 소프트웨어 부사장 제임스 알라드의 계획에 따라 워싱턴 주, 벨뷰에서 개최된 것은 언제인가?
#
# 엑스박스 360에서 사용할 수 있는 다양한 액세서리를 별도로 판매하고 있는 것은?
#
# 엑스박스 360에서 사용할 수 있는 다양한 액세서리를 별도로 판매하고 있는 것은?
#
# 엑스박스 360에서 사용할 수 있는 다양한 액세서리는?
#
# 엑스박스 360에서 사용할 수 있는 다양한 액세서리를 별도로 판매하고 있는 것은?
#
# 새로운 엑스박스 경험에서 하드 드라이브에 게임을 설치할 수 있는 디스크는?
#
# 새로운 엑스박스 경험에서 디스크에서 게임을 설치할 수 있는 것은?
#
# 디스크에서 게임을 설치하면 게임을 실행할때 나오는 소음은?
#
# 새로운 엑스박스 경험에서 디스크에서 게임을 설치하면 불러오는 시간과 디스크를 구동할 때 나오는 소음을 줄여주는 것은?
#
# 게임을 하드 드라이브에 설치하면 불러오는 시간과 디스크를 구동할 때 나오는 소음을 줄이는 것은?
#
# 디스크에서 하드 드라이브에 게임을 설치하면 불러오는 시간과 디스크를 구동할 때 나오는 소음을 줄인 것은?
#
# 게임을 하드 드라이브에 설치하면 나오는 소음은?
#
# 마이크로소프트가 엑스박스 360 소유자에게 제공하는 온라인 서비스는?
#
# 마이크로소프트가 엑스박스 360 소유자에게 제공하는 온라인 서비스는?
#
# 마이크로소프트가 엑스박스 360 소유자에게 제공하는 온라인 서비스는?
#
# 엑스박스 라이브 아케이드의 출시년도는?
#
# 마이크로소프트가 엑스박스 360 소유자에게 제공하는 온라인 서비스는?
#
# 마이크로소프트가 엑스박스 및 엑스박스 360 소유자에게 제공하는 온라인 서비스는?
#
# 캐나다의 국가 상징 중 하나이며 회사의 근면성을 나타내기 위해 캐나다의 로고로 선택된 것은?
#
# 캐나다의 국가 상징 중 하나이며 회사의 근면성을 나타내는 것은?
#
# 캐나다에서 가장 크고 영향력있는 회사로 1975년까지 캐나다에서 가장 큰 영향력을 가졌던 회사는?
#
# 캐나다의 국가 상징 중 하나이며 회사의 근면성을 나타내도록 한 것은?
#
# 캐나다의 국가 상징 중 하나이며 회사의 근면성을 나타내기 위해 회사의 로고로 선택된 것은?
#
# 캐나다 태평양 철도의 정기여객운송업이 종료된 해는?
#
# 캐나다의 국가 상징 중 하나이며 회사의 근면성을 나타내기 위해 회사의 로고로 선택된 것은?
#
# 캐나다의 국가 상징 중 하나이며 회사의 근면성을 나타내도록 한 것은?
#
# 캐나다의 초대수상은 누구인가?
#
# 캐나다 초대수상 존 맥도날드에게 캐나다의 연방 가입 조건을 제시한 캐나다의 초대수상은?
#
# 캐나다 초대수상 이름은?
#
# 대륙횡단 철도건설을 통일된 대륙국가를 건설하는데 필수적이라고 여긴 캐나다의 수상은 누구인가?
#
# 캐나다 초대수상 존 맥도날드의 보수당이 주장한 연방 가입 조건은?
#
# 캐나다 초대수상 존 맥도날드 수상이 철도건설을 통일된 대륙국가를 건설하는데 필수적이라고 여긴 수상은?
#
# 캐나다 초대수상은 누구인가?
#
# 알렉산더 매캔지가 공공사업의 일환으로 건설한 것은?
#
# 알렉산더 매캔지가 대양간 철도사와 계약을 체결한 해는?
#
# 알렉산더 매캔지가 공공사업의 일환으로 건설한 구간의 이름은?
#
# 알렉산더 매캔지가 대양간 철도사와 계약을 체결한 해는?
#
# 알렉산더 매캔지가 공공사업 일환으로 건설한 구간의 이름은?
#
# 아이케 장군이 상관인 폰 브록도르프 알레펠트 백작과의 불화로 후방으로 전출된 후 선임 연대장의 이름은?
#
# 아이케 장군이 후방으로 전출된 후 선임 연대장의 이름은?
#
# 사단이 데먄스크 근방까지 진격했으나 제2군과 소련군의 동계 역공세에 휘말려 포위망에 빠진 해는?
#
# 아이케 장군이 상관인 폰 브록도르프 알레펠트 백작과의 불화로 후방으로 전출된 후에는 누가 지휘했는가?
#
# 아이케 장군이 상관인 폰 브록도르프 알레펠트 백작과의 불화로 후방으로 전출된 후 누가 사단장 대리로서 토텐코프를 지휘했는가?
#
# 1941년 저물 무렵 사단이 진격한 곳은 어디인가?
#
# 폰 브록도르프 알레펠트 백작과 불화를 일으킨 사람은?
#
# 성채 작전이 종료된 후 배치된 제1 전차 대대의 이름은?
#
# 사단이 비시 프랑스의 탈취 목적으로 한 안톤 작전에 투입된 년도는?
#
# 사단의 잔존병들이 전선에서 철수하고 재편성을 위해 프랑스로 향한 것은 언제인가?
#
# 사단의 잔존병들이 전선에서 철수한 해는?
#
# 사단의 잔존병들이 전선에서 철수하기 위해 프랑스로 이동한 시기는?
#
# 사단이 비시 프랑스의 탈취를 목적으로 한 안톤 작전에 투입된 시기는?
#
# 사단이 비시 프랑스의 탈취를 목적으로 한 안톤 작전에 투입된 것은 언제인가?
#
# 이반 코네프 상장의 공세를 저지하기 위해 제3차 하리코프 공방전에 참전한 부대는?
#
# 이반 코네프 상장의 공세를 저지하기 위해 참전한 제3차 하리코프 공방전은 몇 년도인가?
#
# 이반 코네프 상장의 공세를 저지하기 위해 제3차 하리코프 공방전에 참전한 사단은?
#
# 이반 코네프 상장의 공세를 저지하기 위해 제3차 하리코프 공방전에 참전한 사단은?
#
# 이반 코네프 상장의 공세를 저지하기 위해 제3차 하리코프 공방전에 참전한 부대는?
#
# 이반 코네프 상장의 공세를 저지하기 위해 제3차 하리코프 공방전에 참전한 사단은?
#
# 이반 코네프 상장의 공세를 저지하기 위해 참전한 곳은 어디인가?
#
# 허도환이 2013 시즌 말에 당한 부상으로 인해 참여하지 못한 것은?
#
# 허도환이 2013년 시즌 말에 당한 부상으로 인해 참여하지 못한 것은?
#
# 허도환이 2013 시즌 말에 당한 부상으로 인해 참여하지 못한 일본 캠프는?
#
# 허도환이 부상으로 인해 마무리 캠프나 스프링 캠프에 참여하지 못한 해는?
#
# 허도환이 부상으로 인해 마무리 캠프나 스프링 캠프에 참여하지 못한 년도는?
#
# 허도환이 부상으로 인해 마무리 캠프나 스프링 캠프에 참여하지 못한 년도는?
#
# 대통령이 임기 중에 심각한 레임덕에 빠져 원활한 국정 수행이 불가능한 경우는 어떤 국가에서 일어날 수 있는가?
#
# 대통령이 임기 중에 심각한 레임덕에 빠져 원활한 국정 수행이 불가능한 경우가 발생할 수 있는 것은 무엇을 채택했기 때문인가?
#
# 국무총리와 국무위원, 각 부처의 장관 등 기존의 내각 일원을 전면 교체하고 양당이 모두 내각에 참여하는 방향으로 개각하는 방안 중 양당이 수용 가능한 인물을 국무총리에 임명하는 방안을 무엇이라 하는 방안이 있는가?
#
# 대통령제를 채택한 국가에서는 대통령이 임기 중에 심각한 레임덕에 빠져 국정 수행이 불가능한 경우가 발생할 수 있다. 이것은 무엇인가?
#
# 의회 총선거를 통해 원내에서 가장 많은 의석을 획득한 정당이 정부 내각을 구성할 기회를 얻는 제도는?
#
# 의회 총선거를 통해 원내에서 가장 많은 의석을 획득한 정당이 정부 내각을 구성하는 제도는?
#
# 제 2차 세계 대전 당시 영국에서 집권 정당은?
#
# 의회 총선거를 통해 원내에서 가장 많은 의석을 획득한 정당이 정부 내각을 구성하는 정치 체제는?
#
# 의회 총선거를 통해 원내에서 가장 많은 의석을 획득한 정당이 정부 내각을 구성할 기회를 얻는 제도는?
#
# 의회 총선거를 통해 원내에서 가장 많은 의석을 획득한 정당이 정부 내각을 구성할 기회를 얻는 제도는?
#
# 의회 총선거를 통해 원내에서 가장 많은 의석을 획득한 정당이 정부 내각을 구성하는 정치 체제는?
#
# 이정재의 동향 선배로 곽영주가 수도경찰학교를 수료했다는 이야기가 나오는 TV드라마는?
#
# 이정재의 동향 후배로 이정재의 도움을 받아 수도경찰학교를 수료했다는 이야기가 나오는 TV드라마는?
#
# 이정재의 도움으로 수도경찰학교를 수료했다는 이야기가 나오는 시대는?
#
# 이정재의 도움으로 수도경찰학교를 수료했다는 이야기가 나오는 TV드라마는?
#
# 이정재의 도움으로 수도경찰학교를 입교하였다는 이야기가 와전된것으로 보이는 시대는?
#
# 이정재의 도움을 받아 수도경찰학교를 수료했다는 이야기가 나오는 TV드라마는?
#
# 이정재의 도움으로 수도경찰학교를 수료했다는 이야기가 나오는 시대는?
#
# 이정재의 도움으로 수도경찰학교를 입교했다는 설이 와전된것으로 보이는 사람은?
#
# 백령도 근처 해상에서 대한민국 해군의 초계함인 PCC-772 천안이 피격되어 침몰한 사건은?
#
# 천안함 침몰 사건의 공식 명칭은?
#
# 2010년 3월 26일 백령도 근처 해상에서 대한민국 해군의 초계함으로 피격되어 침몰한 사건은?
#
# 백령도 근처 해상에서 대한민국 해군의 초계함으로 피격되어 침몰한 사건은?
#
# 천안함 침몰 사건으로 대한민국 해군의 초계함이 피격되어 침몰한 사건은?
#
# 천안함 침몰 사건의 공식 명칭은?
#
# 침몰 지점에 배치된 100여 명의 해군 해난구조대 잠수요원들은 무엇을 위해 배치되었는가?
#
# 잠수사들에 의해 발견 된 구명복 상의 갯수는?
#
# 침몰지점에 배치된 100여 명의 해군 해난구조대 잠수 요원들은 무엇을 위해 광양함을 추가로 배치하였는가?
#
# 수색과정에서 발견된 구명복 상의 갯수는?
#
# 수색과정에서 발견된 구명복 상의 갯수는?
#
# 조사팀은 천안함 침몰을 북한 소행이라고 결론 내렸다고 보도한 매체는 어디인가?
#
# 2010년 조사팀은 북한의 어뢰 공격을 무엇에 의한 침몰로 볼 수 없다고 결론 내렸는가?
#
# 조사팀은 천안함 침몰을 무엇에 의한 침몰로 볼 수 없다고 결론 내렸나?
#
# 조사팀은 북한의 어뢰 타격에 의한 침몰로 볼 수 없다고 결론 내렸다고 보도한 매체는 어디인가?
#
# 2010년 7월 8일 조사팀은 천안함 침몰을 무엇에 의한 침몰로 볼 수 없다고 결론 내렸는가?
#
# 합조단의 조사결과를 상당부분 신뢰했기 때문에 유엔 안보리에서 거부권을 가진 국가는 어디인가?
#
# 합조단의 조사결과를 상당부분 신뢰했기 때문에 거부권을 가지고 있던 국가는?
#
# 2010년 7월 27일 조사단의 요약보고서를 공개한 매체는 어디인가?
#
# 천안함 조사단의 요약보고서를 공개한 방송사는 어디인가?
#
# 한국 정부가 러시아의 조사에 비협조적 대응했다고 비판한 인물은?
#
# 한국 정부가 러시아의 조사에 비협조적으로 대응했다고 비판한 인물은?
#
# 한국 정부가 러시아의 조사에 비협조적으로 대응했다고 비판한 인물은?
#
# 한국 정부가 러시아의 조사에 비협조적으로 대응했다고 비판한 인물은?
#
# UN 안보리 의장 성명은 균형 잡히고 객관적이라고 판단한 대통령은 누구인가?
#
# 2010년 9월 15일 한-러 정상회담이 열린 장소는 어디인가?
#
# 2010년 9월 15일 한-러 정상회담이 열린 장소는 어디인가?
#
# 2010년 한-러 정상회담에서 북한이 소행이라는 직접적인 언급을 하지 않은 이유는?
#
# UN 안보리 의장 성명은 언제 채택되었나?
#
# 북한 조선민주주의인민공화국의 외무성 부상은 누구인가?
#
# 북한 조선민주주의인민공화국의 외무성 부상이 천안함 사건을 이용해 미국과 남한이 한반도와 주변지역에서 무력 군사위협을 벌인다고 비난한 인물은?
#
# 조선민주주의인민공화국의 박길연 외무성 부상이 천안함 사건을 이용해 미국과 남한이 한반도와 주변지역에서 무력 군사위협을 벌인다고 비판한 연설은?
#
# 조선민주주의인민공화국의 외무성 부상은 누구인가?
#
# 조선민주주의인민공화국의 외무성 부상이 천안함 사건을 이용해 미국과 남한이 한반도와 주변지역에서 무력 군사위협을 벌이는 것을 비난한 인물은?
#
# 천안함 침몰 원인에 대한 가설 중 외부충격에 의한 가설은?
#
# 천안함 침몰 원인에 대한 가설 중 외부충격에 의한 가설은?
#
# 천안함 침몰 원인에 대한 가설 중 외부충격에 의한 가설은?
#
# 천안함 침몰 원인에 대한 가설 중 외부충격에 의한 것은?
#
# 천안함 침몰 원인에 대한 가설 중 외부충격에 의한 가설은?
#
# 북한 잠수정에 의한 어뢰공격과 인간어뢰에 의한 공격까지 포함하고 있는 것은?
#
# 북한 잠수정에 의한 어뢰공격과 인간어뢰에 의한 공격까지 포함하고 있는 것은?
#
# 북한 잠수정에 의한 어뢰공격과 인간어뢰에 의한 공격까지 포함하고 있는 설은?
#
# 북한 잠수정에 의한 어뢰공격과 인간어뢰에 의한 공격까지 포함하고 있는 것은?
#
# 북한이 잠수정에 의한 어뢰공격과 인간어뢰에 의한 공격까지 포함하고 있는 것은?
#
# 6.25 전쟁 당시 북한군 동해와 서해에 설치한 기뢰가 제거되지 않은 채로 바다 밑에 있던 천안함에 부딪혀 폭발했다는 설이 있는가?
#
# 기뢰사고설의 대상은?
#
# 손석희의 시선집중에 출연하여 선체의 결함 이외에 다른 침몰의 요인을 알지 못한다고 말한 사람은?
#
# 미국 브루킹스연구소 초빙연구원인 박선원 박사가 출연한 시선집중은 어느 방송사인가?
#
# 손석희의 시선집중에 출연한 미국 브루킹스연구소 초빙연구원의 이름은?
#
# 미국 브루킹스연구소 초빙연구원인 박선원 박사는 어느나라 사람인가?
#
# 손석희의 시선집중에 출연하여 선체의 결함 이외에 다른 침몰의 요인을 알지 못한다고 말한 사람은?
#
# 손석희의 시선집중에 출연한 미국 브루킹스연구소 초빙연구원의 이름은?
#
# 선체 프로펠러에서 나는 소음은 몇km 이내에서 감지되는가?
#
# 함정에서 내는 소음은 몇km 이내에서 감지되는가?
#
# 천안함 사건을 10년 동안 북한이 철저하게 준비해온 사건이라고 주장한 고위급 탈북자는 누구인가?
#
# 천안함 사건이 10년 동안 북한이 준비해온 사건이라고 주장한 고위급 탈북자는 누구인가?
#
# 튜브형 금속 조형물 축 진동의 고유 진동수 스펙트럼과 지진파 관측 결과가 일치하는 것을 발견했다고 설명한 기관은?
#
# 튜브형 금속 조형물 축 진동의 고유 진동수 스펙트럼과 지진파 관측 결과가 일치하는 것을 발견했다고 설명한 곳은?
#
# 잠수함이 잠수함과 충돌해 침몰했을 가능성을 제기한 사람은?
#
# 천안함 침몰 당시 백령도에서 관측된 지진파 주파수를 분석한 사람은?
#
# 튜브형 금속 조형물 축 진동의 고유 진동수 스펙트럼과 지진파 관측 결과가 일치하는 것을 발견했다고 설명한 기관은?
#
# 천안함 사건 당일 아침 해군 2함대가 전파한 군 문자정보망 교신 내역을 공개한 의원은?
#
# 민주당 신학용의원은 천안함 사건 당일 아침 해군 2함대가 전파한 군 문자정보망 교신내용을 어디에서 공개하였는가?
#
# 천안함 사건 당일 아침 해군 2함대가 전파한 군 문자정보망 교신 내역을 공개한 날짜는?
#
# 천안함 사건 당일 아침 해군 2함대가 전파한 군 문자정보망 교신 내역을 공개한 사람은?
#
# 천안함 사건 당일 아침 2함대가 전파한 군 문자정보망 교신 내역을 공개한 사람은?
#
# 서프라이즈 대표는 누구인가?
#
# 신상철을 추천한 민주당 의원은?
#
# 조사단의 구성원 문제나 은폐 가능성을 제기했던 사람은?
#
# 조사단의 구성원 문제나 은폐 가능성을 제기했던 인물은?
#
# 서프라이즈 대표의 이름은?
#
# 천안함 사건에 대해 문제를 제기해 논란을 일으켰던 사람들 중 상당수가 고소, 고발을 당한 이유는?
#
# 천안함 사태에 대해 문제를 제기해 논란을 일으켰던 사람들 중 상당수는 고소, 고발을 당한 사람들은?
#
# 천안함 사태 당시 천안함 조사위원 중 고소, 고발을 당한 대표적인 사람은?
#
# 천안함 사건에 대해 문제를 제기해 논란을 일으켰던 사람들 중 상당수가 고소, 고발을 당한 이유는?
#
# 천안함 침몰 사건에 대한 성금 모금이 진행된 날짜는?
#
# 천안함 침몰 사건에 대한 성금 모금이 진행된 날짜는?
#
# 천안함 침몰 사건에 대한 성금 모금이 진행된 날짜는?
#
# 천안함 침몰 사건에 대한 성금 모금이 진행된 년도는?
#
# 천안함 침몰 사건에 대한 성금 모금이 진행된 날짜는?
#
# 천안함 침몰 사건의 조사날짜를 원래 5월 23일로 하기로 한 것은 누구의 서거 1주기 때문이었나?
#
# 천안함 침몰 사건의 책임론을 주장한 당은?
#
# 천안함 침몰 사건에 대해 여야 정당들이 정 반대의 해석과 책임론을 주장하며 비판한 정부는?
#
# 2010년 6월 2일 있을 지방선거에서 우위를 점하기 위한 전략이라고 해석되는 단어는?
#
# 천안함 침몰 사건에 대해 한나라당과 자유선진당, 미래희망연대의 소속 정당은?
#
# 여론조사에서 정부의 발표를 믿는다고 답변한 비율은?
#
# 여론조사가 실시된 날짜는?
#
# 여론조사가 실시된 날짜는?
#
# 여론 조사에서 정부의 발표를 믿는다고 답변한 비율은 몇퍼센트인가?
#
# 여론조사에서 정부의 발표를 믿지 않는다고 답변한 비율은?
#
# 윤덕용 천안함 사건 민군 합동조사단장이 안보리 이사회에 참석한 날짜는?
#
# 윤덕용 천안함 사건 민.군 합동조사단장이 안보리 이사회에 참석한 날짜는?
#
# 윤덕용 천안함 사건 민.군 합동조사단장이 안보리 이사회에 참석한 날짜는?
#
# 윤덕용 천안함 사건 민군 합동조사단장이 안보리 이사회에 참석한 날짜는?
#
# 윤덕용 천안함 사건 민군 합동조사단장이 안보리 이사회에 참석한 것은 언제인가?
#
# 참여연대가 천안함 침몰 사건의 의문점을 담은 서한을 안전보장이사회와 이사국들에 보낸 날은?
#
# 2010년 6월 14일 참여연대가 의문점을 담은 서한을 안전보장이사회와 이사국들에 보낸 곳은 어디인가?
#
# 참여연대가 천안함 침몰 사건의 의문점을 담은 서한을 안전보장이사회와 이사국들에 보낸 날짜는?
#
# 2010년 6월 14일 참여연대가 의문점을 담은 서한을 안전보장이사회와 이사국들에 보낸 곳은?
#
# 참여연대가 안보리 결의 1540호를 제안한 년도는?
#
# 군의 대응실태를 조사한 감사원은 총 몇 명의 징계를 요청하였는가?
#
# 군의 대응실태를 조사한 감사원은 총 몇 명의 징계를 요청하였는가?
#
# 군의 대응실태를 조사한 감사원은 총 몇 명의 징계를 요청하였는가?
#
# 허위보고, 음주근무 등 초기 대응의 총체적 문제점으로 인해 총 몇 명의 징계를 요청하였나?
#
# 군의 대응실태를 조사한 감사원은 총 몇 명의 징계를 요청하였는가?
#
# 김현웅이 제56대 법무부 장관에 임용된 것은 몇 대 때의 일인가?
#
# 김현웅이 제26대 법무부 장관에 임용된 해는?
#
# 법무법인 재직 중 제56대 법무부 장관에 임용된 김현웅이 법무법인 재직 중 맡았던 직책은?
#
# 제46대 서울고등검찰청 검사장 재직 중 제64대 법무부 장관에 임용된 인물은?
#
# 법무법인 김현웅이 제56대 법무부 장관에 임용된 년도는?
#
# 제46대 서울고등검찰청 검사장 재직 중 제54대 법무부 장관에 임용된 사람은?
#
# 제46대 서울고등검찰청 검사장 재직 중 김현웅이 법무법인 재직 중 임용된 직책은?
#
# 크리스티나 애플게이트, 카마 칼라와 함께 현대적인 클럽 공연단을 구상한 년도는?
#
# 1997년 모건 힉비 나이트의 영화 제목은?
#
# 크리스티나 애플게이트, 카마 칼라와 함께 핑크의 Trouble의 뮤직비디오에 출연한 그룹은?
#
# 크리스티나 애플게이트, 카마 칼라와 함께 현대적인 클럽 공연단을 구상한 안무가는?
#
# 1997년 모건 힉비 나이트의 영화 제목은?
#
# 2003년, 오디션 프로그램 팝스타즈의 우승자로 구성된 그룹 에덴스 크러쉬의 전 멤버였던 니콜 셰르징거가 리드보컬로 영입된 그룹은?
#
# 에덴스 크러쉬의 전 멤버였던 니콜 셰르징거가 영입된 해는?
#
# 2003년 에덴스 크러쉬의 전 멤버였던 니콜 셰르징거가 리드보컬로 영입된 그룹은?
#
# 2003년 오디션 프로그램 팝스타즈의 우승자로 구성된 그룹 에덴스 크러쉬의 전 멤버였던 니콜 셰르징거가 리드보컬로 영입된 그룹은?
#
# 2003년, 오디션 프로그램 팝스타즈의 우승자로 구성된 그룹 에덴스 크러쉬의 전 멤버였던 니콜 셰르징거가 리드보컬로 영입된 그룹은?
#
# 2003년, 오디션 프로그램 팝스타즈의 우승자로 구성된 그룹 에덴스 크러쉬의 전 멤버였던 니콜 셰르징거가 영입된 그룹은?
#
# 푸시캣 돌스의 첫 번째 정규 음반의 타이틀 곡은?
#
# 푸시캣 돌스의 첫 번째 정규 음반은?
#
# 푸시캣 돌스의 첫 번째 정규 음반의 타이틀 곡은?
#
# 푸시캣 돌스의 첫 번째 정규 음반 이름은?
#
# 푸시캣 돌스의 첫 번째 정규 음반 이름은?
#
# 푸시캣 돌스의 첫 번째 정규 음반의 타이틀 곡은?
#
# Buttons는 후에 그래미 상의 최우수 팝 퍼포먼스 그룹상 후보에 올랐는데 이 중 몇 위인가?
#
# 미국의 래퍼 Snoop Dogg과 함께 작업한 싱글의 제목은?
#
# 미국의 래퍼 Snoop Dogg과 함께 작업한 네 번째 싱글 곡의 제목은?
#
# 미국의 래퍼 Snoop Dogg과 함께 작업한 네 번째 싱글의 제목은?
#
# 미국의 래퍼 Snoop Dogg과 함께 작업한 네 번째 싱글의 제목은?
#
# 미국의 래퍼 Snoop Dogg과 함께 작업한 네 번째 싱글은?
#
# Pussycat Dolls Present: The Search For the Next Doll의 새 앨범을 녹음하고 투어를 진행할 새 멤버는?
#
# Pussycat Dolls Present For the Next Doll의 새 앨범을 녹음하고 투어를 진행할 새 멤버는?
#
# 2007년 5월 6일 Saverio Principini의 음악과 함께 The CW에서 방영된 프로그램은?
#
# 2007년 3월 6일 Saverio Principini의 음악과 함께 방영된 프로그램의 이름은?
#
# 2007년 3월 6일 Saverio Principini의 음악과 함께 방영된 프로그램의 이름은?
#
# 2007년 Pussycat Dolls Present: The Search For the Next Doll의 우승자는?
#
# 2007년 Pussycat Dolls Present: The Search For the Next Doll의 우승자는?
#
# 2008년 5월 27일 발표된 싱글 When I Grow Up은 빌보드 핫 100 차트에서 몇 위를 차지했는가?
#
# 2007년 Pussycat Dolls Present: The Search For the Next Doll의 우승자는?
#
# 푸시캣 돌스의 새 싱글 When I Grow Up은 빌보드 핫 100 차트에서 몇 위를 차지했는가?
#
# 푸시캣 돌스가 발표한 싱글 When I Grow Up은 빌보드 핫 100 차트에서 몇 위를 하였는가?
#
# 2009년 6월 6일 서울 올림픽공원 사이클 경기장에서 열린 첫 내한공연의 게스트는?
#
# 2008년 7월 MTV 아시아 뮤직 어워드에서 오프닝 무대를 장식하여 아시아 무대에 처음으로 선보인 곡은?
#
# 2009년 6월 6일 서울 올림픽공원 사이클 경기장에서 열린 첫 내한공연의 이름은?
#
# 2009년 6월 6일 서울 올림픽공원 사이클 경기장에서 첫 내한공연을 가진 그룹은?
#
# 유럽과 오스트레일리아 공연에서 오프닝을 맡은 가수는?
#
# 2008년 7월 MTV 아시아 뮤직 어워드에서 오프닝 무대를 장식하여 아시아 무대에 처음으로 선보인 곡은?
#
# 영국에서 Doll Domination 2.0 앨범이 발매된 날짜는?
#
# 오스트레일리아에서 재발매된 Doll Domination 2.0 앨범의 제목은?
#
# 오스트레일리아에서는 Doll Domination 2.0 앨범을 언제 재발매했나?
#
# Doll Domination 2.0의 재발매반에는 몇 개의 싱글이 추가되었는가?
#
# 영국에서 Doll Domination 2.0 앨범이 발매된 날짜는?
#
# 킴벌리 와이어트가 그룹에서 쫒겨났다고 폭로한 인물은?
#
# 그룹 킴벌리 와이어트가 그룹을 떠난 사실을 폭로한 잡지는?
#
# 제시카 수타가 그룹 킴벌리 와이어트가 그룹을 떠난 사실을 폭로한 잡지는?
#
# 킴벌리 와이어트가 그룹에서 쫒겨났다고 폭로한 그룹은?
#
# 2010년 1월 29일 킴벌리 와이어트가 그룹에서 쫒겨났다고 폭로한 그룹은?
#
# Entertainment Weekly의 마고 왓슨이 비난한 리드보컬은?
#
# Entertainment Weekly의 마고 왓슨이 지나치게 부각을 강하게 비판한 리드보컬은?
#
# 마고 왓슨이 리드보컬 니콜 셰르징거에 대한 지나친 부각을 비판한 사람은?
#
# 마고 왓슨이 리드보컬 니콜 셰르징거에 대한 지나친 부각을 비판하고 나선 해는?
#
# 마고 왓슨이 리드보컬 니콜 셰르징거에 대한 지나친 부각을 비판한 해는?
#
# ESP가 시부야 히사타케가 설립한 가게의 이름은?
#
# ESP가 시부야 히사타케가 설립한 가게의 이름은?
#
# ESP가 미국 뉴욕에 리페어 샵을 설립한 해는?
#
# ESP가 미국 뉴욕에 리페어 샵을 설립한 년도는?
#
# ESP가 시부야 히사타케가 설립한 가게의 이름은?
#
# ESP가 미국 뉴욕에 리페어 샵을 설립한 것은 언제인가?
#
# ESP가 미국 뉴욕에 설립한 것은?
#
# ESP가 시부야 히사타케가 설립한 가게의 이름은?
#
# 커크 해밋이 ESP에서 자신의 기타를 주문제작한 년도는?
#
# Metallica의 정식 엔도서로 활동중인 것은?
#
# 시그네처 기타가 가장 많은 브랜드로 유명하며, ESP에서 기타를 수리하기 위해 ESP 샵을 방문하여 주문제작한 기타는?
#
# 시그네처 기타가 가장 많은 브랜드로 꼽히는 것은?
#
# 시그네처 기타가 가장 많은 브랜드로 꼽히는 것은?
#
# 시그네처 기타가 가장 많은 브랜드로 유명한 것은?
#
# 시그네처 기타가 가장 많은 브랜드로 알려진 것은?
#
# ESP의 시그네처 기타는 누구의 시그네처 기타인가?
#
# Standard Series는 몇년도에 단종되었는가?
#
# Standard Series가 단종된 해는?
#
# Standard Series의 수제작 공정과 30%의 자동화 공정을 통해서 만들어졌으며, 미국과 유럽등에서 주로 팔린 수출형 ESP 모델은?
#
# Standard Series가 단종된 년도는?
#
# 미국과 유럽등에서 주로 팔린 수출형 ESP 모델의 이름은?
#
# Standard Series가 단종된 년도는?
#
# Standard Series가 단종된 년도는?
#
# Standard Series가 단종된 년도는?
#
# 승리의 본명은?
#
# 승리의 본명은?
#
# 승리의 본명은?
#
# 승리가 출연한 리얼리티 서바이벌 오디션 프로그램은?
#
# 승리의 본명은?
#
# 승리의 본명은?
#
# 승리의 본명은?
#
# 승리가 합격한 서바이벌 프로그램은?
#
# 승리의 본명은?
#
# 빅뱅의 첫 번째 정규 음반 제목은?
#
# 빅뱅의 첫 번째 정규 음반 제목은?
#
# 빅뱅의 첫 솔로 곡은?
#
# 빅뱅의 첫 번째 정규 음반의 타이틀 곡 제목은?
#
# 빅뱅의 첫 번째 정규 음반 제목은?
#
# 빅뱅의 첫 솔로 곡 제목은?
#
# 빅뱅의 첫 번째 정규 음반 제목은?
#
# 빅뱅이 첫 솔로 곡을 부른 곡의 제목은?
#
# 빅뱅의 첫 솔로 곡은?
#
# 승리가 뮤지컬에 처음으로 도전한 작품은?
#
# 승리가 뮤지컬에 처음으로 도전한 작품은?
#
# 승리가 대성과 함께 진행을 맡은 MBC 음악 프로그램은?
#
# 승리가 뮤지컬에 처음 도전한 작품은?
#
# 승리가 뮤지컬에 첫 도전한 작품은?
#
# 승리가 뮤지컬에 처음 도전한 작품은?
#
# 승리의 영화 데뷔작인 우리 집에 왜 왔니에서 함께 호흡을 맞춘 그룹은?
#
# 승리가 뮤지컬에 처음으로 도전한 작품은?
#
# 승리가 뮤지컬에 처음 도전한 작품은?
#
# 승리가 2012년 7월 쯤부터 출연하기 시작한 일본 버라이어티 방송의 이름은?
#
# 승리가 2012년 7월 쯤부터 일본 버라이어티 방송에 출연하기 시작한 시기는?
#
# 2012년 7월 승리가 출연한 일본 버라이어티 방송의 이름은?
#
# 2012년 승리가 출연한 NTV 60주년 스페셜 드라마의 제목은?
#
# 승리가 2012년 7월 쯤부터 출연하기 시작한 일본 버라이어티 방송의 이름은?
#
# 승리가 2012년 7월 쯤부터 출연하기 시작한 일본 버라이어티 방송의 이름은?
#
# 승리가 2012년 7월 쯤부터 출연하기 시작한 일본 버라이어티 방송의 이름은?
#
# 승리가 2012년 7월 쯤부터 출연하기 시작한 일본 버라이어티 방송의 이름은?
#
# 승리의 두 번째 EP 음반 Let's Talk About Love가 발매된 날짜는?
#
# 승리의 두 번째 EP 음반은 언제 발매되었는가?
#
# 승리의 두 번째 EP 음반은 언제 발매한다고 발표되었는가?
#
# 2013년 승리가 일본 지상파 방송 진행을 맡은 프로그램의 이름은?
#
# 2013년 승리의 첫 번째 EP 음반의 제목은?
#
# 승리의 첫 번째 일본어 음반은?
#
# 승리의 첫 번째 일본어 음반은?
#
# 종합편성채널에 법적 근거를 부여하는 방송법 개정안이 한나라당의 단독 강행 처리로 국회를 통과한 해는?
#
# 종합편성채널에 법적 근거를 부여하기 위해 한나라당의 단독 강행 처리로 국회를 통과한 방송법 개정안은 언제 통과되었나?
#
# 2010년 11월 30일 종합편성채널의 신청서 접수가 시작되었을 때 중앙일보 측은 어떤 이름으로 신청을 시도하려 하였는가?
#
# 종합편성채널에 법적 근거를 부여하는 방송법 개정안이 국회를 통과한 해는?
#
# 2010년 11월 30일 종합편성채널의 신청서 접수가 시작되었을 때 중앙일보 측은 어떤 이름으로 신청서를 제출하였는가?
#
# 2010년 11월 30일 종합편성채널 신청서 접수가 시작되었을 때 중앙일보 측은 어떤 이름으로 신청서를 제출하였는가?
#
# 종합편성채널에 법적 근거를 부여하는 방송법 개정안이 여당인 한나라당의 단독 강행 처리로 국회를 통과한 해는?
#
# 2012년 방송 신뢰도가 지상파채널인 MBC와 SBS를 추월한 방송사는?
#
# 2012년 지상파를 제치고 지상파 포함 3위를 기록한 방송사는?
#
# 2012년 기준 방송통신위원회 전체회의에서 의결된 방송평가에서 지상파 포함 3위를 차지한 방송사는?
#
# 방송통신위원회 전체회의에서 의결된 2012년도 방송평가에서 지상파 포함 3위를 차지한 방송사는?
#
# 2012년에 지상파채널과 보도전문편성 사업자들 중 가장 높은 순위를 기록한 방송국은 어디인가?
#
# 2012년에 지상파채널인 MBC와 SBS를 제치고 지상파 3위를 기록한 방송사는?
#
# 모션 그래픽스가 electronic media기술로 표출되기도 하고 수동적인 기술로 표출되기도 하는 것은?
#
# 모션 그래픽스란 개념은 무엇에 따라 형상이 변화하는 그래픽을 구분하는데 유용한가?
#
# 모션 그래픽스는 어떤 프로젝트에 사용되기 위해 음향과 결합되기도 하는가?
#
# 모션 그래픽스가 수동적인 기술로 표출되기도 하며 어떤 기술로 표현되기도 하는가?
#
# 모션 그래픽스가 일반적으로 어떤 기술로 표출되기도 하는가?
#
# 모션 그래픽스는 어떤 프로젝트에 사용되기 위해 음향과 결합되기도 하는가?
#
# 모션 그래픽스란 개념은 무엇에 따라 형상이 변화하는 그래픽을 구분하는데 유용한가?
#
# 카일쿠퍼가 담당한 영화 세븐의 오프닝 타이틀은?
#
# 카일쿠퍼가 담당한 영화 세븐의 오프닝 그래픽스 디자이너의 이름은?
#
# 카일쿠퍼가 담당한 영화 세븐의 오프닝 타이틀은 지금까지도 기념비적인 타이틀로 회자되고 있는데, 이 영화의 오프닝 시퀀스 디자이너는 누구인가?
#
# 영화의 오프닝 시퀀스를 담당한 모션 그래픽스 디자이너의 이름은?
#
# 카일쿠퍼가 담당한 영화의 오프닝 시퀀스 디자이너의 이름은?
#
# 영화의 오프닝 시퀀스를 담당한 모션 그래픽스 디자이너의 이름은?
#
# 카일쿠 감독의 영화 세븐의 오프닝 시퀀스 디자이너는 누구인가?
#
# 카일쿠퍼가 담당한 영화 세븐의 오프닝 그래픽스 디자이너는?
#
# 최근 영상 제작의 트렌드 중 시각적 즐거움과 카타르시스를 느끼게 해주는 것은?
#
# 최근 영상 디자인의 트렌드가 되고 있는 것은?
#
# 최근 영상 제작의 트렌드는?
#
# TV에 국한되었던 매체가 점점 넓어지고 재생기기도 다양해 지는 시기는?
#
# 중세에서 계몽주의 시대까지 모든 종류의 체계적이거나 정확하게 기록된 지식을 가리키는 단어는?
#
# 중세로부터 계몽주의 시대까지 모든 종류의 체계적이거나 정확하게 기록된 지식을 가리켰던 영어단어는?
#
# 중세로부터 계몽주의 시대까지 모든 종류의 체계적이거나 정확하게 기록된 지식을 가리키는 단어는?
#
# 중세로부터 계몽주의 시대까지 모든 종류의 체계적이거나 정확하게 기록된 지식을 가리켰던 단어는?
#
# 중세에서 계몽주의 시대까지 모든 종류의 체계적이거나 정확하게 기록된 지식을 가리키는 영어 단어는?
#
# 중세로부터 계몽주의 시대까지, science나 scientia는 모든 종류의 체계적이거나 정확하게 기록한 지식을 무엇이라 하는가?
#
# 이집트의 알렉산드리아 도서관이 위치한 도시는?
#
# 아이작 아시모프가 쓴 책의 이름은?
#
# 최초의 대규모 과학 연구소는 어디인가?
#
# 최초로 약을 조제한 이집트 성직자는 누구인가?
#
# 최초의 대규모 과학 연구소로 불리는 곳은?
#
# 최초로 대규모 과학 연구소로 불리는 곳은?
#
# 최초의 대규모 과학 연구소가 있는 나라는?
#
# 세계에서 가장 세련되고 성능이 좋은 감마선 망원경 일부를 이용한 공공서비스 국립대학교는?
#
# 국제적으로 가장 세련되고 성능이 좋은 감마선 망원경 일부를 이용해, 헝가리 부다페스트의 공공서비스 국립대학교의 어느곳을 이용하였는가?
#
# 세계에서 가장 세련되고 성능이 좋은 감마선 망원경은?
#
# 세계에서 가장 세련되고 성능이 좋은 감마선 망원경은?
#
# 우주에서 가장 큰 규모의 계층적 구조의 증거가 초은하단과 필라멘트 규모에서 발견된 것은 언제인가?
#
# 우주에서 가장 큰 규모의 계층적 구조의 증거가 초은하단과 어디에서 보였는가?
#
# 우주에서 가장 큰 규모의 계층적 구조의 증거가 초은하단과 어디에서 보였는가?
#
# 우주의 겉보기 평균 밀도는 균질성 규모가 그보다 약 4배 큰 몇년임을 시사하는가?
#
# 우주에서 가장 큰 규모의 계층적 구조의 증거가 초은하단과 필라멘트 규모에서 나타난 때는?
#
# 100억년 전 또는 빅뱅 거의 38억년 후의 구조를 우리가 보고 있음을 의미하는 것으로 주목해야 할 것은?
#
# 구조가 100억 년 전 또는 빅뱅 거의 38억 년 후의 구조를 우리가 보고 있음을 의미하는 것은?
#
# 암흑물질이 어떠한 물질을 끌어당겨 거대한 구조를 형성했다는 뜻인가?
#
# 암흑물질이 바리온 물질을 끌어당겨 거대한 구조를 형성했다는 뜻의 구조는?
#
# 나경원이 국회의원과 장애아동 부모 및 전문가 등이 의견을 나누는 연구모임으로 만든 것은?
#
# 딸이 다운증후군을 앓는다는 이유로 차별을 당한 경험을 살려 만든 연구모임은?
#
# 나경원이 장애아동 부모 등이 의견을 나누는 연구모임의 이름은?
#
# 나경원의 딸이 다운증후군을 앓는다는 이유로 차별을 당했던 경험을 살려 만든 연구모임의 이름은?
#
# 나경원이 국회의원과 장애아동 부모 및 전문가 등이 의견을 나누는 연구모임의 이름은?
#
# 정보통신망 이용촉진 및 정보보호 등에 관한 법률 일부개정법률안을 대표 발의한 사람은?
#
# 정보통신망 이용촉진 및 정보보호 등에 관한 법률 일부개정법률안을 대표발의한 사람은?
#
# 정보통신망 이용촉진 및 정보보호 등에 관한 법률 일부개정법률안을 대표 발의한 사람은?
#
# 정보통신망 이용촉진 및 정보보호 등에 관한 법률 일부개정법률안을 대표발의한 사람은?
#
# 정보통신망 이용촉진 및 정보보호 등에 관한 법률 일부개정법률안을 대표발의한 국회의원은?
#
# 정보통신망 이용촉진 및 정보보호 등에 관한 법률 일부개정법률안을 대표 발의한 사람은?
#
# 정보통신망 이용촉진 및 정보보호 등에 관한 법률 일부개정법률안을 대표 발의한 사람은?
#
# 나경원이 정보통신망 이용촉진 및 정보보호 등에 관한 법률 일부개정법률안을 대표발의한 날짜는?
#
# 국제스페셜올림픽위원회 전략기획수석인 사람은?
#
# 올림픽 개최 사상 처음으로 지적장애인들의 권리 보호를 위한 국제 정상회담이 열린 것은?
#
# 평창 스페셜올림픽의 성공과 홍보를 위해 열린 걷기대회는 어느 일대에서 진행되었는가?
#
# 평창 스페셜올림픽이 개최된 기간은?
#
# 평창 스페셜올림픽의 성공과 홍보를 위해 걷기대회와 전광판 제막 행사를 개최한 곳은 어디인가?
#
# 국제스페셜올림픽위원회 전략기획수석 수석은 누구인가?
#
# 평창 스페셜올림픽이 열린 년도는?
#
# 국제스페셜올림픽위원회 전략기획수석인 인물은?
#
# 나경원이 북한 인권 문제를 감시하고 관련 정보를 수집하기 위해 건립한 것은?
#
# 나경원이 외통위원장으로 선출된 해는?
#
# 나경원이 유엔 북한인권사무소의 개소식에 참석한 년도는?
#
# 나경원이 북한인권 문제를 감시하고 관련 정보를 수집하는 '유엔 북한인권사무소'가 건립된 년도는?
#
# 나경원이 유엔(UN) 북한인권 결의안을 최초로 제출한 년도는?
#
# 나경원이 유엔 북한인권사무소 개소식에 참석한 년도는?
#
# 나경원이 유엔 북한인권사무소 개소식에 참석한 년도는?
#
# 한국정신대문제대책협의회 대표는 누구인가?
#
# 2004년 주한 일본대사관이 자위대 창립 50돌 기념 행사를 연 장소는?
#
# 한국정신대문제대책협의회 대표는 누구인가?
#
# 2004년 주한 일본대사관이 자위대 창립 50주년 기념 행사를 연 장소는?
#
# 한국정신대문제대책협의회 대표는 누구인가?
#
# 2004년 주한 일본대사관이 자위대 창립 50돌 기념 행사를 열었을 때 나경원이 참석한 행사는?
#
# 2004년 주한 일본대사관이 자위대 창립 50주년 기념 행사를 열었을 때 나경원이 참석한 행사는?
#
# 나경원이 목욕봉사를 들어갈 때에는 취재진에게 들어오지 말아달라고 한 것은?
#
# 나경원이 목욕봉사를 들어갈 때에는 취재진에게 들어오지 말아달라고 한 것은?
#
# 나경원이 알몸 목욕장면을 촬영할 때 몇 세 아동의 알몸 목욕장면이 노출되었는가?
#
# 나경원이 목욕봉사를 들어갈 때에는 취재진에게 들어오지 말아달라고 요청한 곳은 어디인가?
#
# 나경원이 목욕봉사를 할 때 몇 세 아동의 알몸 목욕장면이 노출되었는가?
#
# 나경원이 목욕봉사를 들어갈 때에는 취재진에게 들어오지 말아달라고 요청한 곳은 어디인가?
#
# 10.26 서울시장 보궐선거에 나선 나경원 후보는 트위터에서 스스로를 지지하는 어떤 글을 올렸는가?
#
# 나경원 트위터 계정 연동 오류에 대해 트위터 본사에 문의한 내용을 어디에 게시하였는가?
#
# 10.26 서울시장 보궐선거에 나선 나경원 후보의 트위터 계정 연동 오류에 대해 트위터 본사에 문의한 내용을 게시한 내용을 어디에 게시하였는가?
#
# 나경원이 트위터에서 자화자찬하는 글을 올린 날짜는?
#
# 10.26 서울시장 보궐선거에 나선 한나라당 나경원 후보는 트위터에서 스스로를 지지하는 어떤 글을 올렸는가?
#
# 2008년 6월 13일 나경원을 허위사실로 고소하고 손해배상청구소송을 제기한 사람은 누구인가?
#
# 나경원은 누구를 사랑하는 사람들의 모임에 속해있었는가?
#
# 2008년 6월 13일 박근혜 지지모임인 박사모 회장 정광용을 고소한 사람은 누구인가?
#
# 2009년 10월 30일 서울중앙지법은 누구의 고소 취하로 정광용을 석방하였는가?
#
# 2009년 10월 27일 정광용을 모욕한 혐의 등으로 구속된 사람은 누구인가?
#
# 2009년 10월 27일 정광용 회장 명의의 사과문을 게재한 곳은 어디인가?
#
# 정광용이 나경원을 모욕한 혐의 등으로 구속된 해는?
#
# 2008년 6월 당시 나경원은 누구를 모욕한 혐의로 구속되었는가?
#
# 나경원이 후원금을 어디에 냈다는 얘긴 들은 적이 없다고 말하였는가?
#
# 불법 후원금 수수 의혹에 대해 나경원이 인터뷰를 가진 방송사는 어디인가?
#
# 나경원의 부친은 누구인가?
#
# 나경원의 부친은 누구인가?
#
# 나경원이 초선 의원이던 시절 이사로 있던 학교에 불법 정치후원금을 준 교사는 누구인가?
#
# 나경원이 이사로 있던 학교의 이름은?
#
# 나경원의 부친은 누구인가?
#
# 교사의 정치자금 기부를 금지하는 규정은 몇 년도 제정된 이래 바뀐 적이 없었다고 밝혔나?
#
# 교사의 정치자금 기부를 금지하는 규정이 제정된 해는?
#
# 교사의 정치자금 기부를 금지하는 규정이 제정된 해는?
#
# 교사의 정치자금 기부를 금지하는 규정은 언제 제정된 이래 바뀐 적이 없었고 따라서 교사의 정치자금 기부가 합법이었던 적은 없었다고 밝혔나?
#
# 2004년 당시 흥신학원 교사들이 나경원 의원에게 낸 정치후원금의 출처는?
#
# 교사의 정치자금 기부를 금지하는 규정이 제정된 해는?
#
# 교사의 정치자금 기부를 금지하는 규정이 제정된 해는?
#
# 2018년 2월 19일 기준 청와대 대변인은?
#
# 2018년 2월 19일 청와대 국민청원에는 몇 명이 동참하였는가?
#
# 2018년 2월 19일 기준 나경원의 소속 정당은?
#
# 2018년 2월 19일 기준 청와대 답변 기준은?
#
# 평창 동계올림픽 조직위원으로 활동하던 나경원이 서한을 보내 논란을 빚은 곳은 어디인가?
#
# 2018년 2월 19일 청와대 국민청원에는 몇명이 동참하였는가?
#
# 2018년 2월 19일 기준 청와대 직원 수는?
#
# 나경원 의원의 비서 박창훈씨가 페이스북에서 한 중학생과의 전화 통화에서 막말과 협박을 해 논란이 일었던 년도는?
#
# 나경원 의원의 비서인 박창훈씨가 페이스북에서 논쟁을 벌이던 중학생과의 전화 통화에서 막말과 협박을 해 논란이 일었던 해는?
#
# 나경원 의원의 비서 박창훈씨가 막말과 협박을 한 중학생과의 전화 통화 녹음 파일이 공개된 날짜는?
#
# 박창훈씨가 페이스북에서 논쟁을 벌이던 중학생과의 전화 통화에서 막말과 협박을 해 논란을 일으킨 해는?
#
# 나경원 자유한국당 의원 비서인 박창훈씨가 페이스북에서 논쟁을 벌인 중학생과의 전화 통화에서 막말과 협박을 해 논란이 일었던 년도는?
#
# 박창훈씨가 페이스북에서 논쟁을 벌인 중학생과의 전화 통화에서 막말과 협박을 해 논란이 일었던 년도는?
#
# 박창훈씨가 페이스북에서 논쟁을 벌인 중학생과의 전화 통화에서 막말과 협박을 한 날짜는?
#
# 화폐와 화폐의 역사를 과학적으로 연구하는 다양한 분야의 학문을 일컫는 말은?
#
# 화폐와 화폐의 역사를 연구하는 다양한 분야의 학문을 일컫는 말은?
#
# 신성로마제국의 황제인 막시밀리안과 페르디난트 1세, 프랑스의 절대군주인 앙리 4세 등이 속했던 학문은?
#
# 동전 수집가로 유명한 대표적인 인물은?
#
# 동전을 기계로 주조한 시기는 언제인가?
#
# 동전을 기계로 주조한 시기는 언제인가?
#
# 국가 원수격인 군주 또는 총독이 대신을 임명하는 기준은?
#
# 국가 원수격인 군주 또는 총독은 누가 임명되는가?
#
# 군주가 자기들의 결정과 부처의 실적을 의회 의원들에게 보고할 때 반드시 있어야 하는 것은?
#
# 군주가 오직 책임감 있는 대신들을 통해서 수행해야 하는 것은?
#
# 국가 원수격인 군주 또는 총독의 직책은?
#
# 미국 독립 혁명의 영향으로 영국계 인구와 사회적 불안에 민감했던 나라는?
#
# 미국 독립 혁명의 영향으로 영국계 인구 큰 잔여 식민지를 불안에 떨친 나라는?
#
# 루이-조셉 파피노가 이끌었던 로어 캐나다 반란과 1837년에서 1838년까지 윌리엄 라이언 매켄지가 이끌었던 어퍼 캐나다 반란은?
#
# 캐나다 의회의 개혁파들이 반란손해조례를 통과한 해는?
#
# 캐나다 의회의 개혁파들이 반란손해조례를 통과하는 일을 시험삼아 실시한 해는?
#
# 1849년 의회의 개혁파들이 반란손해조례를 통과하는 일을 시험삼아 실시했던 것은?
#
# 1849년 캐나다 성에서 의회의 개혁파들이 반란손해조례를 통과하는 일을 시험삼아 실시한 것은?
#
# 캐나다 의회의 개혁파들이 반란손해조례를 통과하는 일을 시험삼아 실시한 해는?
#
# 웨스턴오스트레일리아 식민지도 1890년에 이와 비슷하게 확립한 식민지는?
#
# 웨스턴오스트레일리아 식민지와 뉴질랜드를 제외한 모든 오스트레일리아 대륙의 식민지들이 확립한 체제는?
#
# 웨스턴오스트레일리아 식민지도 1890년에 이와 비슷하게 확립한 식민지는?
#
# 웨스턴오스트레일리아 식민지와 뉴질랜드를 제외한 모든 대륙의 식민지가 확립한 것은?
#
# 영국식 웨스트민스터 체제를 이해하는데 도움을 주었던 정부는?
#
# 1991년 1월 5일 김봉환은 무엇으로 인해 사망하였는가?
#
# 김봉환이 이황화탄소 중독판정을 받고 산재요양신청을 낸 년도는?
#
# 김봉환이 이황화탄소 중독판정을 받고 산재요양신청을 낸 년도는?
#
# 김봉환이 이황화탄소 중독판정을 받고 회사에 산재요양신청을 낸 년도는?
#
# 1991년 1월 5일 김봉환은 무엇으로 인해 사망에 이르게 되었는가?
#
# 이황화탄소 중독 판정을 받고 산재요양신청을 낸 사람은?
#
# 1991년 1월 5일 김봉환이 사망한 이유는?
#
# 1991년 1월 5일 사망한 김봉환의 직업병 증세는?
#
# 김봉환이 이황화탄소 중독판정을 받고 회사에 산재요양신청을 낸 년도는?
#
# 1988년 7월 23일 원진레이온 직업병 피해자 가족 협의회를 결성한 사람은?
#
# 원진레이온 직업병 피해자 가족 협의회를 결성한 년도는?
#
# 원진레이온 직업병 피해자 가족 협의회를 결성한 해는?
#
# 구리노동상담소가 원진레이온 직업병 피해자 가족 협의회를 결성한 해는?
#
# ...
#
# 명성황후 암살 작전이 결행된 날짜는?
#
# 명성황후 암살 작전이 결행된 날짜는?
#
# 명성황후 암살 작전이 결행된 날짜는?
#
# 명성황후 암살 작전이 결행된 날짜는?
#
# 명성황후의 직위는?
#
# 명성황후의 직위는 고종의 무엇으로 올라갔는가?
#
# 명성왕후의 직위는 무엇으로 올라갔는가?
#
# 명성황후의 능호는 무엇으로 개칭되었는가?
#
# 명성왕후의 능호는?
#
# 백범 김구를 일본 낭인으로 오인하여 치하포에서 죽인 인물은?
#
# 백범 김구를 일본 낭인으로 오인하며 치하포에서 만나 그를 죽인 인물은?
#
# 명성황후의 암살 배후로 지목된 일본 공사는?
#
# 야마가타 아리토모 육군대장과 무쓰 무네미쓰 외상 사이의 편지에서 일본 정부의 개입설을 제기한 인물은?
#
# 명성황후의 암살 배후로 지목된 일본 공사는?
#
# 윤치호가 명성황후를 살해한 범인이라고 지목한 인물은?
#
# 윤치호가 명성황후를 살해한 범인이라고 지목한 인물은?
#
# 윤치호가 명성황후를 살해한 범인이라고 지목한 인물은?
#
# 윤치호가 명성황후를 살해한 범인으로 지목한 인물은?
#
# 윤치호가 명성황후를 살해한 범인으로 지목한 인물은?
#
# 명성황후와 척족세력은 전통과 서양 문명을 절충하려는 어떤 정책 노선을 띠었는가?
#
# 명성황후와 척족세력은 전통과 서양 문명을 절충하려는 어떤 정책 노선을 띠었는가?
#
# 명성황후와 척족세력은 전통과 서양 문명을 절충하려는 어떤 정책 노선을 띠었는가?
#
# 명성황후와 척족세력은 전통과 서양 문명을 절충하려는 어떤 정책 노선을 띠었는가?
#
# 명성황후와 척족 세력은 전통과 서양 문명을 절충하려는 어떤 정책 노선인가?
#
# 왕비의 머리 색은?
#
# 왕비의 피부색은?
#
# 삼성 갤럭시 노트7의 전반적인 디자인은?
#
# 갤럭시 노트7의 전반적인 디자인은?
#
# 갤럭시 노트7의 전반적인 디자인은?
#
# 삼성 갤럭시 노트7의 전반적인 디자인은?
#
# 갤럭시 노트7의 색상은?
#
# 갤럭시 노트7의 전반적인 디자인은?
#
# 삼성 엑시노스 9 Series와 퀄컴 스냅드래곤 835 MSM8998은 어느 모델인가?
#
# 삼성 갤럭시 노트7의 AP 모델명은?
#
# 삼성 엑시노스 9 Series와 퀄컴 스냅드래곤 835 MSM8998을 주로 사용하는 모델은?
#
# 삼성 엑시노스 9 Series와 퀄컴 스냅드래곤 835 MSM8998을 탑재한 모델은?
#
# 삼성 갤럭시 노트7의 내장 메모리는 몇 GB인가?
#
# 삼성 엑시노스 9 Series는 어떤 규격인가?
#
# 삼성 갤럭시 노트7의 내장 메모리는 몇 GB인가?
#
# 삼성 갤럭시 노트7의 내장 메모리는 몇 GB인가?
#
# 삼성 갤럭시 노트7에 처음으로 적용된 AMOLED 디스플레이 기술은?
#
# 삼성 갤럭시 노트7에 처음으로 적용된 AMOLED 디스플레이 기술은?
#
# 삼성 갤럭시 노트7에 처음으로 적용된 AMOLED 디스플레이 기술은?
#
# 삼성 갤럭시 노트7에 처음으로 적용된 AMOLED 디스플레이 기술은?
#
# 삼성 갤럭시 노트7의 인터넷 사용 시간은 갤럭시 노트7에 비해 얼마나 줄었는가?
#
# 삼성 갤럭시 노트7의 인터넷 사용 시간은?
#
# 삼성 갤럭시 노트7의 인터넷 사용 시간은 갤럭시 노트7보다 얼마나 줄었는가?
#
# 삼성 갤럭시 노트7의 배터리 용량은?
#
# 삼성 갤럭시 노트7이 갤럭시S7보다 인터넷 사용시간이 얼마나 줄었나?
#
# 삼성 갤럭시 노트7의 배터리 용량은?
#
# 삼성 갤럭시 노트7의 후면 카메라의 밝기는?
#
# 삼성 갤럭시 노트7의 전면 카메라의 밝기는?
#
# 삼성 갤럭시 노트7의 전면 카메라의 밝기는?
#
# 삼성 갤럭시 노트7의 후면 카메라의 밝기는?
#
# 삼성 갤럭시 노트7의 전면 카메라의 밝기는?
#
# 삼성 갤럭시 노트7의 후면 카메라의 조리개 밝기는?
#
# 엘리자베스 룬드 홈에서 태어난 것은 누구인가?
#
# 아버지가 세일즈맨이자 공군 예비역인 로이드 마셜이라고 기술되어 있는 것은?
#
# 아버지가 세일즈맨이자 공군 예비역이었던 로이드 마셜이라고 되어 있는 것은?
#
# 아버지가 세일즈맨이자 공군 예비역인 로이드 마셜이라고 되어 있는 사람은 누구인가?
#
# 아버지가 세일즈맨이자 공군 예비역인 로이드 마셜이라고 되어 있는 사람은?
#
# 아버지가 세일즈맨이자 공군 예비역인 로이드 마셜이라고 되어 있는 사람은?
#
# 테드 번디의 출생증명서에서 아버지가 세일즈맨이자 공군 예비역이라고 되어 있는 것은?
#
# 아버지가 세일즈맨이자 공군 예비역인 로이드 마셜이라고 되어 있는 사람은?
#
# 번디의 어머니는 누구인가?
#
# 번디가 3살때까지 살았던 외조부모의 직업은?
#
# 번디가 3살때까지 살았던 외조부모의 직업은?
#
# 번디를 개인적으로 알고 있던 자서전작가의 이름은?
#
# 번디의 어머니는 누구인가?
#
# 번디의 어머니의 직업은?
#
# 번디가 3살때까지 살았던 곳은?
#
# 변호인단에게 압제적으로 약자를 괴롭히는 사람이며 흑인, 이탈리아 출신자, 카톨릭 교도, 유대인을 혐오하는 편견이 심했다고 말한 사람은?
#
# 변호인단에게 압제적으로 약자를 괴롭히는 사람이며 흑인, 이탈리아 출신자, 카톨릭 교도, 유대인을 혐오하는 편견이 심했다고 말한 사람은?
#
# 변호인단에게 사뮤엘 코웰은 누구를 혐오하는 편견이 심한 사람이라고 말했는가?
#
# 번디의 외조부가 루이지의 여동생인 줄리아를 밀치기도 한 시간은?
#
# 번디와 다른 가족들이 변호인단에게 혐오하는 사람이며 흑인, 이탈리아 출신자, 카톨릭 교도, 유대인을 혐오하는 편견이였다고 말한 사람은 누구인가?
#
# 변호인단에게 압제적으로 약자를 괴롭히는 사람이며 흑인, 이탈리아 출신의자, 카톨릭 교도, 유대인을 혐오하는 편견이 심하다고 말한 사람은 누구인가?
#
# 변호인단에게 사뮤엘 코웰은 압제적으로 약자를 괴롭힌 사람이며 흑인과 이탈리아 출신자, 카톨릭 교도, 유대인을 혐오하는 편견이 심한 사람이었다고 말한 사람은?
#
# 변호인단에게 사뮤엘 코웰은 압제적으로 약자를 괴롭히는 사람이라고 말한 사람은 누구인가?
#
# 변호인단에게 사뮤엘 코웰은 압제적으로 약자를 괴롭히는 사람이며 흑인, 이탈리아 출신의자, 카톨릭 교도, 카톨릭 교도, 유대인을 혐오하는 편견이 심한 사람이었다고 말한 사람은?
#
# 조니 컬페퍼 번디가 테드를 입양한 후 입양한 자식의 숫자는?
#
# 조니 컬페퍼 번디가 입양한 테드의 숫자는?
#
# 조니 컬페퍼 번디가 테드를 입양한 곳은?
#
# 조니 컬페퍼 번디가 테드를 입양한 해는?
#
# 조니 번디가 입양한 테드의 자식은 몇 명인가?
#
# 1950년 루이지는 자신의 성을 무엇으로 바꾸었는가?
#
# 조니 컬페퍼 번디가 입양한 테드의 자식은 몇 명인가?
#
# 조니 번디가 테드를 입양한 장소는?
#
# 조니 컬페퍼 번디가 테드를 입양한 장소는?
#
# 번디와 애인스워스와 대화했을 때, 여자 나체 사진을 찾기 위해 쓰레기 통을 찔러보면서 이웃집들을 돌아다닌 사람은?
#
# 번디가 미쇼와 애인스워스와 대화 중 탐정잡지, 특히 사체나 불구가 된 사진이 있는 실제 범죄 다큐멘터리를 탐독했다고 말한 사람은?
#
# 번디와 애인스워스와 대화에서 여자 나체사진을 찾기 위해 쓰레기 통을 찔러보면서 이웃집을 돌아다닌 인물은?
#
# 번디와 미쇼와의 대화에서 여자 나체 사진을 찾기 위해 쓰레기 통을 찔러보면서 돌아다닌 곳은?
#
# 번디가 미쇼와 애인스워스와 대화 중 탐정잡지나 범죄소설 그리고 사체나 불구가 된 사진이 있는 실제적인 범죄 다큐멘터리를 탐독했다고 말한 사람은?
#
# 미쇼와의 대화에서 번디가 밤늦게까지 돌아다닌 곳은?
#
# 번디가 미쇼와 애인스워스와 대화 중 탐정잡지와 범죄소설 그리고 특히 사체나 불구가 된 사진이 있는 실제 범죄 다큐멘터리를 탐독했다고 말한 사람은?
#
# 존 번디가 타코마 시절에 대해 서로 다른 회상을 한 사람은?
#
# 번디에게 술과 함께 여자 나체 사진을 찾기 위해 쓰레기 통을 찔러보라며 이웃집들을 돌아다닌 사람은?
#
# 넬슨 록펠러의 대선 캠페인을 위해 시애틀 사무소에서 자원해서 일한 사람은?
#
# 넬슨 록펠러의 대선 캠페인을 위한 시애틀 사무소에서 번디가 자원해서 일했던 직책은?
#
# 1968년 초기에 번디가 학교를 그만두고 직업들을 전전한 직업은?
#
# 넬슨 록펠러의 대선 캠페인에 자원해 일했던 사람은?
#
# 존 번디가 고등학교를 졸업한 해는?
#
# 넬슨 록펠러의 대선 캠페인을 위한 시애틀 사무소에서 번디가 자원해서 일했던 직책은?
#
# 넬슨 록펠러의 대선 캠페인을 위해 시애틀 사무소에서 자원해서 일한 사람은?
#
# 넬슨 록펠러의 대선 캠페인을 위한 시애틀 사무소에서 번디가 자원해서 일한 직책은?
#
# 존 번디가 고등학교를 졸업한 해는?
#
# 앤 룰이 번디의 전기들 중 최고인 내 옆의 이방인을 쓴 작가의 이름은?
#
# 번디와 엘리자베스 클로퍼의 관계는 언제까지 지속되었는가?
#
# 1969년 가을에 번디가 위싱턴주로 돌아와 만난 사람은?
#
# 존 번디와 엘리자베스 클로퍼의 이혼녀는 누구인가?
#
# 존 번디가 워싱턴 대학교에 다시 등록한 년도는?
#
# 존 번디가 워싱턴 대학교에 다시 등록한 때는?
#
# 존 번디가 워싱턴 대학교에 재학한 전공은?
#
# 존 번디가 워싱턴 대학교에 다시 등록한 것은 언제인가?
#
# 존 번디와 엘리자베스 클로퍼의 관계는 언제까지 지속되었는가?
#
# 1972년 로스쿨 재선 캠페인에 합류한 사람은?
#
# 에반스가 재선에 성공한 뒤 누구에게 사무보조원으로 고용되었는가?
#
# 에반스가 재선에 성공한 후 번디가 사무보조원으로 고용된 사람은?
#
# 에반스가 재선에 성공한 후 번디가 사무보조원으로 고용된 사람은?
#
# 에반스가 재선에 성공한 후 번디가 사무보조원으로 고용된 사람은?
#
# 1972년 로스쿨 입학허가를 받은 로스쿨 출신 대학교는?
#
# 에반스가 재선에 성공한 뒤 번디가 사무보조원으로 고용된 사람은?
#
# 1972년 로스쿨 재선 캠페인에 합류한 주지사 이름은?
#
# 로스쿨 입학 시험 성적에도 불구하고 로스쿨 입학허가를 받은 로스쿨은?
#
# 번디가 캘리포니아행 공화당 출장기간에 다시 전개한 것은?
#
# 번디와 함께 시애틀로 간 번디가 결혼에 대해 의논한 사람은?
#
# 1974년 1월 번디와 전화통화에 성공한 브룩스의 상대는?
#
# 번디와 데이비스의 약혼녀가 된 사람은?
#
# 번디와 결혼에 대해 의논한 번디에게 데이비스에게 자신의 약혼녀라고 소개한 사람은?
#
# 1973년 브룩스가 로스쿨에서 데이트를 한 상대는?
#
# 번디와 결혼에 대해 의논한 번디가 데비스에게 자신을 자신의 약혼녀라고 소개한 사람은?
#
# 번디와 결혼에 대해 의논한 사람은?
#
# 번디와 함께 결혼에 대해 의논한 사람은?
#
# 번디가 넬슨에게 처음 납치를 시도한 뉴저지주 오션 시티의 도시는?
#
# 번디가 뉴저지주 오션 시티에서 납치를 시도한 년도는?
#
# 번디가 살해범으로 지목한 터코마의 앤 마리 버르의 나이는?
#
# 번디가 넬슨에게 납치를 시도한 곳은?
#
# 번디가 넬슨에게 처음 납치를 시도한 년도는?
#
# 번디가 넬슨에게 처음으로 납치를 시도한 뉴저지주 오션 시티의 도시는?
#
# 넬슨에게 처음으로 납치를 시도한 년도는?
#
# 1969년 뉴저지주 오션 시티에서 처음 납치를 시도한 사람은?
#
# 번디가 최초로 여성들을 살해하기 시작한 나이는?
#
# 시애틀에서 남동쪽으로 60마일 떨어진 에버그린 주립 대학의 19살 도나 게일 맨슨이 재즈 콘서트장으로 향한 시기는?
#
# 시애틀 남동쪽으로 60마일 떨어진 올림피아 소재 에버그린 주립 대학의 19살 도나 게일 맨슨이 재즈 콘서트장으로 향한 시기는?
#
# 시애틀에서 남동쪽으로 60 마일 떨어진 에버그린 주립 대학은?
#
# 시애틀에서 남동쪽으로 60마일 떨어진 에버그린 주립 대학의 19살 도나 게일 맨슨이 다닌 노래는?
#
# 시애틀에서 남동쪽으로 60마일 떨어진 에버그린 주립 대학의 학생 이름은?
#
# 시애틀에서 남동쪽으로 60마일 떨어진 에버그린 주립 대학의 19살 도나 게일 맨슨은 어디로 향했는가?
#
# 시애틀에서 남동쪽으로 60마일 떨어진 에버그린 주립 대학의 19살 도나 게일 맨슨이 간 곳은?
#
# 시애틀에서 남동쪽으로 60마일 떨어진 에버그린 주립 대학의 19살 도나 게일 맨슨이 다닌 노래는?
#
# 브렌다 캐롤 볼이 시애틀-터고마 국제 공항인근 버리엔에 있는 플레임 여관을 떠난 나이는?
#
# 브렌다 캐롤 볼이 시애틀-터고마 국제 공항인근 버리엔에 있는 플레임 여관을 떠난 날은?
#
# 브렌다 캐롤 볼이 시애틀-터고마 국제 공항인근 버리엔에 있는 플레임 여관을 떠난 나이는?
#
# 브렌다 캐롤 볼이 시애틀-터고마 국제 공항인근 버리엔에 있는 플레임 여관을 떠난 나이는?
#
# 브렌다 캐롤 볼이 시애틀-터고마 국제 공항인근 버리엔에 있는 플레임 여관에서 사라진 나이는?
#
# 브렌다 캐롤 볼이 시애틀-터고마 국제 공항인근 버리엔에 있는 플레임 여관에서 사라진 나이는?
#
# 브렌다 캐롤볼이 플레임 여관을 떠난 나이는?
#
# 스팍스의 끔찍한 폭행 사건에 관한 기사들이 뉴욕과 오리건 전역에 보도된 매체는?
#
# 깁스나 팔걸이 붕대를 하고 갈색 또는 탄색 폭스바겐 비틀 차량을 모는 남자의 직업은?
#
# 스팍스의 끔찍한 폭행 사건에 관한 기사들이 워싱턴주와 오리건 전역에 보도된 곳은?
#
# 대부분의 범죄현장에서 깁스나 팔걸이 붕대를 하고 갈색 혹은 탄색 폭스바겐 비틀 차량을 모는 남자가 목격된 곳은?
#
# 스팍스의 끔찍한 폭행 사건에 관한 기사들이 워싱턴주와 오리건 전역에 신문과 텔레비전으로 보도된 시기는?
#
# 스팍스의 끔찍한 폭행 사건에 관한 기사들이 워싱턴주와 오리건 전역에 신문과 텔레비전으로 보도된 곳은?
#
# 스팍스의 끔찍한 폭행 사건에 관한 기사들이 워싱턴주와 오리건 전역에 신문과 텔레비전으로 보도된 곳은?
#
# 스팍스의 끔찍한 폭행 사건에 관한 기사들이 뉴욕과 오리건 전역에 보도된 매체는?
#
# 중간고사나 기말고사를 앞둔 일 주일 이내의 시기에 모든 피해자가 입은 옷은?
#
# 시애틀 동쪽 20마일 떨어진 레이크 새머미시 주립 공원에서 2명의 여성 유괴사건이 일어난 날짜는?
#
# 시애틀 동쪽 20 마일 떨어진 이사쿠아 소재 레이크 새머미시 주립 공원에서 2명의 여성 유괴 사건이 일어난 날짜는?
#
# 시애틀 동쪽 20마일 떨어진 레이크 새머미시 주립 공원에서 2명의 여성 유괴사건이 일어난 날짜는?
#
# 시애틀 동쪽 20마일 떨어진 이사쿠아 소재 레이크 새머미시 주립 공원에서 2명의 여성 유괴 사건이 일어난 날짜는?
#
# 시애틀 동쪽 20마일 떨어진 레이크 새머미시 주립 공원에서 2명의 여성 유괴사건이 일어난 날짜는?
#
# 시애틀 동쪽 20마일 떨어진 레이크 새머미시 주립 공원에서 2명의 여성 유괴사건이 일어난 날짜는?
#
# 시애틀 동쪽 20마일 떨어진 이사쿠아 소재 레이크 새머미시 주립 공원에서 2명의 여성 유괴사건이 일어난 날짜는?
#
# 시애틀 동쪽 20마일 떨어진 레이크 새머미시 주립 공원에서 2명의 여성 유괴사건이 일어난 공원은?
#
# 제니스 앤 오트에게 접근하는 남자가 보호관찰관에서 일하는 23살의 남자에게 접근하는 것을 본 사람은?
#
# 테드가 낸시 윌콕스를 납치하여 나무가 우거진 곳으로 끌고가서 병적인 충동을 충족하기 위해 강간한 나이는?
#
# 테드가 낸시 윌콕스를 납치하여 나무가 우거진 곳으로 끌고가 병적인 충동을 충족시키기 위해 강간한 날짜는?
#
# 낸시의 유해가 묻힌 곳은?
#
# 테드가 16살 나이의 낸시 윌콕스를 납치하여 나무가 우거진 곳으로 끌고가서 병적인 충동을 충족시키기 위해 강간한 날짜는?
#
# 테드가 16살 나이의 낸시 윌콕스를 납치하여 나무가 우거진 곳으로 끌고가 병적인 충동을 충족시키기 위해 강간한 날짜는?
#
# 테드가 16살 나이의 낸시 윌콕스를 납치하여 나무가 우거진 곳으로 끌고가서 병적인 충동을 충족하기 위해 강간한 날짜는?
#
# 달이 지나자 새로운 일련의 살인이 시작되었는데 그 중 16살 나이의 낸시 윌콕스를 납치해 나무가 우거진 곳으로 끌고가 병적인 충동을 충족시키기 위한 목적으로 강간한 후 놓아준 이는?
#
# 10월 2일 테드가 낸시 윌콕스를 납치하여 나무가 우거진 곳으로 끌고가 병적인 충동을 충족시키기 위한 목적으로 강간한 후 놓아준 사람은?
#
# 윤정훈이 졸업한 대학교는?
#
# 윤정훈이 졸업한 대학교는?
#
# 윤정훈은 어느대학교 신학과 학사인가?
#
# 윤정훈이 졸업한 대학교는?
#
# 윤정훈이 졸업한 대학교는?
#
# 윤정훈이 졸업한 대학교는?
#
# 윤정훈이 졸업한 대학교는?
#
# 새누리당과 박근혜의 연관성을 부인한 사람은?
#
# 새마음포럼이라는 이름이 붙은 파일철이 발견된 곳은 어디인가?
#
# 새마음포럼이라는 이름이 붙은 파일철이 발견된 곳은 어디인가?
#
# 새마음포럼이라는 이름이 붙은 파일철이 발견된 곳은 어디인가?
#
# 새마음포럼이라는 제목이 붙은 파일철이 발견된 곳은 어디인가?
#
# 새누리당과 박근혜의 연관성을 부인한 인물은?
#
# 박근혜가 2012년 9월 17일 30명을 동원하여 3백만명에게 노출하여 여론 형성을 해간다는 내용의 보고가 올라온 회의 이름은?
#
# 제나가 발견한 열과 다시증 증상은?
#
# 제나가 발견한 열과 다시증 증상은?
#
# 제나 기즈가 발견한 열과 다시증의 증상은?
#
# 자신의 고향 위스콘신 근처의 교회에 가다가 박쥐를 잡았던 인물은?
#
# 자신의 고향 위스콘신 근처의 교회에 가다가 박쥐를 잡았던 미국의 성모 마리아 스프링스 고등학교의 학생은?
#
# 제나 기즈는 자신의 고향 위스콘신 근처의 교회에 가다가 누구를 잡았는가?
#
# 제나 기즈에 의해 광견병 감염이 확인된 미국 CDC의 검사는?
#
# 제나를 인위적인 혼수상태에 빠뜨리기 위해 투여한 것은?
#
# 제나를 인위적인 혼수상태에 빠뜨리기 위해 투여한 것은?
#
# 제나가 혼수상태에 빠져 있는 동안 체내의 면역 체계가 생성시킬 수 있는 항체는?
#
# 제나를 인위적인 혼수상태에 빠뜨리기 위해 투여한 것은?
#
# 제나가 혼수상태에 빠져있는 동안 체내의 면역 체계가 항체를 스스로 생성시킬 수 있을 만큼 오래 생존해주길 기대한 것은?
#
# 제나가 혼수상태에 빠져 있는 동안 체내의 면역체계가 스스로 생성시킬 수 있을 만큼 오래 생존해주길 기대한 것은?
#
# 제나가 처음 자동차 운전을 시작한 것은 언제인가?
#
# 제나가 광견병 바이러스가 사라졌다고 공식적으로 인정받은 날은?
#
# 제나가 퇴원한 해는?
#
# 제나가 퇴원한 해는?
#
# 삼성 갤럭시 노트7의 기본 색상은?
#
# 삼성 갤럭시 노트7의 기본 색상은?
#
# 삼성 갤럭시 노트7의 기본 색상은 몇종인가?
#
# 삼성 갤럭시 노트7의 기본 색상은?
#
# 삼성 갤럭시 노트7의 기본 색상은?
#
# 삼성 갤럭시 노트7의 전반적인 디자인은?
#
# 삼성 갤럭시 노트7의 삼성 갤럭시 노트7에 탑재된 AP 사양은?
#
# 삼성 갤럭시 노트7의 기본 색상은?
#
# 카를 13세가 폐위한 해는?
#
# 제4차 대프랑스 동맹에 가입해 틸지트 조약으로 러시아 편으로 돌아선 나라는?
#
# 제4차 대프랑스 동맹에 가입해 틸지트 조약으로 러시아가 프랑스 편으로 돌아선 다음에도 계속 동맹을 고수하던 나라는?
#
# 제4차 대프랑스 동맹에 가입해 틸지트 조약으로 러시아 편으로 돌아선 나라는?
#
# 제4차 대프랑스 동맹에 가입한 스웨덴의 왕은?
#
# 제4차 대프랑스 동맹에 가입해 틸지트 조약으로 러시아가 프랑스 편으로 돌아선 해는?
#
# 제4차 대프랑스 동맹에 가입해 틸지트 조약으로 러시아가 프랑스 편으로 돌아선 후에도 계속 동맹을 고수하던 나라는?
#
# 알렉산드르 1세가 데 톨리에게 총지휘권을 넘겨준 후 이동한 곳은?
#
# 1812년 6월 24일, 프랑스군이 네만 강을 넘어 러시아 원정을 시작한 날짜는?
#
# 바그르 1세가 데 톨리에게 총지휘권을 넘겨주고 모스크바를 경유해 상트페테르부르크로 이동한 곳은?
#
# 바그레이 데 톨리가 지휘하는 러시아의 제 1 서부군의 대군 수는?
#
# 바클레이 데 톨리가 지휘하는 러시아의 제 1 서부군은 10만여 이상의 대군이었으나 나폴레옹군에 비해 어느 정도 열세였는가?
#
# 알렉산드르 1세가 데 톨리에게 총지휘권을 넘겨주고 모스크바를 경유해 이동한 곳은?
#
# 1812년 6월 24일 바클레이 데 톨리가 지휘하는 러시아의 제 1 서부군의 대군은?
#
# 한여름의 무더움과 강행군으로 인한 인마의 손실이 유난히 높았던 것은?
#
# 한여름의 무더움과 강행군으로 인한 인마의 손실이 유난히 높았던 시기는?
#
# 한여름의 무더움과 강행군으로 인한 인마의 손실이 유난히 높았던 계절은?
#
# 원정 초반 10만에 달하던 원정군 기병을 와해할 정도로 큰 전투 없이도 원정군 기병을 와해한 것은?
#
# 말먹이 풀의 부족은 원정 초반 거의 10만에 달하던 원정군 기병을 와해할 정도로 큰 전투 없이도 원정 초반에 달했던 무엇을 와해할 정도였나?
#
# 말먹이 풀의 부족으로 원정 초반 거의 10만에 달하던 원정군 기병을 와해할 정도로 유난히 높았던 것은?
#
# 한여름의 무더움과 강행군으로 인한 인마의 손실이 유난히 높았던 시기는?
#
# 마힐루 전투에서 바그라티온의 러시아군과 바그라티온의 러시아군 사이에 전투가 벌어진 날짜는?
#
# 마힐루 전투에서 러시아군과 바그라티온의 러시아군 사이에 전투가 벌어져 바그라티온의 군대가 패하고 비텝스크로 가는 길이 막혔는데 이 군대는?
#
# 마힐루 전투에서 러시아군과 바그라티온의 러시아군 사이에 전투가 벌어진 날짜는?
#
# 마힐루 전투에서 바그라티온의 러시아군과 바그라티온의 러시아군 사이에 전투가 벌어진 날짜는?
#
# 마힐루 전투에서 바그라티온의 군대와 바그라티온의 러시아군 사이에 전투가 벌어진 날짜는?
#
# 마힐루에서 다부가 이끄는 프랑스군과 바그라티온의 러시아군 사이에 전투가 벌어진 날짜는?
#
# 데 톨리가 지휘하던 4만여 병력으로 러시아군을 추격해 다음 날 데 톨리가 지휘하던 4만여 명의 러시아군 후위대와 발루티노 전투를 치른 인물은?
#
# 나폴레옹군이 러시아군 본대와 승부를 가리기로 마음 먹은 인물은?
#
# 러시아군 본대와 승부를 가리기로 마음 먹은 인물은?
#
# 스몰렌스크 공격을 최전선에서 지휘하던 네 원수는 얼마의 병력으로 러시아군을 추격했는가?
#
# 스몰렌스크 공격을 최전선에서 지휘하던 네 원수는 4만여 명의 병력으로 러시아군을 추격해 다음 날 누구와 발루티노 전투를 하였는가?
#
# 러시아군 본대와 승부를 가리기로 마음 먹은 인물은?
#
# 나폴레옹이 러시아군 본대와 승부를 가리기로 마음 먹은 인물은?
#
# 모스크바로 가는 길 부근에서 뒤따라온 나폴레옹군과 격전을 벌인 전투는?
#
# 러시아군이 모스크바로 가는 길 부근에서 뒤따라온 나폴레옹군과 격전을 벌인 전투는?
#
# 러시아군이 모스크바로 가는 길 부근에서 뒤따라온 나폴레옹군과 격전을 벌인 전투는?
#
# 러시아군이 모스크바로 가는 길 부근에서 뒤따라온 나폴레옹군과 격전을 벌인 전투는?
#
# 러시아군이 모스크바로 가는 길 부근에서 나폴레옹군과 격전을 벌인 전투는?
#
# 러시아군이 모스크바로 가는 길 부근에서 나폴레옹군과 격전을 벌인 전투는?
#
# 러시아군이 모스크바로 가는 길 부근에서 나폴레옹군과 격전을 벌인 전투는?
#
# 알렉산드르 1세가 협상을 위해 협상을 제안한 인물은?
#
# 알렉산드르 1세가 쿠투조프에게 교섭을 금지시킨 것은 언제인가?
#
# 알렉산드르 1세가 협상을 청해오기를 기다린 인물은?
#
# 나폴레옹이 협상을 청해오기를 기다린 알렉산드르 1세가 협상을 제안한 인물은?
#
# 알렉산드르 1세가 알렉산드르 1세에게 교섭을 금지시킨 것은 언제인가?
#
# 알렉산드르 1세가 협상을 청해오기를 기다린 곳은?
#
# 알렉산드르 1세가 협상을 청해오기를 기다린 나폴레옹이 협상을 제안한 사람은?
#
# 코자크 기병대가 수송대와 전령을 습격하는 일이 잦아지고 보급이 불확실해지자 나폴레옹이 철군을 결정한 곳은?
#
# 코자크 기병대가 수송대와 전령을 습격하는 일이 잦아지고 이해가 불확실해지자 나폴레옹이 철군을 결정한 곳은?
#
# 코자크 기병대가 수송대와 전령을 습격하는 일이 잦아지고 날이 갈수록 불확실해지자, 결국 철군을 결정한 인물은?
#
# 코자크 기병대가 수송대와 전령을 습격하는 일이 잦아지고 보급이 불확실해지자 나폴레옹은 어디로 철군을 결정하였는가?
#
# 코자크 기병대가 수송대와 전령을 습격하는 일이 잦아지고 날이 갈수록 불확실해지자 나폴레옹이 결정한 것은?
#
# 나폴레옹이 모스크바를 떠난 날짜는?
#
# 코자크 기병대가 수송대와 전령을 습격하는 일이 잦아지고 무엇이 불확실해지자, 나폴레옹이 철군을 결정하였나?
#
# 나폴레옹이 스몰렌스크 전투에서 예비 병력으로 남겨두었던 빅토르 페랭 원수의 군대와 합류하기 위해 진격한 방향은?
#
# 나폴레옹이 스몰렌스크 전투에서 예비 병력으로 남겨두었던 빅토르 페랭 원수의 군대는 어디로 진격하였는가?
#
# 나폴레옹이 스몰렌스크 근방을 떠나 군대를 남쪽으로 인솔해 자신과 합류할 것을 명령한 사람은?
#
# 11월 초 러시아 군대가 다부의 후위대를 가로막고 전투를 벌인 장군은?
#
# 11월 초에 나폴레옹이 예비 병력으로 남겨두었던 빅토르 페랭 원수의 군대와 합류하기 위해 진격한 방향은?
#
# 11월 초에 나폴레옹은 누구의 지휘 하에 따라 전투를 벌였는가?
#
# 11월 초, 나폴레옹이 지휘한 러시아 군대가 다부의 후위대를 가로막고 전투를 벌인 곳은 어디인가?
#
# 골리친의 군대가 반격으로 나가 우월한 포병과 기병을 앞세워 공격한 군대는?
#
# 나폴레옹과 정면 승부를 피하고 전진하지 않는 쪽을 선택한 사람은 누구인가?
#
# 나폴레옹과 정면 승부를 피하고자 한 인물은?
#
# 나폴레옹은 누구에게 오르샤로 통하는 서북쪽 길을 열어두는 역할을 맡겼는가?
#
# 나폴레옹은 누구의 명령으로 크라스니 마을을 공격했는가?
#
# 토르마소프, 토르마소프, 동쪽의 밀루라도비치의 군대와 협력해 포위할 계획을 세운 인물은?
#
# 나폴레옹의 근위대가 크로라스니 마을로 들어간 것을 방치한 인물은?
#
# 치챠고프와 비트겐슈타인이 이끄는 군대가 원정군의 후퇴를 저지하기 위해 이끌고 온 군대는?
#
# 나폴레옹이 빅토르 페랭과 우디노의 남은 3만여 정규군과 재결합해 약 5만명의 병력과 그 절반 가량의 낙오병, 비전투원들을 움직이게 된 강은?
#
# 나폴레옹이 빅토르 페랭과 우디노의 군대와 재결합한 곳은 어디인가?
#
# 바리사우에서 베레지나 강을 건너려고 한 인물은?
#
# 원정군이 바리사우보다 하류에 위치한 지점을 골라 도강할 것이라고 오판해 주력을 이끌고 남쪽으로 내려갔던 인물은?
#
# 나폴레옹이 동브로프스키의 연대를 보낸 곳은 어디인가?
#
# 치챠고프가 바리사우보다 하류에 위치한 지점을 골라 도강할 것이라고 오판해 주력을 남쪽으로 내려갔는데 이 지점을 무엇이라 하는가?
#
# 치챠고프가 바리사우보다 하류에 위치한 지점을 골라 도강할 것이라고 오판해 주력을 이끌고 내려간 곳은?
#
# 치챠고프가 바리사우보다 하류에 위치한 지점을 골라 도강할 것이라고 오판해 주력을 이끌고 내려간 곳은?
#
# 바리사우보다 하류에 위치한 지점을 골라 도강할 것이라고 오판한 원정군은?
#
# 12월 14일 네만 강 서쪽에 도착한 뮈라의 보고에 따르면 네만 강 서쪽에 도착한 날짜는?
#
# 12월 14일 네만 강 서쪽에 도착한 나폴레옹의 보고에 따르면 몇명만이 싸울 수 있었는가?
#
# 11월 말에 남은 정규군을 이끌고 베레지나 강을 건너 에움을 벗어나는 데 성공한 인물은?
#
# 나폴레옹이 12월 초 시달린 생존자들과 함께 도착한 곳은?
#
# 12월 14일 네만 강 서쪽에 도착한 뮈라의 보고에 따르면 네만 강 서쪽에 도착한 뮈라의 보고에 따르면 몇명만이 싸울 수 있었는가?
#
# 12월 14일 네만 강 서쪽에 도착한 뮈라의 보고에 따르면 얼마만이 싸울 수 있었는가?
#
# 나폴레옹이 바르샤바 공국 다음으로 대군을 이끌고 러시아, 프로이센군에 대항한 나라는?
#
# 나폴레옹이 프랑스에서 수십만의 신병을 징집하고 엘베 강을 방어선으로 선택한 인물은?
#
# 함부르크에 수만 병력을 주둔시켜 다부가 지휘하게 한 인물은?
#
# 라인 동맹의 해체와 18세기 말까지의 오스트리아의 세력권은?
#
# 고다이고 천황이 퇴각한 이후 나라현의 요시노에 남조를 수립한 인물은?
#
# 고다이고 천황이 퇴각한 후 나라현의 요시노에서 수립한 것은?
#
# 고다이고 천황이 퇴각한 이후 남조를 수립한 곳은?
#
# 고다이고 천황이 퇴각한 후 남조를 수립한 곳은?
#
# 고다이고 천황이 퇴각한 후 나라현의 요시노에 수립한 조정의 이름은?
#
# 고다이고 천황이 퇴각한 후 남조를 수립한 곳은?
#
# 고다이고 천황이 퇴각한 이후, 나라현의 요시노에서 남조를 수립한 천황은?
#
# 고다이고 천황이 퇴각한 후 남조를 수립한 곳은?
#
# 고다이고 천황이 퇴각한 후 남조를 수립한 곳은?
#
# 고다이고 천황의 군대를 격파하고 황도에 입성해 무로마치 막부를 세운 인물은?
#
# 고다이고 천황의 군대를 격파한 아시카가 다카우지가 황도에 입성해 세운 막부는?
#
# 고다이고 천황의 군대를 격파하고 황도에 입성해 무로마치 막부를 세운 인물은?
#
# 1336년 고다이고 천황의 군대를 격파하고 황도에 입성해 무로마치 막부를 수립한 인물은?
#
# 1336년 고다이고 천황의 군대를 격파하고 황도에 입성해 무로마치 막부를 수립한 인물은?
#
# 고다이고 천황이 삼종신기를 가지고 교토를 탈출한 사람은?
#
# 고코곤 천황이 다시 교토를 탈출한 날짜는?
#
# 고코곤 천황이 남조의 반격으로 다시 교토를 탈출한 날짜는?
#
# 고코곤 천황이 다시 교토를 수복한 해는?
#
# 고코곤 천황이 북조에 건네준 삼종신기는 위조품이라고 선언한 인물은?
#
# 고다이고 천황은 삼종신기를 누구에게 건네주었는가?
#
# 일본의 황실에서는 남북조의 천황들 모두에 대한 제사를 지내는가?
#
# 일본의 황실에서는 남북조의 천황들 모두에 대한 제사를 지내고 있는 것은?
#
# 일본의 황실에서는 남북조의 천황들 모두에 대한 제사를 지내는 것은?
#
# 일본의 황실에서는 남북조의 천황들 모두에 대한 제사를 지내고 있다. 이것은 무엇인가?
#
# 일본의 황실에서는 남북조의 천황들 모두에 대한 제사를 지내는것을 무엇이라고 하는가?
#
# 일본 황실에서는 남북조의 천황들 모두에 대한 제사를 지내고 있는 것은?
#
# 일본의 황실에서는 남북조의 천황 모두에 대한 제사를 지내는 것은?
#
# 사람의 실체는 원래 신이었기 때문에 현재의 사람이 원래의 실체로 돌아가면, 즉 신이 되면 죽지 않는 무엇의 영생체가 되는가?
#
# 영생교에서 사람의 실체는 원래 신이었기 때문에 현재의 사람이 원래의 실체로 돌아가면, 즉 무엇이 되면 죽지 않는 무엇의 영생체가 되는가?
#
# 기독교 등 다른 종교가 사후 또는 사후 극락의 교리를 갖는 것과 달리 영생교는 어떠한 교리를 표방하고 있는가?
#
# 영생교는 기독교 등 다른 종교가 어떤 교리를 갖는 것과 달리 살아 영생을 표방하고 있는가?
#
# 영생교에서 사람의 실체는 원래신이었기 때문에 현재의 사람이 원래의 실체로 돌아가면 무엇이 되는가?
#
# 사람의 실체는 원래 신이었기 때문에 현재의 사람이 원래의 실체로 돌아가면 무엇이 되는가?
#
# 영생교에서 사람의 실체는 원래신이었기 때문에 현재의 사람이 원래의 실체로 돌아가면, 즉 신이 되면 죽지 않는 무엇의 영생체가 된다고 하는가?
#
# 교주 조희성과 처단조 행동대장 나경옥에게 사형이 선고된 해는?
#
# 수원지방법원이 나경옥에게 선고한 형벌은?
#
# 교주 조희성과 처단조 행동대장 나경옥에게 사형이 선고된 년도는?
#
# 교주 조희성과 처단조 행동대원의 이름은?
#
# 교주 조희성과 처단조 행동대장 나경옥에게 사형이 선고된 년도는?
#
# 교주 조희성과 처단조 행동대장 나경옥에게 사형이 선고된 해는?
#
# 수원지방법원은 언제 조희성과 처단조 행동대장 나경옥에게 사형을 선고했나?
#
# 수원지방법원은 언제 교주 조희성과 처단조 행동대장 나경옥에게 사형을 선고했나?
#
# 삼성 엑시노스 88의 통신 모뎀 솔루션을 내장한 최초의 모바일 AP는?
#
# 삼성 갤럭시 노트7의 통신 모뎀 솔루션이 모바일 AP에 내장된 스마트폰 모델은?
#
# 삼성 엑시노스 88의 통신 모뎀 솔루션을 내장한 스마트폰 모델은?
#
# 삼성 엑시노스 88의 통신 모뎀 솔루션을 내장한 최초의 모바일 AP는?
#
# 삼성 엑시노스 88을 통신 모뎀 솔루션을 내장한 최초의 모바일 AP는?
#
# 삼성 엑시노스 88의 통신 모뎀 솔루션을 내장한 스마트폰 모델은?
#
# 삼성 갤럭시 노트7의 통신 모뎀 솔루션이 모바일 AP에 내장된 스마트폰 모델은?
#
# 갤럭시 노트7의 내장형 용량은?
#
# 삼성 갤럭시 노트7의 내장형 용량은?
#
# 삼성 갤럭시 노트7의 내장형 용량은?
#
# 삼성 갤럭시 노트7의 내장형 용량은?
#
# 삼성 갤럭시 노트7의 내장형 용량은?
#
# 삼성 갤럭시 노트7의 내장형 용량은?
#
# 삼성 갤럭시 노트7의 출력량을 절반으로 줄인 사건의 이름은?
#
# 갤럭시 노트7의 내장형 용량은?
#
# 삼성 갤럭시 노트7의 후면 카메라의 화소는?
#
# 삼성 갤럭시 노트7의 후면 카메라의 밝기는?
#
# 삼성 갤럭시 노트7의 전면 카메라의 화소는?
#
# 삼성 갤럭시 노트7의 전면 카메라의 화소는?
#
# 삼성 갤럭시 노트7의 후면 카메라 모듈에 탑재된 기술은?
#
# 삼성 갤럭시 노트7의 후면 카메라의 화소는?
#
# 삼성 갤럭시 노트7의 후면 카메라의 화소는?
#
# 삼성 갤럭시 노트7의 후면 카메라의 화소는?
#
# 삼성 기어 VR과의 호환성을 보완하기 위해 삼성 기어 VR과의 호환성 문제를 가지고 있는 모델은?
#
# 삼성 갤럭시 노트7의 기존 규격은?
#
# 삼성 갤럭시 노트7에 탑재되었다가 방수 방진 등급으로나 방수 등급으로나 최고레벨을 받은 모델은?
#
# 삼성 갤럭시 노트7에 탑재되었다가 방수 방진을 다시 지원한 모델은?
#
# 삼성 갤럭시 노트7의 방수 등급은?
#
# 삼성 기어 VR과의 호환성 문제로 아직 캡리스 방수 솔루션이 준비되지 않은 모델은?
#
# 삼성 갤럭시 노트7의 방수 등급 등급은?
#
# 삼성 갤럭시 노트7의 모델명은?
#
# 삼성 갤럭시 노트7의 폭발 사고는 무엇과 관련이 있다고 추측되고 있는가?
#
# 삼성 갤럭시 노트7 폭발 사건과 관련이 있다고 추측되는 갤럭시 노트7의 모델명은?
#
# 2016년 삼성 갤럭시 노트7 엣지가 폭발하는 사건이 일어난 도시는?
#
# 삼성 갤럭시 노트7 엣지가 폭발하는 사건이 일어난 년도는?
#
# 삼성 갤럭시 노트7의 모델명은?
#
# 삼성 갤럭시 노트7 엣지가 폭발하는 사건이 일어난 년도는?
# 100%|██████████| 5774/5774 [00:02<00:00, 2501.51it/s]
# bleu1:  14.471179482680984
# bleu2:  10.184096950121232
# bleu3:  7.191299425874609
# bleu4:  4.979940999307239

# %% [markdown]
# # Testing original model

# %%
import torch
import KoBart
import dataset
from torch.utils.data import DataLoader
from tqdm import tqdm

from transformers import BartForConditionalGeneration
from transformers import PreTrainedTokenizerFast

# device
#device = 'cuda' if torch.cuda.is_available() else 'cpu'

device = 'cuda'

# Data file path
#'/content/drive/MyDrive/school/CS NLP/'
dev_path = '/home/josh/Desktop/school/data/dev.tsv'

# config
batch_size = 16

# model, tokenizer init
model_directory = 'Sehong/kobart-QuestionGeneration'
model = BartForConditionalGeneration.from_pretrained(model_directory)
tokenizer = PreTrainedTokenizerFast.from_pretrained('Sehong/kobart-QuestionGeneration')

model = model.to(device)

# dataset
dev_dataset = dataset.KoBARTQGDataset(dev_path, tokenizer)
dev_dataloader = DataLoader(dev_dataset, batch_size)

#output_path = './output/.txt'

with open('/home/josh/Desktop/school/outputs/base-Kobart.txt', 'w', encoding='utf-8') as f:
    for step_index, batch_data in tqdm( enumerate(dev_dataloader), f"[GENERATE]", total=len(dev_dataloader)):

        input_ids, decoder_input_ids, labels = tuple(value.to(device) for value in batch_data.values())

        output = model.generate(input_ids=input_ids, eos_token_id=tokenizer.eos_token_id, max_length=100, num_beams=5)

        for o in output:
            output = tokenizer.decode(o, skip_special_tokens=True)
            f.write(output+'\n')
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# [GENERATE]: 100%|██████████| 361/361 [02:04<00:00,  2.90it/s]

# %%
test_data_path = '/home/josh/Desktop/school/data/dev.tsv' # .tsv
output_path = '/home/josh/Desktop/school/outputs/base-Kobart.txt' # .txt

from tqdm import tqdm
#df = pd.read_csv(test_data_path, encoding='cp949', sep='\t')
df = pd.read_csv(test_data_path, encoding='utf-8', sep='\t')
question = list(df['question'])

generated_question = []


with open(output_path, 'r', encoding='utf-8') as f:
    for line in f.readlines():
        print(line)
        generated_question.append(line)

# save info
pd.DataFrame(generated_question, question)

len_question = len(question)

score_list_1 = np.zeros(len_question)
score_list_2 = np.zeros(len_question)
score_list_3 = np.zeros(len_question)
score_list_4 = np.zeros(len_question)

for i in tqdm(range(len_question)):
    
    matrix = dialogue_evaluation([generated_question[i]], [question[i]])
    score_list_1[i] = matrix['bleu1']
    score_list_2[i] = matrix['bleu2']
    score_list_3[i] = matrix['bleu3']
    score_list_4[i] = matrix['bleu4']
    

#score_list = np.array(score_list)
print('bleu1: ', np.mean(score_list_1))
print('bleu2: ', np.mean(score_list_2))
print('bleu3: ', np.mean(score_list_3))
print('bleu4: ', np.mean(score_list_4))
# Out:
# 임종석이 지명수배된 날짜는?
#
# 임종석이 지명수배된 날짜는?
#
# 임종석이 지명수배된 날짜는?
#
# 임종석이 지명수배된 날짜는?
#
# 임종석이 지명수배된 날짜는?
#
# 임종석이 지명수배된 날짜는?
#
# 임종석이 지명수배된 날짜는?
#
# 허영 경희대 석좌교수는 헌법개정안 준비 과정에 대해 "청와대 비서실이 아닌 국무회의 중심으로 이뤄졌어야 한다고 지적한 것은?
#
# 허영 경희대 석좌교수는 헌법개정안 준비 과정에 대해 "청와대 비서실이 아닌 국무회의 중심으로 이뤄졌어야 한다고 지적한 것은?
#
# 허영 경희대 석좌교수는 헌법개정안 준비 과정에 대해 "청와대 비서실이 아닌 국무회의 중심으로 이뤄졌어야 한다고 지적한 것은?
#
# 허영 경희대 석좌교수는 헌법개정안 준비 과정에 대해 "청와대 비서실이 아닌 국무회의 중심으로 이뤄졌어야 한다고 지적한 것은?
#
# 알렉산더 메이그스 헤이그 2세가 쓴 책의 이름은?
#
# 알렉산더 메이그스 헤이그 2세가 쓴 책의 이름은?
#
# 알렉산더 메이그스 헤이그 2세가 쓴 책의 이름은?
#
# 알렉산더 메이그스 헤이그 2세가 쓴 책의 이름은?
#
# 알렉산더 메이그스 헤이그 2세가 쓴 책의 이름은?
#
# 알렉산더 메이그스 헤이그 2세가 쓴 책의 이름은?
#
# 알렉산더 메이그스 헤이그 2세가 쓴 책의 이름은?
#
# 알렉산더 메이그스 헤이그 2세가 쓴 책의 이름은?
#
# 로저 헤이그는 몇 명의 자식을 두었는가?
#
# 로저 헤이그는 몇 명의 자식을 두었는가?
#
# 로저 헤이그는 몇 명의 자식을 두었는가?
#
# 로저 헤이그는 몇 명의 자식을 두었는가?
#
# 로저 헤이그는 몇 명의 자식을 두었는가?
#
# 로저 헤이그는 몇 명의 자식을 두었는가?
#
# 로저 헤이그는 몇 명의 자식을 두었는가?
#
# 로저 헤이그는 몇 명의 자식을 두었는가?
#
# 워터게이트 사건이 일어난지 한달 후 닉슨 대통령이 그를 사성 장군과 육군 부참모로 진급시킨 협상들에서 헤이그가 수단이었던 우연이 아니었던 것은?
#
# 워터게이트 사건이 일어난지 한달 후 닉슨 대통령이 그를 사성 장군과 육군 부참모로 진급시킨 협상들에서 헤이그가 수단이었던 우연이 아니었던 것은?
#
# 워터게이트 사건이 일어난지 한달 후 닉슨 대통령이 그를 사성 장군과 육군 부참모로 진급시킨 협상들에서 헤이그가 수단이었던 우연이 아니었던 것은?
#
# 워터게이트 사건이 일어난지 한달 후 닉슨 대통령이 그를 사성 장군과 육군 부참모로 진급시킨 협상들에서 헤이그가 수단이었던 우연이 아니었던 것은?
#
# 워터게이트 사건이 일어난지 한달 후 닉슨 대통령이 그를 사성 장군과 육군 부참모로 진급시킨 협상들에서 헤이그가 수단이었던 우연이 아니었던 것은?
#
# 워터게이트 사건이 일어난지 한달 후 닉슨 대통령이 그를 사성 장군과 육군 부참모로 진급시킨 협상들에서 헤이그가 수단이었던 우연이 아니었던 것은?
#
# 워터게이트 사건이 일어난지 한달 후 닉슨 대통령이 그를 사성 장군과 육군 부참모로 진급시킨 협상들에서 헤이그가 수단이었던 우연이 아니었던 것은?
#
# Worldwide Associates Inc.의 국제적 상담 회사에 의해 기용된 인물은?
#
# Worldwide Associates Inc.의 국제적 상담 회사에 의해 기용된 인물은?
#
# Worldwide Associates Inc.의 국제적 상담 회사에 의해 기용된 인물은?
#
# Worldwide Associates Inc.의 국제적 상담 회사에 의해 기용된 인물은?
#
# Worldwide Associates Inc.의 국제적 상담 회사에 의해 기용된 인물은?
#
# Worldwide Associates Inc.의 국제적 상담 회사에 의해 기용된 인물은?
#
# 창세기에서 모든 생물(물고기 제외)이 전멸하고 말았으며 이 방주에 탔던 노아의 가족과 동물들은 살아 남았다고 하는 것은?
#
# 창세기에서 모든 생물(물고기 제외)이 전멸하고 말았으며 이 방주에 탔던 노아의 가족과 동물들은 살아 남았다고 하는 것은?
#
# 창세기에서 모든 생물(물고기 제외)이 전멸하고 말았으며 이 방주에 탔던 노아의 가족과 동물들은 살아 남았다고 하는 것은?
#
# 창세기에서 모든 생물(물고기 제외)이 전멸하고 말았으며 이 방주에 탔던 노아의 가족과 동물들은 살아 남았다고 하는 것은?
#
# 창세기에서 모든 생물(물고기 제외)이 전멸하고 말았으며 이 방주에 탔던 노아의 가족과 동물들은 살아 남았다고 하는 것은?
#
# 창세기에서 모든 생물(물고기 제외)이 전멸하고 말았으며 이 방주에 탔던 노아의 가족과 동물들은 살아 남았다고 하는 것은?
#
# 창세기에서 모든 생물(물고기 제외)이 전멸하고 말았으며 이 방주에 탔던 노아의 가족과 동물들은 살아 남았다고 하는 것은?
#
# 창세기에서 모든 생물(물고기 제외)이 전멸하고 말았으며 이 방주에 탔던 노아의 가족과 동물들은 살아 남았다고 하는 것은?
#
# 창세기에서 모든 생물(물고기 제외)이 전멸하고 말았으며 이 방주에 탔던 노아의 가족과 동물들은 살아 남았다고 하는 것은?
#
# 현대 신학계에서 노아의 방주 자체의 의미는 중요하게 해석된다고 하는 것은?
#
# 현대 신학계에서 노아의 방주 자체의 의미는 중요하게 해석된다고 하는 것은?
#
# 현대 신학계에서 노아의 방주 자체의 의미는 중요하게 해석된다고 하는 것은?
#
# 현대 신학계에서 노아의 방주 자체의 의미는 중요하게 해석된다고 하는 것은?
#
# 현대 신학계에서 노아의 방주 자체의 의미는 중요하게 해석된다고 하는 것은?
#
# 현대 신학계에서 노아의 방주 자체의 의미는 중요하게 해석된다고 하는 것은?
#
# 현대 신학계에서 노아의 방주 자체의 의미는 중요하게 해석된다고 하는 것은?
#
# 유교교로 대표되는 극보수주의계열 기독교에서 노아의 방주를 찾기 위한 노력을 했다고 주장하는 신화는?
#
# 유교교로 대표되는 극보수주의계열 기독교에서 노아의 방주를 찾기 위한 노력을 했다고 주장하는 신화는?
#
# 유교교로 대표되는 극보수주의계열 기독교에서 노아의 방주를 찾기 위한 노력을 했다고 주장하는 신화는?
#
# 유교교로 대표되는 극보수주의계열 기독교에서 노아의 방주를 찾기 위한 노력을 했다고 주장하는 신화는?
#
# 유교교로 대표되는 극보수주의계열 기독교에서 노아의 방주를 찾기 위한 노력을 했다고 주장하는 신화는?
#
# 유교교로 대표되는 극보수주의계열 기독교에서 노아의 방주를 찾기 위한 노력을 했다고 주장하는 신화는?
#
# 유교교로 대표되는 극보수주의계열 기독교에서 노아의 방주를 찾기 위한 노력을 했다고 주장하는 신화는?
#
# 현재 노아의 방주가 실존한다는 주장은 그 증거가 존재하지 않기에 관련 학계로부터 인정받지 못하고 있는것은?
#
# 현재 노아의 방주가 실존한다는 주장은 그 증거가 존재하지 않기에 관련 학계로부터 인정받지 못하고 있는것은?
#
# Fernand Navarra가 발견한 목재 파편의 이름은?
#
# Fernand Navarra가 발견한 목재 파편의 이름은?
#
# Fernand Navarra가 발견한 목재 파편의 이름은?
#
# Fernand Navarra가 발견한 목재 파편의 이름은?
#
# Fernand Navarra가 발견한 목재 파편의 이름은?
#
# Fernand Navarra가 발견한 목재 파편의 이름은?
#
# 에베레스트 산이 잠기게 할 정도의 폭우로 인해 담수와 염수가 급작스럽게 섞일 경우 대부분의 수생생물이 폐사하게 되는 것은?
#
# 에베레스트 산이 잠기게 할 정도의 폭우로 인해 담수와 염수가 급작스럽게 섞일 경우 대부분의 수생생물이 폐사하게 되는 것은?
#
# 에베레스트 산이 잠기게 할 정도의 폭우로 인해 담수와 염수가 급작스럽게 섞일 경우 대부분의 수생생물이 폐사하게 되는 것은?
#
# 에베레스트 산이 잠기게 할 정도의 폭우로 인해 담수와 염수가 급작스럽게 섞일 경우 대부분의 수생생물이 폐사하게 되는 것은?
#
# 에베레스트 산이 잠기게 할 정도의 폭우로 인해 담수와 염수가 급작스럽게 섞일 경우 대부분의 수생생물이 폐사하게 되는 것은?
#
# 에베레스트 산이 잠기게 할 정도의 폭우로 인해 담수와 염수가 급작스럽게 섞일 경우 대부분의 수생생물이 폐사하게 되는 것은?
#
# 에베레스트 산이 잠기게 할 정도의 폭우로 인해 담수와 염수가 급작스럽게 섞일 경우 대부분의 수생생물이 폐사하게 되는 것은?
#
# 창조과학회에서 주장하는 방주의 크기와 철제 부품을 사용하지 않은 목재 선박 중 가장 큰 수준의 선박들을 비교하면 배수량이 두배 이상 차이난다고 주장한 것은?
#
# 창조과학회에서 주장하는 방주의 크기와 철제 부품을 사용하지 않은 목재 선박 중 가장 큰 수준의 선박들을 비교하면 배수량이 두배 이상 차이난다고 주장한 것은?
#
# 창조과학회에서 주장하는 방주의 크기와 철제 부품을 사용하지 않은 목재 선박 중 가장 큰 수준의 선박들을 비교하면 배수량이 두배 이상 차이난다고 주장한 것은?
#
# 창조과학회에서 주장하는 방주의 크기와 철제 부품을 사용하지 않은 목재 선박 중 가장 큰 수준의 선박들을 비교하면 배수량이 두배 이상 차이난다고 주장한 것은?
#
# 창조과학회에서 주장하는 방주의 크기와 철제 부품을 사용하지 않은 목재 선박 중 가장 큰 수준의 선박들을 비교하면 배수량이 두배 이상 차이난다고 주장한 것은?
#
# 창조과학회에서 주장하는 방주의 크기와 철제 부품을 사용하지 않은 목재 선박 중 가장 큰 수준의 선박들을 비교하면 배수량이 두배 이상 차이난다고 주장한 것은?
#
# 창조과학회에서 주장하는 방주의 크기와 철제 부품을 사용하지 않은 목재 선박 중 가장 큰 수준의 선박들을 비교하면 배수량이 두배 이상 차이난다고 주장한 것은?
#
# 에조치에 건너가 하코다테 전쟁에서 에노모토 해군의 주력함이 된 것은?
#
# 에조치에 건너가 하코다테 전쟁에서 에노모토 해군의 주력함이 된 것은?
#
# 에조치에 건너가 하코다테 전쟁에서 에노모토 해군의 주력함이 된 것은?
#
# 에조치에 건너가 하코다테 전쟁에서 에노모토 해군의 주력함이 된 것은?
#
# 에조치에 건너가 하코다테 전쟁에서 에노모토 해군의 주력함이 된 것은?
#
# 에조치에 건너가 하코다테 전쟁에서 에노모토 해군의 주력함이 된 것은?
#
# 에조치에 건너가 하코다테 전쟁에서 에노모토 해군의 주력함이 된 것은?
#
# 에조치에 건너가 하코다테 전쟁에서 에노모토 해군의 주력함이 된 것은?
#
# 하야시 다다스는 어디에서 신정부군의 철갑함의 추격을 받았는가?
#
# 하야시 다다스는 어디에서 신정부군의 철갑함의 추격을 받았는가?
#
# 하야시 다다스는 어디에서 신정부군의 철갑함의 추격을 받았는가?
#
# 하야시 다다스는 어디에서 신정부군의 철갑함의 추격을 받았는가?
#
# 하야시 다다스는 어디에서 신정부군의 철갑함의 추격을 받았는가?
#
# 하야시 다다스는 어디에서 신정부군의 철갑함의 추격을 받았는가?
#
# 하야시 다다스는 어디에서 신정부군의 철갑함의 추격을 받았는가?
#
# 하야시 다다스는 어디에서 신정부군의 철갑함의 추격을 받았는가?
#
# 하코다테 총공격에서 벤텐 다이바와 기관 고장으로 움직일 수 없는 포대가 된 가이텐마루가 신정부 군 함대와 응전을 벌인 곳은?
#
# 하코다테 총공격에서 벤텐 다이바와 기관 고장으로 움직일 수 없는 포대가 된 가이텐마루가 신정부 군 함대와 응전을 벌인 곳은?
#
# 하코다테 총공격에서 벤텐 다이바와 기관 고장으로 움직일 수 없는 포대가 된 가이텐마루가 신정부 군 함대와 응전을 벌인 곳은?
#
# 하코다테 총공격에서 벤텐 다이바와 기관 고장으로 움직일 수 없는 포대가 된 가이텐마루가 신정부 군 함대와 응전을 벌인 곳은?
#
# 하코다테 총공격에서 벤텐 다이바와 기관 고장으로 움직일 수 없는 포대가 된 가이텐마루가 신정부 군 함대와 응전을 벌인 곳은?
#
# 하코다테 총공격에서 벤텐 다이바와 기관 고장으로 움직일 수 없는 포대가 된 가이텐마루가 신정부 군 함대와 응전을 벌인 곳은?
#
# 하코다테 총공격에서 벤텐 다이바와 기관 고장으로 움직일 수 없는 포대가 된 가이텐마루가 신정부 군 함대와 응전을 벌인 곳은?
#
# 하코다테 총공격에서 벤텐 다이바와 기관 고장으로 움직일 수 없는 포대가 된 가이텐마루가 신정부 군 함대와 응전을 벌인 곳은?
#
# 서양철학이라는 용어 자체는 고대 그리스어에서 유래한 용어인가?
#
# 서양철학이라는 용어 자체는 고대 그리스어에서 유래한 용어인가?
#
# 서양철학이라는 용어 자체는 고대 그리스어에서 유래한 용어인가?
#
# 서양철학이라는 용어 자체는 고대 그리스어에서 유래한 용어인가?
#
# 서양철학이라는 용어 자체는 고대 그리스어에서 유래한 용어인가?
#
# 서양철학이라는 용어 자체는 고대 그리스어에서 유래한 용어인가?
#
# sep철학의 범위에 대한 고대의 이해와 고대 철학자의 글쓰기를 살펴보면, 모든 지적 노력을 철학에 포함시키고 있는 것은?
#
# sep철학의 범위에 대한 고대의 이해와 고대 철학자의 글쓰기를 살펴보면, 모든 지적 노력을 철학에 포함시키고 있는 것은?
#
# sep철학의 범위에 대한 고대의 이해와 고대 철학자의 글쓰기를 살펴보면, 모든 지적 노력을 철학에 포함시키고 있는 것은?
#
# sep철학의 범위에 대한 고대의 이해와 고대 철학자의 글쓰기를 살펴보면, 모든 지적 노력을 철학에 포함시키고 있는 것은?
#
# sep철학의 범위에 대한 고대의 이해와 고대 철학자의 글쓰기를 살펴보면, 모든 지적 노력을 철학에 포함시키고 있는 것은?
#
# sep철학의 범위에 대한 고대의 이해와 고대 철학자의 글쓰기를 살펴보면, 모든 지적 노력을 철학에 포함시키고 있는 것은?
#
# 서양 철학이라는 용어의 지정학적 경계가 형성된 시기는?
#
# 서양 철학이라는 용어의 지정학적 경계가 형성된 시기는?
#
# 서양 철학이라는 용어의 지정학적 경계가 형성된 시기는?
#
# 서양 철학이라는 용어의 지정학적 경계가 형성된 시기는?
#
# 서양 철학이라는 용어의 지정학적 경계가 형성된 시기는?
#
# 서양 철학이라는 용어의 지정학적 경계가 형성된 시기는?
#
# 세계 종교의 차이를 비교하는 비교 종교학을 비롯한 종교 연구의 다른 부분에서 종교 연구와 철학이 쉽게 구분되는 이유는?
#
# 세계 종교의 차이를 비교하는 비교 종교학을 비롯한 종교 연구의 다른 부분에서 종교 연구와 철학이 쉽게 구분되는 이유는?
#
# 세계 종교의 차이를 비교하는 비교 종교학을 비롯한 종교 연구의 다른 부분에서 종교 연구와 철학이 쉽게 구분되는 이유는?
#
# 세계 종교의 차이를 비교하는 비교 종교학을 비롯한 종교 연구의 다른 부분에서 종교 연구와 철학이 쉽게 구분되는 이유는?
#
# 세계 종교의 차이를 비교하는 비교 종교학을 비롯한 종교 연구의 다른 부분에서 종교 연구와 철학이 쉽게 구분되는 이유는?
#
# 세계 종교의 차이를 비교하는 비교 종교학을 비롯한 종교 연구의 다른 부분에서 종교 연구와 철학이 쉽게 구분되는 이유는?
#
# 임세영이 비밀결사에 가입하여 무예를 배우기 시작한 시기는?
#
# 임세영이 비밀결사에 가입하여 무예를 배우기 시작한 시기는?
#
# 임세영이 비밀결사에 가입하여 무예를 배우기 시작한 시기는?
#
# 임세영이 비밀결사에 가입하여 무예를 배우기 시작한 시기는?
#
# 임세영이 비밀결사에 가입하여 무예를 배우기 시작한 시기는?
#
# 임세영이 비밀결사에 가입하여 무예를 배우기 시작한 시기는?
#
# 임세영이 비밀결사에 가입하여 무예를 배우기 시작한 시기는?
#
# 임세영이 비밀결사에 가입하여 무예를 배우기 시작한 시기는?
#
# 황비홍을 재조명하는 작업에 착수하여 황비홍의 존재를 널리 알린 인물은?
#
# 황비홍을 재조명하는 작업에 착수하여 황비홍의 존재를 널리 알린 인물은?
#
# 황비홍을 재조명하는 작업에 착수하여 황비홍의 존재를 널리 알린 인물은?
#
# 황비홍을 재조명하는 작업에 착수하여 황비홍의 존재를 널리 알린 인물은?
#
# 황비홍을 재조명하는 작업에 착수하여 황비홍의 존재를 널리 알린 인물은?
#
# 황비홍을 재조명하는 작업에 착수하여 황비홍의 존재를 널리 알린 인물은?
#
# 황비홍을 재조명하는 작업에 착수하여 황비홍의 존재를 널리 알린 인물은?
#
# 황비홍을 재조명하는 작업에 착수하여 황비홍의 존재를 널리 알린 인물은?
#
# 성정이 포악하여 새로운 도장이 들어설 때마다 찾아가 대련을 신청하여 도장을 폐쇄시켜 도장이 들어설 수 없도록 한 관장은?
#
# 성정이 포악하여 새로운 도장이 들어설 때마다 찾아가 대련을 신청하여 도장을 폐쇄시켜 도장이 들어설 수 없도록 한 관장은?
#
# 성정이 포악하여 새로운 도장이 들어설 때마다 찾아가 대련을 신청하여 도장을 폐쇄시켜 도장이 들어설 수 없도록 한 관장은?
#
# 성정이 포악하여 새로운 도장이 들어설 때마다 찾아가 대련을 신청하여 도장을 폐쇄시켜 도장이 들어설 수 없도록 한 관장은?
#
# 성정이 포악하여 새로운 도장이 들어설 때마다 찾아가 대련을 신청하여 도장을 폐쇄시켜 도장이 들어설 수 없도록 한 관장은?
#
# 성정이 포악하여 새로운 도장이 들어설 때마다 찾아가 대련을 신청하여 도장을 폐쇄시켜 도장이 들어설 수 없도록 한 관장은?
#
# 유길복이 졸업한 학교는?
#
# 유길복이 졸업한 학교는?
#
# 유길복이 졸업한 학교는?
#
# 유길복이 졸업한 학교는?
#
# 유길복이 졸업한 학교는?
#
# 유길복이 졸업한 학교는?
#
# 무디스가 한국의 국가신용등급 전망을 '긍정적'에서 '부정적'으로 낮추며 압박한 인물은?
#
# 무디스가 한국의 국가신용등급 전망을 '긍정적'에서 '부정적'으로 낮추며 압박한 인물은?
#
# 무디스가 한국의 국가신용등급 전망을 '긍정적'에서 '부정적'으로 낮추며 압박한 인물은?
#
# 무디스가 한국의 국가신용등급 전망을 '긍정적'에서 '부정적'으로 낮추며 압박한 인물은?
#
# 무디스가 한국의 국가신용등급 전망을 '긍정적'에서 '부정적'으로 낮추며 압박한 인물은?
#
# 무디스가 한국의 국가신용등급 전망을 '긍정적'에서 '부정적'으로 낮추며 압박한 인물은?
#
# 무디스가 한국의 국가신용등급 전망을 '긍정적'에서 '부정적'으로 낮추며 압박한 인물은?
#
# 무디스가 한국의 국가신용등급 전망을 '긍정적'에서 '부정적'으로 낮추며 압박한 인물은?
#
# 무디스가 한국의 국가신용등급 전망을 '긍정적'에서 '부정적'으로 낮추며 압박한 인물은?
#
# 유엔사를 해체하고 주한미군을 철수시키려는 조선민주주의인민공화국의 기만전술이라고 판단하여 노무현에게 보고조차 하지 않은것은?
#
# 유엔사를 해체하고 주한미군을 철수시키려는 조선민주주의인민공화국의 기만전술이라고 판단하여 노무현에게 보고조차 하지 않은것은?
#
# 유엔사를 해체하고 주한미군을 철수시키려는 조선민주주의인민공화국의 기만전술이라고 판단하여 노무현에게 보고조차 하지 않은것은?
#
# 유엔사를 해체하고 주한미군을 철수시키려는 조선민주주의인민공화국의 기만전술이라고 판단하여 노무현에게 보고조차 하지 않은것은?
#
# 유엔사를 해체하고 주한미군을 철수시키려는 조선민주주의인민공화국의 기만전술이라고 판단하여 노무현에게 보고조차 하지 않은것은?
#
# 유엔사를 해체하고 주한미군을 철수시키려는 조선민주주의인민공화국의 기만전술이라고 판단하여 노무현에게 보고조차 하지 않은것은?
#
# 유엔사를 해체하고 주한미군을 철수시키려는 조선민주주의인민공화국의 기만전술이라고 판단하여 노무현에게 보고조차 하지 않은것은?
#
# 2005년 9월 미국 워싱턴을 방문하여 모든 핵무기를 파기하고 NPT와 IAEA로 복귀한다는 9.19 공동성명이 타결될 때 외교부에 박선원 당시 행정관을 감시병으로 파견하기도 한 사람은?
#
# 2005년 9월 미국 워싱턴을 방문하여 모든 핵무기를 파기하고 NPT와 IAEA로 복귀한다는 9.19 공동성명이 타결될 때 외교부에 박선원 당시 행정관을 감시병으로 파견하기도 한 사람은?
#
# 2005년 9월 미국 워싱턴을 방문하여 모든 핵무기를 파기하고 NPT와 IAEA로 복귀한다는 9.19 공동성명이 타결될 때 외교부에 박선원 당시 행정관을 감시병으로 파견하기도 한 사람은?
#
# 2005년 9월 미국 워싱턴을 방문하여 모든 핵무기를 파기하고 NPT와 IAEA로 복귀한다는 9.19 공동성명이 타결될 때 외교부에 박선원 당시 행정관을 감시병으로 파견하기도 한 사람은?
#
# 2005년 9월 미국 워싱턴을 방문하여 모든 핵무기를 파기하고 NPT와 IAEA로 복귀한다는 9.19 공동성명이 타결될 때 외교부에 박선원 당시 행정관을 감시병으로 파견하기도 한 사람은?
#
# 2005년 9월 미국 워싱턴을 방문하여 모든 핵무기를 파기하고 NPT와 IAEA로 복귀한다는 9.19 공동성명이 타결될 때 외교부에 박선원 당시 행정관을 감시병으로 파견하기도 한 사람은?
#
# 2005년 9월 미국 워싱턴을 방문하여 모든 핵무기를 파기하고 NPT와 IAEA로 복귀한다는 9.19 공동성명이 타결될 때 외교부에 박선원 당시 행정관을 감시병으로 파견하기도 한 사람은?
#
# 2005년 9월 미국 워싱턴을 방문하여 모든 핵무기를 파기하고 NPT와 IAEA로 복귀한다는 9.19 공동성명이 타결될 때 외교부에 박선원 당시 행정관을 감시병으로 파견하기도 한 사람은?
#
# 2005년 9월 미국 워싱턴을 방문하여 모든 핵무기를 파기하고 NPT와 IAEA로 복귀한다는 9.19 공동성명이 타결될 때 외교부에 박선원 당시 행정관을 감시병으로 파견하기도 한 사람은?
#
# 반기문이 유엔 사무총장에 당선된 것은 언제인가?
#
# 반기문이 유엔 사무총장에 당선된 것은 언제인가?
#
# 반기문이 유엔 사무총장에 당선된 것은 언제인가?
#
# 반기문이 유엔 사무총장에 당선된 것은 언제인가?
#
# 반기문이 유엔 사무총장에 당선된 것은 언제인가?
#
# 반기문이 유엔 사무총장에 당선된 것은 언제인가?
#
# 반기문이 유엔 사무총장에 당선된 것은 언제인가?
#
# 반기문이 유엔 사무총장에 당선된 것은 언제인가?
#
# 반기문이 유엔 사무총장에 당선된 것은 언제인가?
#
# 2007년 7월 31일 유엔 안전 보장 이사회는 26,000명의 유엔 평화유지군 병력이 어디 연합군과 합세해 분쟁 지역으로 진입하는 것을 승인하였는가?
#
# 2007년 7월 31일 유엔 안전 보장 이사회는 26,000명의 유엔 평화유지군 병력이 어디 연합군과 합세해 분쟁 지역으로 진입하는 것을 승인하였는가?
#
# 2007년 7월 31일 유엔 안전 보장 이사회는 26,000명의 유엔 평화유지군 병력이 어디 연합군과 합세해 분쟁 지역으로 진입하는 것을 승인하였는가?
#
# 2007년 7월 31일 유엔 안전 보장 이사회는 26,000명의 유엔 평화유지군 병력이 어디 연합군과 합세해 분쟁 지역으로 진입하는 것을 승인하였는가?
#
# 2007년 7월 31일 유엔 안전 보장 이사회는 26,000명의 유엔 평화유지군 병력이 어디 연합군과 합세해 분쟁 지역으로 진입하는 것을 승인하였는가?
#
# 2007년 7월 31일 유엔 안전 보장 이사회는 26,000명의 유엔 평화유지군 병력이 어디 연합군과 합세해 분쟁 지역으로 진입하는 것을 승인하였는가?
#
# 2007년 7월 31일 유엔 안전 보장 이사회는 26,000명의 유엔 평화유지군 병력이 어디 연합군과 합세해 분쟁 지역으로 진입하는 것을 승인하였는가?
#
# 2007년 7월 31일 유엔 안전 보장 이사회는 26,000명의 유엔 평화유지군 병력이 어디 연합군과 합세해 분쟁 지역으로 진입하는 것을 승인하였는가?
#
# 2007년 7월 31일 유엔 안전 보장 이사회는 26,000명의 유엔 평화유지군 병력이 어디 연합군과 합세해 분쟁 지역으로 진입하는 것을 승인하였는가?
#
# 2016년 6월 이스라엘과 팔레스타인 양측 중 어디에서 분쟁 해결을 위한 중재를 하였는가?
#
# 2016년 6월 이스라엘과 팔레스타인 양측 중 어디에서 분쟁 해결을 위한 중재를 하였는가?
#
# 2016년 6월 이스라엘과 팔레스타인 양측 중 어디에서 분쟁 해결을 위한 중재를 하였는가?
#
# 2016년 6월 이스라엘과 팔레스타인 양측 중 어디에서 분쟁 해결을 위한 중재를 하였는가?
#
# 2016년 6월 이스라엘과 팔레스타인 양측 중 어디에서 분쟁 해결을 위한 중재를 하였는가?
#
# 2016년 6월 이스라엘과 팔레스타인 양측 중 어디에서 분쟁 해결을 위한 중재를 하였는가?
#
# 2016년 6월 이스라엘과 팔레스타인 양측 중 어디에서 분쟁 해결을 위한 중재를 하였는가?
#
# 2016년 5월 16일 박근혜 대통령을 비판하며 친박계와 선을 그은 사람은?
#
# 2016년 5월 16일 박근혜 대통령을 비판하며 친박계와 선을 그은 사람은?
#
# 2016년 5월 16일 박근혜 대통령을 비판하며 친박계와 선을 그은 사람은?
#
# 2016년 5월 16일 박근혜 대통령을 비판하며 친박계와 선을 그은 사람은?
#
# 2016년 5월 16일 박근혜 대통령을 비판하며 친박계와 선을 그은 사람은?
#
# 2016년 5월 16일 박근혜 대통령을 비판하며 친박계와 선을 그은 사람은?
#
# 2016년 5월 16일 박근혜 대통령을 비판하며 친박계와 선을 그은 사람은?
#
# 김남희 세계여성평화그룹(IWPG) 대표가 신천지와 친밀한 관계라는 의혹과 관련하여 반기문에게 해명을 요구한 두자릭 UN 대변인은 누구인가?
#
# 김남희 세계여성평화그룹(IWPG) 대표가 신천지와 친밀한 관계라는 의혹과 관련하여 반기문에게 해명을 요구한 두자릭 UN 대변인은 누구인가?
#
# 김남희 세계여성평화그룹(IWPG) 대표가 신천지와 친밀한 관계라는 의혹과 관련하여 반기문에게 해명을 요구한 두자릭 UN 대변인은 누구인가?
#
# 김남희 세계여성평화그룹(IWPG) 대표가 신천지와 친밀한 관계라는 의혹과 관련하여 반기문에게 해명을 요구한 두자릭 UN 대변인은 누구인가?
#
# 김남희 세계여성평화그룹(IWPG) 대표가 신천지와 친밀한 관계라는 의혹과 관련하여 반기문에게 해명을 요구한 두자릭 UN 대변인은 누구인가?
#
# 김남희 세계여성평화그룹(IWPG) 대표가 신천지와 친밀한 관계라는 의혹과 관련하여 반기문에게 해명을 요구한 두자릭 UN 대변인은 누구인가?
#
# 김남희 세계여성평화그룹(IWPG) 대표가 신천지와 친밀한 관계라는 의혹과 관련하여 반기문에게 해명을 요구한 두자릭 UN 대변인은 누구인가?
#
# 반기문 유엔 사무총장이 강한 지도자의 면모를 갖춘 인물이라고 보도한 기고 글의 이름은?
#
# 반기문 유엔 사무총장이 강한 지도자의 면모를 갖춘 인물이라고 보도한 기고 글의 이름은?
#
# 반기문 유엔 사무총장이 강한 지도자의 면모를 갖춘 인물이라고 보도한 기고 글의 이름은?
#
# 반기문 유엔 사무총장이 강한 지도자의 면모를 갖춘 인물이라고 보도한 기고 글의 이름은?
#
# 반기문 유엔 사무총장이 강한 지도자의 면모를 갖춘 인물이라고 보도한 기고 글의 이름은?
#
# 반기문 유엔 사무총장이 강한 지도자의 면모를 갖춘 인물이라고 보도한 기고 글의 이름은?
#
# 반기문 유엔 사무총장이 강한 지도자의 면모를 갖춘 인물이라고 보도한 기고 글의 이름은?
#
# 반기문 유엔 사무총장이 강한 지도자의 면모를 갖춘 인물이라고 보도한 기고 글의 이름은?
#
# 외금강의 남쪽 지역이 신금강으로 분류되는 것은?
#
# 외금강의 남쪽 지역이 신금강으로 분류되는 것은?
#
# 외금강의 남쪽 지역이 신금강으로 분류되는 것은?
#
# 외금강의 남쪽 지역이 신금강으로 분류되는 것은?
#
# 외금강의 남쪽 지역이 신금강으로 분류되는 것은?
#
# 외금강의 남쪽 지역이 신금강으로 분류되는 것은?
#
# 외금강의 남쪽 지역이 신금강으로 분류되는 것은?
#
# 외금강의 남쪽 지역이 신금강으로 분류되는 것은?
#
# 외금강의 남쪽 지역이 신금강으로 분류되는 것은?
#
# 많은 이름을 가진 산이 금강산으로 널리 알려진 이유는?
#
# 많은 이름을 가진 산이 금강산으로 널리 알려진 이유는?
#
# 많은 이름을 가진 산이 금강산으로 널리 알려진 이유는?
#
# 많은 이름을 가진 산이 금강산으로 널리 알려진 이유는?
#
# 많은 이름을 가진 산이 금강산으로 널리 알려진 이유는?
#
# 많은 이름을 가진 산이 금강산으로 널리 알려진 이유는?
#
# 많은 이름을 가진 산이 금강산으로 널리 알려진 이유는?
#
# 많은 이름을 가진 산이 금강산으로 널리 알려진 이유는?
#
# 비와 눈이 많이 내리는 지역인 금강산의 지질층은 어떤 작용으로 형성되었는가?
#
# 비와 눈이 많이 내리는 지역인 금강산의 지질층은 어떤 작용으로 형성되었는가?
#
# 비와 눈이 많이 내리는 지역인 금강산의 지질층은 어떤 작용으로 형성되었는가?
#
# 비와 눈이 많이 내리는 지역인 금강산의 지질층은 어떤 작용으로 형성되었는가?
#
# 비와 눈이 많이 내리는 지역인 금강산의 지질층은 어떤 작용으로 형성되었는가?
#
# 비와 눈이 많이 내리는 지역인 금강산의 지질층은 어떤 작용으로 형성되었는가?
#
# 비와 눈이 많이 내리는 지역인 금강산의 지질층은 어떤 작용으로 형성되었는가?
#
# 주분서령의 서쪽에 있는 지역으로 금강산의 주봉인 비로봉과 여러 폭포가 있는 곳은?
#
# 주분서령의 서쪽에 있는 지역으로 금강산의 주봉인 비로봉과 여러 폭포가 있는 곳은?
#
# 주분서령의 서쪽에 있는 지역으로 금강산의 주봉인 비로봉과 여러 폭포가 있는 곳은?
#
# 주분서령의 서쪽에 있는 지역으로 금강산의 주봉인 비로봉과 여러 폭포가 있는 곳은?
#
# 주분서령의 서쪽에 있는 지역으로 금강산의 주봉인 비로봉과 여러 폭포가 있는 곳은?
#
# 주분서령의 서쪽에 있는 지역으로 금강산의 주봉인 비로봉과 여러 폭포가 있는 곳은?
#
# 주분서령의 서쪽에 있는 지역으로 금강산의 주봉인 비로봉과 여러 폭포가 있는 곳은?
#
# 개성의 박연폭포, 설악산에 있는 대승폭포와 더불어 조선 3대 폭포로 꼽히며 높이는?
#
# 개성의 박연폭포, 설악산에 있는 대승폭포와 더불어 조선 3대 폭포로 꼽히며 높이는?
#
# 개성의 박연폭포, 설악산에 있는 대승폭포와 더불어 조선 3대 폭포로 꼽히며 높이는?
#
# 개성의 박연폭포, 설악산에 있는 대승폭포와 더불어 조선 3대 폭포로 꼽히며 높이는?
#
# 개성의 박연폭포, 설악산에 있는 대승폭포와 더불어 조선 3대 폭포로 꼽히며 높이는?
#
# 개성의 박연폭포, 설악산에 있는 대승폭포와 더불어 조선 3대 폭포로 꼽히며 높이는?
#
# 개성의 박연폭포, 설악산에 있는 대승폭포와 더불어 조선 3대 폭포로 꼽히며 높이는?
#
# 개성의 박연폭포, 설악산에 있는 대승폭포와 더불어 조선 3대 폭포로 꼽히며 높이는?
#
# 삼일포 기슭에 있는 관동 팔경의 하나인 총석정은 개방되어 있지 않은가?
#
# 삼일포 기슭에 있는 관동 팔경의 하나인 총석정은 개방되어 있지 않은가?
#
# 삼일포 기슭에 있는 관동 팔경의 하나인 총석정은 개방되어 있지 않은가?
#
# 삼일포 기슭에 있는 관동 팔경의 하나인 총석정은 개방되어 있지 않은가?
#
# 삼일포 기슭에 있는 관동 팔경의 하나인 총석정은 개방되어 있지 않은가?
#
# 삼일포 기슭에 있는 관동 팔경의 하나인 총석정은 개방되어 있지 않은가?
#
# 삼일포 기슭에 있는 관동 팔경의 하나인 총석정은 개방되어 있지 않은가?
#
# 삼일포 기슭에 있는 관동 팔경의 하나인 총석정은 개방되어 있지 않은가?
#
# 신계사 복원 공사가 2004년 4월에 착공해 2007년 10월에 완료된것은?
#
# 신계사 복원 공사가 2004년 4월에 착공해 2007년 10월에 완료된것은?
#
# 신계사 복원 공사가 2004년 4월에 착공해 2007년 10월에 완료된것은?
#
# 신계사 복원 공사가 2004년 4월에 착공해 2007년 10월에 완료된것은?
#
# 신계사 복원 공사가 2004년 4월에 착공해 2007년 10월에 완료된것은?
#
# 신계사 복원 공사가 2004년 4월에 착공해 2007년 10월에 완료된것은?
#
# 신계사 복원 공사가 2004년 4월에 착공해 2007년 10월에 완료된것은?
#
# 신계사 복원 공사가 2004년 4월에 착공해 2007년 10월에 완료된것은?
#
# 조선민주주의인민공화국 최고인민회의 상임위원회가 채택한 '금강산 관광지구법'에 따라 금강산이 엄격히 보호되고 있는 이유는?
#
# 조선민주주의인민공화국 최고인민회의 상임위원회가 채택한 '금강산 관광지구법'에 따라 금강산이 엄격히 보호되고 있는 이유는?
#
# 조선민주주의인민공화국 최고인민회의 상임위원회가 채택한 '금강산 관광지구법'에 따라 금강산이 엄격히 보호되고 있는 이유는?
#
# 조선민주주의인민공화국 최고인민회의 상임위원회가 채택한 '금강산 관광지구법'에 따라 금강산이 엄격히 보호되고 있는 이유는?
#
# 조선민주주의인민공화국 최고인민회의 상임위원회가 채택한 '금강산 관광지구법'에 따라 금강산이 엄격히 보호되고 있는 이유는?
#
# 조선민주주의인민공화국 최고인민회의 상임위원회가 채택한 '금강산 관광지구법'에 따라 금강산이 엄격히 보호되고 있는 이유는?
#
# 현대그룹의의 창업자 정주영이 1989년 방북하여 금강산 관광 의정서를 체결한 시기는?
#
# 현대그룹의의 창업자 정주영이 1989년 방북하여 금강산 관광 의정서를 체결한 시기는?
#
# 현대그룹의의 창업자 정주영이 1989년 방북하여 금강산 관광 의정서를 체결한 시기는?
#
# 현대그룹의의 창업자 정주영이 1989년 방북하여 금강산 관광 의정서를 체결한 시기는?
#
# 현대그룹의의 창업자 정주영이 1989년 방북하여 금강산 관광 의정서를 체결한 시기는?
#
# 현대그룹의의 창업자 정주영이 1989년 방북하여 금강산 관광 의정서를 체결한 시기는?
#
# 현대그룹의의 창업자 정주영이 1989년 방북하여 금강산 관광 의정서를 체결한 시기는?
#
# 현대그룹의의 창업자 정주영이 1989년 방북하여 금강산 관광 의정서를 체결한 시기는?
#
# 현대그룹의의 창업자 정주영이 1989년 방북하여 금강산 관광 의정서를 체결한 시기는?
#
# 남측 강원도는 2008년 7월 DMZ 관광청을 발족해 운영하고 있는데 이 관청의 계획에는 설악산과 금강산을 묶어 세계적인 관광지대로 가꾸는 것이 포함되어있다.
#
# 남측 강원도는 2008년 7월 DMZ 관광청을 발족해 운영하고 있는데 이 관청의 계획에는 설악산과 금강산을 묶어 세계적인 관광지대로 가꾸는 것이 포함되어있다.
#
# 남측 강원도는 2008년 7월 DMZ 관광청을 발족해 운영하고 있는데 이 관청의 계획에는 설악산과 금강산을 묶어 세계적인 관광지대로 가꾸는 것이 포함되어있다.
#
# 남측 강원도는 2008년 7월 DMZ 관광청을 발족해 운영하고 있는데 이 관청의 계획에는 설악산과 금강산을 묶어 세계적인 관광지대로 가꾸는 것이 포함되어있다.
#
# 남측 강원도는 2008년 7월 DMZ 관광청을 발족해 운영하고 있는데 이 관청의 계획에는 설악산과 금강산을 묶어 세계적인 관광지대로 가꾸는 것이 포함되어있다.
#
# 남측 강원도는 2008년 7월 DMZ 관광청을 발족해 운영하고 있는데 이 관청의 계획에는 설악산과 금강산을 묶어 세계적인 관광지대로 가꾸는 것이 포함되어있다.
#
# 체스보드 위의 정사각형들이 흰색과 검은색이 번갈아가며 칠해져 있는것은?
#
# 체스보드 위의 정사각형들이 흰색과 검은색이 번갈아가며 칠해져 있는것은?
#
# 체스보드 위의 정사각형들이 흰색과 검은색이 번갈아가며 칠해져 있는것은?
#
# 체스보드 위의 정사각형들이 흰색과 검은색이 번갈아가며 칠해져 있는것은?
#
# 체스보드 위의 정사각형들이 흰색과 검은색이 번갈아가며 칠해져 있는것은?
#
# 체스보드 위의 정사각형들이 흰색과 검은색이 번갈아가며 칠해져 있는것은?
#
# 체스보드 위의 정사각형들이 흰색과 검은색이 번갈아가며 칠해져 있는것은?
#
# 체스보드 위의 정사각형들이 흰색과 검은색이 번갈아가며 칠해져 있는것은?
#
# 체스보드 위의 정사각형들이 흰색과 검은색이 번갈아가며 칠해져 있는것은?
#
# 앙파상 규칙으로 상대의 폰이 체스보드에서 제거한 후 상대의 폰이 있던 자리에 자신의 폰을 놓는 것이 아니라면?
#
# 앙파상 규칙으로 상대의 폰이 체스보드에서 제거한 후 상대의 폰이 있던 자리에 자신의 폰을 놓는 것이 아니라면?
#
# 앙파상 규칙으로 상대의 폰이 체스보드에서 제거한 후 상대의 폰이 있던 자리에 자신의 폰을 놓는 것이 아니라면?
#
# 앙파상 규칙으로 상대의 폰이 체스보드에서 제거한 후 상대의 폰이 있던 자리에 자신의 폰을 놓는 것이 아니라면?
#
# 퀸 8번째 랭크까지 전진시키면 퀸, 룩, 비숍 또는 나이트로 바꿀 수 있는 기물은?
#
# 퀸 8번째 랭크까지 전진시키면 퀸, 룩, 비숍 또는 나이트로 바꿀 수 있는 기물은?
#
# 퀸 8번째 랭크까지 전진시키면 퀸, 룩, 비숍 또는 나이트로 바꿀 수 있는 기물은?
#
# 퀸 8번째 랭크까지 전진시키면 퀸, 룩, 비숍 또는 나이트로 바꿀 수 있는 기물은?
#
# 퀸 8번째 랭크까지 전진시키면 퀸, 룩, 비숍 또는 나이트로 바꿀 수 있는 기물은?
#
# 퀸 8번째 랭크까지 전진시키면 퀸, 룩, 비숍 또는 나이트로 바꿀 수 있는 기물은?
#
# 퀸 8번째 랭크까지 전진시키면 퀸, 룩, 비숍 또는 나이트로 바꿀 수 있는 기물은?
#
# 체크메이트가 발생하면 경기는 체크메이트를 당한 사람의 패배로 종료되는 것은?
#
# 체크메이트가 발생하면 경기는 체크메이트를 당한 사람의 패배로 종료되는 것은?
#
# 체크메이트가 발생하면 경기는 체크메이트를 당한 사람의 패배로 종료되는 것은?
#
# 체크메이트가 발생하면 경기는 체크메이트를 당한 사람의 패배로 종료되는 것은?
#
# 체크메이트가 발생하면 경기는 체크메이트를 당한 사람의 패배로 종료되는 것은?
#
# 체크메이트가 발생하면 경기는 체크메이트를 당한 사람의 패배로 종료되는 것은?
#
# 체크메이트가 발생하면 경기는 체크메이트를 당한 사람의 패배로 종료되는 것은?
#
# 자신의 킹을 넘어뜨리는 것도 기권을 뜻하지만 기권한 사람의 패배가 되는 것은?
#
# 자신의 킹을 넘어뜨리는 것도 기권을 뜻하지만 기권한 사람의 패배가 되는 것은?
#
# 자신의 킹을 넘어뜨리는 것도 기권을 뜻하지만 기권한 사람의 패배가 되는 것은?
#
# 자신의 킹을 넘어뜨리는 것도 기권을 뜻하지만 기권한 사람의 패배가 되는 것은?
#
# 자신의 킹을 넘어뜨리는 것도 기권을 뜻하지만 기권한 사람의 패배가 되는 것은?
#
# 자신의 킹을 넘어뜨리는 것도 기권을 뜻하지만 기권한 사람의 패배가 되는 것은?
#
# 자신의 킹을 넘어뜨리는 것도 기권을 뜻하지만 기권한 사람의 패배가 되는 것은?
#
# 시간제한이 주어진 대국에 대해서 '타임 컨트롤'이 적용된 종목은?
#
# 시간제한이 주어진 대국에 대해서 '타임 컨트롤'이 적용된 종목은?
#
# 시간제한이 주어진 대국에 대해서 '타임 컨트롤'이 적용된 종목은?
#
# 시간제한이 주어진 대국에 대해서 '타임 컨트롤'이 적용된 종목은?
#
# 시간제한이 주어진 대국에 대해서 '타임 컨트롤'이 적용된 종목은?
#
# 시간제한이 주어진 대국에 대해서 '타임 컨트롤'이 적용된 종목은?
#
# 룩을 먼저 이동 시킬 경우 룩은 주위로 2칸 이상 갈 수 없으니 캐슬링의 의도가 성립되는 체스 협회는?
#
# 룩을 먼저 이동 시킬 경우 룩은 주위로 2칸 이상 갈 수 없으니 캐슬링의 의도가 성립되는 체스 협회는?
#
# 룩을 먼저 이동 시킬 경우 룩은 주위로 2칸 이상 갈 수 없으니 캐슬링의 의도가 성립되는 체스 협회는?
#
# 룩을 먼저 이동 시킬 경우 룩은 주위로 2칸 이상 갈 수 없으니 캐슬링의 의도가 성립되는 체스 협회는?
#
# 룩을 먼저 이동 시킬 경우 룩은 주위로 2칸 이상 갈 수 없으니 캐슬링의 의도가 성립되는 체스 협회는?
#
# 룩을 먼저 이동 시킬 경우 룩은 주위로 2칸 이상 갈 수 없으니 캐슬링의 의도가 성립되는 체스 협회는?
#
# 룩을 먼저 이동 시킬 경우 룩은 주위로 2칸 이상 갈 수 없으니 캐슬링의 의도가 성립되는 체스 협회는?
#
# 룩을 먼저 이동 시킬 경우 룩은 주위로 2칸 이상 갈 수 없으니 캐슬링의 의도가 성립되는 체스 협회는?
#
# 토너먼트 경기는 일반적으로 타임 컨트롤이라고 불리는 시간제한 안에서 이루어지는가?
#
# 토너먼트 경기는 일반적으로 타임 컨트롤이라고 불리는 시간제한 안에서 이루어지는가?
#
# 토너먼트 경기는 일반적으로 타임 컨트롤이라고 불리는 시간제한 안에서 이루어지는가?
#
# 토너먼트 경기는 일반적으로 타임 컨트롤이라고 불리는 시간제한 안에서 이루어지는가?
#
# USCF에서 체크메이트 할 가능성으로 판단하는 것은?
#
# USCF에서 체크메이트 할 가능성으로 판단하는 것은?
#
# USCF에서 체크메이트 할 가능성으로 판단하는 것은?
#
# USCF에서 체크메이트 할 가능성으로 판단하는 것은?
#
# USCF에서 체크메이트 할 가능성으로 판단하는 것은?
#
# 랭크마다 1부터 8까지의 숫자가 붙어있는 체스보드는?
#
# 랭크마다 1부터 8까지의 숫자가 붙어있는 체스보드는?
#
# 랭크마다 1부터 8까지의 숫자가 붙어있는 체스보드는?
#
# 랭크마다 1부터 8까지의 숫자가 붙어있는 체스보드는?
#
# 랭크마다 1부터 8까지의 숫자가 붙어있는 체스보드는?
#
# 랭크마다 1부터 8까지의 숫자가 붙어있는 체스보드는?
#
# 랭크마다 1부터 8까지의 숫자가 붙어있는 체스보드는?
#
# sep게임 도중 게임의 시작 포지션이 규칙에 어긋나 있었다는 사실이 발견되면 게임은 재시작되는 것은?
#
# sep게임 도중 게임의 시작 포지션이 규칙에 어긋나 있었다는 사실이 발견되면 게임은 재시작되는 것은?
#
# sep게임 도중 게임의 시작 포지션이 규칙에 어긋나 있었다는 사실이 발견되면 게임은 재시작되는 것은?
#
# sep게임 도중 게임의 시작 포지션이 규칙에 어긋나 있었다는 사실이 발견되면 게임은 재시작되는 것은?
#
# 정사각형의 한 변의 길이는?
#
# 정사각형의 한 변의 길이는?
#
# 정사각형의 한 변의 길이는?
#
# 정사각형의 한 변의 길이는?
#
# 정사각형의 한 변의 길이는?
#
# 정사각형의 한 변의 길이는?
#
# 정사각형의 한 변의 길이는?
#
# 퀸이 모든 방향의 대각선으로 움직일 수 있는 것은?
#
# 퀸이 모든 방향의 대각선으로 움직일 수 있는 것은?
#
# 퀸이 모든 방향의 대각선으로 움직일 수 있는 것은?
#
# 퀸이 모든 방향의 대각선으로 움직일 수 있는 것은?
#
# 퀸이 모든 방향의 대각선으로 움직일 수 있는 것은?
#
# 퀸이 모든 방향의 대각선으로 움직일 수 있는 것은?
#
# 퀸이 모든 방향의 대각선으로 움직일 수 있는 것은?
#
# 티베트 고원의 남부 및 동부 경계의 한 해 평균 강수량은?
#
# 티베트 고원의 남부 및 동부 경계의 한 해 평균 강수량은?
#
# 티베트 고원의 남부 및 동부 경계의 한 해 평균 강수량은?
#
# 티베트 고원의 남부 및 동부 경계의 한 해 평균 강수량은?
#
# 티베트 고원의 남부 및 동부 경계의 한 해 평균 강수량은?
#
# 티베트 고원의 남부 및 동부 경계의 한 해 평균 강수량은?
#
# 티베트 고원의 남부 및 동부 경계의 한 해 평균 강수량은?
#
# 커커시리는 극한의 환경으로 인하여, 전 세계적으로 남극대륙과 북쪽의 그린란드 다음인 세 번째로 인구밀도가 희박한 지역으로 잘 알려져있다.
#
# 커커시리는 극한의 환경으로 인하여, 전 세계적으로 남극대륙과 북쪽의 그린란드 다음인 세 번째로 인구밀도가 희박한 지역으로 잘 알려져있다.
#
# 커커시리는 극한의 환경으로 인하여, 전 세계적으로 남극대륙과 북쪽의 그린란드 다음인 세 번째로 인구밀도가 희박한 지역으로 잘 알려져있다.
#
# 커커시리는 극한의 환경으로 인하여, 전 세계적으로 남극대륙과 북쪽의 그린란드 다음인 세 번째로 인구밀도가 희박한 지역으로 잘 알려져있다.
#
# 커커시리는 극한의 환경으로 인하여, 전 세계적으로 남극대륙과 북쪽의 그린란드 다음인 세 번째로 인구밀도가 희박한 지역으로 잘 알려져있다.
#
# 커커시리는 극한의 환경으로 인하여, 전 세계적으로 남극대륙과 북쪽의 그린란드 다음인 세 번째로 인구밀도가 희박한 지역으로 잘 알려져있다.
#
# 커커시리는 극한의 환경으로 인하여, 전 세계적으로 남극대륙과 북쪽의 그린란드 다음인 세 번째로 인구밀도가 희박한 지역으로 잘 알려져있다.
#
# 티베트 고원이 형성되면서 상당한 기후 패턴의 변화가 있었으며, 이것이 아시아 열대 몬순에 영향을 주었다고 생각되는 것은?
#
# 티베트 고원이 형성되면서 상당한 기후 패턴의 변화가 있었으며, 이것이 아시아 열대 몬순에 영향을 주었다고 생각되는 것은?
#
# 티베트 고원이 형성되면서 상당한 기후 패턴의 변화가 있었으며, 이것이 아시아 열대 몬순에 영향을 주었다고 생각되는 것은?
#
# 티베트 고원이 형성되면서 상당한 기후 패턴의 변화가 있었으며, 이것이 아시아 열대 몬순에 영향을 주었다고 생각되는 것은?
#
# 티베트 고원이 형성되면서 상당한 기후 패턴의 변화가 있었으며, 이것이 아시아 열대 몬순에 영향을 주었다고 생각되는 것은?
#
# 티베트 고원이 형성되면서 상당한 기후 패턴의 변화가 있었으며, 이것이 아시아 열대 몬순에 영향을 주었다고 생각되는 것은?
#
# 티베트 고원이 형성되면서 상당한 기후 패턴의 변화가 있었으며, 이것이 아시아 열대 몬순에 영향을 주었다고 생각되는 것은?
#
# 티베트 고원이 형성되면서 상당한 기후 패턴의 변화가 있었으며, 이것이 아시아 열대 몬순에 영향을 주었다고 생각되는 것은?
#
# 김정남이 국가안전보위부 제1차장에 임명된 시기는?
#
# 김정남이 국가안전보위부 제1차장에 임명된 시기는?
#
# 김정남이 국가안전보위부 제1차장에 임명된 시기는?
#
# 김정남이 국가안전보위부 제1차장에 임명된 시기는?
#
# 김정남이 국가안전보위부 제1차장에 임명된 시기는?
#
# 김정남이 국가안전보위부 제1차장에 임명된 시기는?
#
# 김정남이 국가안전보위부 제1차장에 임명된 시기는?
#
# 김정남 암살은 언제 진행되었는가?
#
# 김정남 암살은 언제 진행되었는가?
#
# 김정남 암살은 언제 진행되었는가?
#
# 김정남 암살은 언제 진행되었는가?
#
# 김정남 암살은 언제 진행되었는가?
#
# 김정남 암살은 언제 진행되었는가?
#
# 김정남 암살은 언제 진행되었는가?
#
# 김정남 암살은 언제 진행되었는가?
#
# 박형식이 출연한 쥬얼리S의 뮤직비디오는?
#
# 박형식이 출연한 쥬얼리S의 뮤직비디오는?
#
# 박형식이 출연한 쥬얼리S의 뮤직비디오는?
#
# 박형식이 출연한 쥬얼리S의 뮤직비디오는?
#
# 박형식이 출연한 쥬얼리S의 뮤직비디오는?
#
# 박형식이 출연한 쥬얼리S의 뮤직비디오는?
#
# 박형식이 출연한 쥬얼리S의 뮤직비디오는?
#
# 박형식이 출연한 쥬얼리S의 뮤직비디오는?
#
# 증강현실은 현실 세계에 가상의 물체를 중첩하여 현실 세계를 보충하여 사용자에게 보여 준다는 특징이 있는가?
#
# 증강현실은 현실 세계에 가상의 물체를 중첩하여 현실 세계를 보충하여 사용자에게 보여 준다는 특징이 있는가?
#
# 증강현실은 현실 세계에 가상의 물체를 중첩하여 현실 세계를 보충하여 사용자에게 보여 준다는 특징이 있는가?
#
# 증강현실은 현실 세계에 가상의 물체를 중첩하여 현실 세계를 보충하여 사용자에게 보여 준다는 특징이 있는가?
#
# 증강현실은 현실 세계에 가상의 물체를 중첩하여 현실 세계를 보충하여 사용자에게 보여 준다는 특징이 있는가?
#
# 증강현실은 현실 세계에 가상의 물체를 중첩하여 현실 세계를 보충하여 사용자에게 보여 준다는 특징이 있는가?
#
# 증강현실은 현실 세계에 가상의 물체를 중첩하여 현실 세계를 보충하여 사용자에게 보여 준다는 특징이 있는가?
#
# 방술에서의 역산은 사회에 큰 영향을 미치는 학문 중 하나인가?
#
# 방술에서의 역산은 사회에 큰 영향을 미치는 학문 중 하나인가?
#
# 방술에서의 역산은 사회에 큰 영향을 미치는 학문 중 하나인가?
#
# 방술에서의 역산은 사회에 큰 영향을 미치는 학문 중 하나인가?
#
# 태음태양력의 달이 차고 지는 것은 차츰 시간이 가면서 계절과 맞지 않기 때문인가?
#
# 태음태양력의 달이 차고 지는 것은 차츰 시간이 가면서 계절과 맞지 않기 때문인가?
#
# 태음태양력의 달이 차고 지는 것은 차츰 시간이 가면서 계절과 맞지 않기 때문인가?
#
# 태음태양력의 달이 차고 지는 것은 차츰 시간이 가면서 계절과 맞지 않기 때문인가?
#
# 태음태양력의 달이 차고 지는 것은 차츰 시간이 가면서 계절과 맞지 않기 때문인가?
#
# 태음태양력의 달이 차고 지는 것은 차츰 시간이 가면서 계절과 맞지 않기 때문인가?
#
# sep달력을 제작할 때에 기초가 되는 계산법과 천문상수의 체계를 역법이라고 하는 것은?
#
# sep달력을 제작할 때에 기초가 되는 계산법과 천문상수의 체계를 역법이라고 하는 것은?
#
# sep달력을 제작할 때에 기초가 되는 계산법과 천문상수의 체계를 역법이라고 하는 것은?
#
# sep달력을 제작할 때에 기초가 되는 계산법과 천문상수의 체계를 역법이라고 하는 것은?
#
# sep달력을 제작할 때에 기초가 되는 계산법과 천문상수의 체계를 역법이라고 하는 것은?
#
# sep달력을 제작할 때에 기초가 되는 계산법과 천문상수의 체계를 역법이라고 하는 것은?
#
# sep달력을 제작할 때에 기초가 되는 계산법과 천문상수의 체계를 역법이라고 하는 것은?
#
# sep달력을 제작할 때에 기초가 되는 계산법과 천문상수의 체계를 역법이라고 하는 것은?
#
# sep달력을 제작할 때에 기초가 되는 계산법과 천문상수의 체계를 역법이라고 하는 것은?
#
# 태양과 달의 운행을 연구한 결과 달의 운행 속도가 일정하지 않다는 것을 발견하게 된 시기는?
#
# 태양과 달의 운행을 연구한 결과 달의 운행 속도가 일정하지 않다는 것을 발견하게 된 시기는?
#
# 태양과 달의 운행을 연구한 결과 달의 운행 속도가 일정하지 않다는 것을 발견하게 된 시기는?
#
# 태양과 달의 운행을 연구한 결과 달의 운행 속도가 일정하지 않다는 것을 발견하게 된 시기는?
#
# 태양과 달의 운행을 연구한 결과 달의 운행 속도가 일정하지 않다는 것을 발견하게 된 시기는?
#
# 태양과 달의 운행을 연구한 결과 달의 운행 속도가 일정하지 않다는 것을 발견하게 된 시기는?
#
# 태양과 달의 운행을 연구한 결과 달의 운행 속도가 일정하지 않다는 것을 발견하게 된 시기는?
#
# 황극력이 만들어져 수나라가 망할 때까지 시행된 시기는?
#
# 황극력이 만들어져 수나라가 망할 때까지 시행된 시기는?
#
# 황극력이 만들어져 수나라가 망할 때까지 시행된 시기는?
#
# 황극력이 만들어져 수나라가 망할 때까지 시행된 시기는?
#
# 황극력이 만들어져 수나라가 망할 때까지 시행된 시기는?
#
# 황극력이 만들어져 수나라가 망할 때까지 시행된 시기는?
#
# 황극력이 만들어져 수나라가 망할 때까지 시행된 시기는?
#
# 원나라 세조가 왕순과 곽수경에게 개력을 명령한 시기는?
#
# 원나라 세조가 왕순과 곽수경에게 개력을 명령한 시기는?
#
# 원나라 세조가 왕순과 곽수경에게 개력을 명령한 시기는?
#
# 원나라 세조가 왕순과 곽수경에게 개력을 명령한 시기는?
#
# 원나라 세조가 왕순과 곽수경에게 개력을 명령한 시기는?
#
# 원나라 세조가 왕순과 곽수경에게 개력을 명령한 시기는?
#
# 원나라 세조가 왕순과 곽수경에게 개력을 명령한 시기는?
#
# 소토마요르가 아테네에서 열린 대회에서 자신의 새기록 2.37m를 수립한 것은 언제인가?
#
# 소토마요르가 아테네에서 열린 대회에서 자신의 새기록 2.37m를 수립한 것은 언제인가?
#
# 소토마요르가 아테네에서 열린 대회에서 자신의 새기록 2.37m를 수립한 것은 언제인가?
#
# 소토마요르가 아테네에서 열린 대회에서 자신의 새기록 2.37m를 수립한 것은 언제인가?
#
# 소토마요르가 아테네에서 열린 대회에서 자신의 새기록 2.37m를 수립한 것은 언제인가?
#
# 소토마요르가 아테네에서 열린 대회에서 자신의 새기록 2.37m를 수립한 것은 언제인가?
#
# 소토마요르가 아테네에서 열린 대회에서 자신의 새기록 2.37m를 수립한 것은 언제인가?
#
# 소토마요르가 아테네에서 열린 대회에서 자신의 새기록 2.37m를 수립한 것은 언제인가?
#
# 소토마요르가 세계 실내 선수권 대회에서 자신의 시초적인 시도를 놓치다가 두 번째 시도에서 제거한 것은?
#
# 소토마요르가 세계 실내 선수권 대회에서 자신의 시초적인 시도를 놓치다가 두 번째 시도에서 제거한 것은?
#
# 소토마요르가 세계 실내 선수권 대회에서 자신의 시초적인 시도를 놓치다가 두 번째 시도에서 제거한 것은?
#
# 소토마요르가 세계 실내 선수권 대회에서 자신의 시초적인 시도를 놓치다가 두 번째 시도에서 제거한 것은?
#
# 소토마요르가 세계 실내 선수권 대회에서 자신의 시초적인 시도를 놓치다가 두 번째 시도에서 제거한 것은?
#
# 소토마요르가 세계 실내 선수권 대회에서 자신의 시초적인 시도를 놓치다가 두 번째 시도에서 제거한 것은?
#
# 바르셀로나 올림픽에서 소토마요르가 우승 선수로 선언된 것은 누구인가?
#
# 바르셀로나 올림픽에서 소토마요르가 우승 선수로 선언된 것은 누구인가?
#
# 바르셀로나 올림픽에서 소토마요르가 우승 선수로 선언된 것은 누구인가?
#
# 바르셀로나 올림픽에서 소토마요르가 우승 선수로 선언된 것은 누구인가?
#
# 바르셀로나 올림픽에서 소토마요르가 우승 선수로 선언된 것은 누구인가?
#
# 바르셀로나 올림픽에서 소토마요르가 우승 선수로 선언된 것은 누구인가?
#
# 바르셀로나 올림픽에서 소토마요르가 우승 선수로 선언된 것은 누구인가?
#
# 소토마요르는 1996년 애틀랜타 올림픽에서 무엇을 유지하려는 시도를 하였는가?
#
# 소토마요르는 1996년 애틀랜타 올림픽에서 무엇을 유지하려는 시도를 하였는가?
#
# 소토마요르는 1996년 애틀랜타 올림픽에서 무엇을 유지하려는 시도를 하였는가?
#
# 소토마요르는 1996년 애틀랜타 올림픽에서 무엇을 유지하려는 시도를 하였는가?
#
# 소토마요르는 1996년 애틀랜타 올림픽에서 무엇을 유지하려는 시도를 하였는가?
#
# 소토마요르는 1996년 애틀랜타 올림픽에서 무엇을 유지하려는 시도를 하였는가?
#
# 소토마요르는 1996년 애틀랜타 올림픽에서 무엇을 유지하려는 시도를 하였는가?
#
# 비바람이 몰아친 9월 24일에 열린 남자 높이뛰기 시합은?
#
# 비바람이 몰아친 9월 24일에 열린 남자 높이뛰기 시합은?
#
# 비바람이 몰아친 9월 24일에 열린 남자 높이뛰기 시합은?
#
# 비바람이 몰아친 9월 24일에 열린 남자 높이뛰기 시합은?
#
# 비바람이 몰아친 9월 24일에 열린 남자 높이뛰기 시합은?
#
# 비바람이 몰아친 9월 24일에 열린 남자 높이뛰기 시합은?
#
# 비바람이 몰아친 9월 24일에 열린 남자 높이뛰기 시합은?
#
# 싸이버스카이는 2014년 매출 49억300만 원을 거뒀는데 그 중 대한항공과의 내부거래 비중이 81.5%에 이르렀던 회사는?
#
# 싸이버스카이는 2014년 매출 49억300만 원을 거뒀는데 그 중 대한항공과의 내부거래 비중이 81.5%에 이르렀던 회사는?
#
# 싸이버스카이는 2014년 매출 49억300만 원을 거뒀는데 그 중 대한항공과의 내부거래 비중이 81.5%에 이르렀던 회사는?
#
# 싸이버스카이는 2014년 매출 49억300만 원을 거뒀는데 그 중 대한항공과의 내부거래 비중이 81.5%에 이르렀던 회사는?
#
# 싸이버스카이는 2014년 매출 49억300만 원을 거뒀는데 그 중 대한항공과의 내부거래 비중이 81.5%에 이르렀던 회사는?
#
# 싸이버스카이는 2014년 매출 49억300만 원을 거뒀는데 그 중 대한항공과의 내부거래 비중이 81.5%에 이르렀던 회사는?
#
# 싸이버스카이는 2014년 매출 49억300만 원을 거뒀는데 그 중 대한항공과의 내부거래 비중이 81.5%에 이르렀던 회사는?
#
# 싸이버스카이는 2014년 매출 49억300만 원을 거뒀는데 그 중 대한항공과의 내부거래 비중이 81.5%에 이르렀던 회사는?
#
# 5ᆞ16 군사쿠데타를 지적하는 새누리당 함진규 의원의 지적에 안 맡았으면 좋았을 재판이라고 한 사람은?
#
# 5ᆞ16 군사쿠데타를 지적하는 새누리당 함진규 의원의 지적에 안 맡았으면 좋았을 재판이라고 한 사람은?
#
# 5ᆞ16 군사쿠데타를 지적하는 새누리당 함진규 의원의 지적에 안 맡았으면 좋았을 재판이라고 한 사람은?
#
# 5ᆞ16 군사쿠데타를 지적하는 새누리당 함진규 의원의 지적에 안 맡았으면 좋았을 재판이라고 한 사람은?
#
# 5ᆞ16 군사쿠데타를 지적하는 새누리당 함진규 의원의 지적에 안 맡았으면 좋았을 재판이라고 한 사람은?
#
# 5ᆞ16 군사쿠데타를 지적하는 새누리당 함진규 의원의 지적에 안 맡았으면 좋았을 재판이라고 한 사람은?
#
# 5ᆞ16 군사쿠데타를 지적하는 새누리당 함진규 의원의 지적에 안 맡았으면 좋았을 재판이라고 한 사람은?
#
# 5ᆞ16 군사쿠데타를 지적하는 새누리당 함진규 의원의 지적에 안 맡았으면 좋았을 재판이라고 한 사람은?
#
# 5ᆞ16 군사쿠데타를 지적하는 새누리당 함진규 의원의 지적에 안 맡았으면 좋았을 재판이라고 한 사람은?
#
# 김이수가 헌법재판소장으로 지명된 해는?
#
# 김이수가 헌법재판소장으로 지명된 해는?
#
# 김이수가 헌법재판소장으로 지명된 해는?
#
# 김이수가 헌법재판소장으로 지명된 해는?
#
# 김이수가 헌법재판소장으로 지명된 해는?
#
# 김이수가 헌법재판소장으로 지명된 해는?
#
# 김이수가 헌법재판소장으로 지명된 해는?
#
# 김이수가 헌법재판소장으로 지명된 해는?
#
# 회현동 관사는 벽돌로 지었는데, 이 아파트는 콘크리트 자재를 썼고 4층 높이에 외관도 현대식으로 설계된것은?
#
# 회현동 관사는 벽돌로 지었는데, 이 아파트는 콘크리트 자재를 썼고 4층 높이에 외관도 현대식으로 설계된것은?
#
# 회현동 관사는 벽돌로 지었는데, 이 아파트는 콘크리트 자재를 썼고 4층 높이에 외관도 현대식으로 설계된것은?
#
# 회현동 관사는 벽돌로 지었는데, 이 아파트는 콘크리트 자재를 썼고 4층 높이에 외관도 현대식으로 설계된것은?
#
# 회현동 관사는 벽돌로 지었는데, 이 아파트는 콘크리트 자재를 썼고 4층 높이에 외관도 현대식으로 설계된것은?
#
# 회현동 관사는 벽돌로 지었는데, 이 아파트는 콘크리트 자재를 썼고 4층 높이에 외관도 현대식으로 설계된것은?
#
# 회현동 관사는 벽돌로 지었는데, 이 아파트는 콘크리트 자재를 썼고 4층 높이에 외관도 현대식으로 설계된것은?
#
# 회현동 관사는 벽돌로 지었는데, 이 아파트는 콘크리트 자재를 썼고 4층 높이에 외관도 현대식으로 설계된것은?
#
# 조선주택영단이 여러가지 주택 유형을 연구하기 위해 대한민국에 여러 대안을 실현하게 된것은?
#
# 조선주택영단이 여러가지 주택 유형을 연구하기 위해 대한민국에 여러 대안을 실현하게 된것은?
#
# 조선주택영단이 여러가지 주택 유형을 연구하기 위해 대한민국에 여러 대안을 실현하게 된것은?
#
# 조선주택영단이 여러가지 주택 유형을 연구하기 위해 대한민국에 여러 대안을 실현하게 된것은?
#
# 조선주택영단이 여러가지 주택 유형을 연구하기 위해 대한민국에 여러 대안을 실현하게 된것은?
#
# 조선주택영단이 여러가지 주택 유형을 연구하기 위해 대한민국에 여러 대안을 실현하게 된것은?
#
# 조선주택영단이 여러가지 주택 유형을 연구하기 위해 대한민국에 여러 대안을 실현하게 된것은?
#
# 청풍장-소화장아파트의 부지가 작아 재개발이 시행되지 않고 있는 이유는?
#
# 청풍장-소화장아파트의 부지가 작아 재개발이 시행되지 않고 있는 이유는?
#
# 청풍장-소화장아파트의 부지가 작아 재개발이 시행되지 않고 있는 이유는?
#
# 청풍장-소화장아파트의 부지가 작아 재개발이 시행되지 않고 있는 이유는?
#
# 청풍장-소화장아파트의 부지가 작아 재개발이 시행되지 않고 있는 이유는?
#
# 청풍장-소화장아파트의 부지가 작아 재개발이 시행되지 않고 있는 이유는?
#
# 청풍장-소화장아파트의 부지가 작아 재개발이 시행되지 않고 있는 이유는?
#
# 엘리베이터 가동용 전기와 건설비용을 절약하기 위해 건설한 아파트의 이름은?
#
# 엘리베이터 가동용 전기와 건설비용을 절약하기 위해 건설한 아파트의 이름은?
#
# 엘리베이터 가동용 전기와 건설비용을 절약하기 위해 건설한 아파트의 이름은?
#
# 충정아파트와 함께 서울속 미래유산으로 지정된 아파트의 이름은?
#
# 충정아파트와 함께 서울속 미래유산으로 지정된 아파트의 이름은?
#
# 충정아파트와 함께 서울속 미래유산으로 지정된 아파트의 이름은?
#
# 충정아파트와 함께 서울속 미래유산으로 지정된 아파트의 이름은?
#
# 충정아파트와 함께 서울속 미래유산으로 지정된 아파트의 이름은?
#
# 충정아파트와 함께 서울속 미래유산으로 지정된 아파트의 이름은?
#
# 충정아파트와 함께 서울속 미래유산으로 지정된 아파트의 이름은?
#
# 세운상가가 세워진 연도는?
#
# 세운상가가 세워진 연도는?
#
# 세운상가가 세워진 연도는?
#
# 세운상가가 세워진 연도는?
#
# 세운상가가 세워진 연도는?
#
# 세운상가가 세워진 연도는?
#
# 세운상가가 세워진 연도는?
#
# 힐탑아파트의 외벽은 어떤 마감재를 사용하였는가?
#
# 힐탑아파트의 외벽은 어떤 마감재를 사용하였는가?
#
# 힐탑아파트의 외벽은 어떤 마감재를 사용하였는가?
#
# 힐탑아파트의 외벽은 어떤 마감재를 사용하였는가?
#
# 힐탑아파트의 외벽은 어떤 마감재를 사용하였는가?
#
# 힐탑아파트의 외벽은 어떤 마감재를 사용하였는가?
#
# 힐탑아파트의 외벽은 어떤 마감재를 사용하였는가?
#
# 남산외인아파트가 남산을 가로막는다는 이유로 1994년 철거된 곳은?
#
# 남산외인아파트가 남산을 가로막는다는 이유로 1994년 철거된 곳은?
#
# 남산외인아파트가 남산을 가로막는다는 이유로 1994년 철거된 곳은?
#
# 남산외인아파트가 남산을 가로막는다는 이유로 1994년 철거된 곳은?
#
# 남산외인아파트가 남산을 가로막는다는 이유로 1994년 철거된 곳은?
#
# 남산외인아파트가 남산을 가로막는다는 이유로 1994년 철거된 곳은?
#
# 남산외인아파트가 남산을 가로막는다는 이유로 1994년 철거된 곳은?
#
# 와우시민아파트 건립을 추진한 시기는?
#
# 와우시민아파트 건립을 추진한 시기는?
#
# 와우시민아파트 건립을 추진한 시기는?
#
# 와우시민아파트 건립을 추진한 시기는?
#
# 와우시민아파트 건립을 추진한 시기는?
#
# 와우시민아파트 건립을 추진한 시기는?
#
# 와우시민아파트 건립을 추진한 시기는?
#
# 회현 제2시민아파트는 어떤 이름으로 지어졌는가?
#
# 회현 제2시민아파트는 어떤 이름으로 지어졌는가?
#
# 회현 제2시민아파트는 어떤 이름으로 지어졌는가?
#
# 회현 제2시민아파트는 어떤 이름으로 지어졌는가?
#
# 회현 제2시민아파트는 어떤 이름으로 지어졌는가?
#
# 회현 제2시민아파트는 어떤 이름으로 지어졌는가?
#
# 회현 제2시민아파트는 어떤 이름으로 지어졌는가?
#
# 여의도에 고층아파트 단지를 지어 보급한다는 계획을 세운 시기는?
#
# 여의도에 고층아파트 단지를 지어 보급한다는 계획을 세운 시기는?
#
# 여의도에 고층아파트 단지를 지어 보급한다는 계획을 세운 시기는?
#
# 여의도에 고층아파트 단지를 지어 보급한다는 계획을 세운 시기는?
#
# 여의도에 고층아파트 단지를 지어 보급한다는 계획을 세운 시기는?
#
# 여의도에 고층아파트 단지를 지어 보급한다는 계획을 세운 시기는?
#
# 여의도에 고층아파트 단지를 지어 보급한다는 계획을 세운 시기는?
#
# 서소문아파트가 미래유산으로 지정된 년도는?
#
# 서소문아파트가 미래유산으로 지정된 년도는?
#
# 서소문아파트가 미래유산으로 지정된 년도는?
#
# 서소문아파트가 미래유산으로 지정된 년도는?
#
# 서소문아파트가 미래유산으로 지정된 년도는?
#
# 서소문아파트가 미래유산으로 지정된 년도는?
#
# 서소문아파트가 미래유산으로 지정된 년도는?
#
# 성요셉 아파트의 특이한 건물형태로 인해 민간에 매각된 아파트는?
#
# 성요셉 아파트의 특이한 건물형태로 인해 민간에 매각된 아파트는?
#
# 성요셉 아파트의 특이한 건물형태로 인해 민간에 매각된 아파트는?
#
# 성요셉 아파트의 특이한 건물형태로 인해 민간에 매각된 아파트는?
#
# 성요셉 아파트의 특이한 건물형태로 인해 민간에 매각된 아파트는?
#
# 성요셉 아파트의 특이한 건물형태로 인해 민간에 매각된 아파트는?
#
# 성요셉 아파트의 특이한 건물형태로 인해 민간에 매각된 아파트는?
#
# 반포주공아파트가 강남과 더불어 대한민국을 '아파트공화국'으로 만드는데 큰 역할을 한 것은?
#
# 반포주공아파트가 강남과 더불어 대한민국을 '아파트공화국'으로 만드는데 큰 역할을 한 것은?
#
# 반포주공아파트가 강남과 더불어 대한민국을 '아파트공화국'으로 만드는데 큰 역할을 한 것은?
#
# 반포주공아파트가 강남과 더불어 대한민국을 '아파트공화국'으로 만드는데 큰 역할을 한 것은?
#
# 반포주공아파트가 강남과 더불어 대한민국을 '아파트공화국'으로 만드는데 큰 역할을 한 것은?
#
# 반포주공아파트가 강남과 더불어 대한민국을 '아파트공화국'으로 만드는데 큰 역할을 한 것은?
#
# 반포주공아파트가 강남과 더불어 대한민국을 '아파트공화국'으로 만드는데 큰 역할을 한 것은?
#
# 현대건설이 지은 주공아파트의 이름은?
#
# 현대건설이 지은 주공아파트의 이름은?
#
# 현대건설이 지은 주공아파트의 이름은?
#
# 현대건설이 지은 주공아파트의 이름은?
#
# 현대건설이 지은 주공아파트의 이름은?
#
# 현대건설이 지은 주공아파트의 이름은?
#
# 현대건설이 지은 주공아파트의 이름은?
#
# 현대산업개발에서 건설한 아파트단지의 이름은?
#
# 현대산업개발에서 건설한 아파트단지의 이름은?
#
# 현대산업개발에서 건설한 아파트단지의 이름은?
#
# 현대산업개발에서 건설한 아파트단지의 이름은?
#
# 현대산업개발에서 건설한 아파트단지의 이름은?
#
# 현대산업개발에서 건설한 아파트단지의 이름은?
#
# 현대산업개발에서 건설한 아파트단지의 이름은?
#
# 서울시는 어떤년도의 아파트 인증제 도입을 추진한다고 보도하였는가?
#
# 서울시는 어떤년도의 아파트 인증제 도입을 추진한다고 보도하였는가?
#
# 서울시는 어떤년도의 아파트 인증제 도입을 추진한다고 보도하였는가?
#
# 서울시는 어떤년도의 아파트 인증제 도입을 추진한다고 보도하였는가?
#
# 서울시는 어떤년도의 아파트 인증제 도입을 추진한다고 보도하였는가?
#
# 서울시는 어떤년도의 아파트 인증제 도입을 추진한다고 보도하였는가?
#
# 서울시는 어떤년도의 아파트 인증제 도입을 추진한다고 보도하였는가?
#
# 은행권·동전과 같은 물질인 방식 아니라 디지털방식으로만 사용될 수 있는 유형의 화폐를 가리키는 용어는?
#
# 은행권·동전과 같은 물질인 방식 아니라 디지털방식으로만 사용될 수 있는 유형의 화폐를 가리키는 용어는?
#
# 은행권·동전과 같은 물질인 방식 아니라 디지털방식으로만 사용될 수 있는 유형의 화폐를 가리키는 용어는?
#
# 은행권·동전과 같은 물질인 방식 아니라 디지털방식으로만 사용될 수 있는 유형의 화폐를 가리키는 용어는?
#
# 은행권·동전과 같은 물질인 방식 아니라 디지털방식으로만 사용될 수 있는 유형의 화폐를 가리키는 용어는?
#
# 은행권·동전과 같은 물질인 방식 아니라 디지털방식으로만 사용될 수 있는 유형의 화폐를 가리키는 용어는?
#
# 은행권·동전과 같은 물질인 방식 아니라 디지털방식으로만 사용될 수 있는 유형의 화폐를 가리키는 용어는?
#
# 유럽중앙은행이 2012년에 가상화폐를 무엇이라 정의하였는가?
#
# 유럽중앙은행이 2012년에 가상화폐를 무엇이라 정의하였는가?
#
# 유럽중앙은행이 2012년에 가상화폐를 무엇이라 정의하였는가?
#
# 유럽중앙은행이 2012년에 가상화폐를 무엇이라 정의하였는가?
#
# 유럽중앙은행이 2012년에 가상화폐를 무엇이라 정의하였는가?
#
# 유럽중앙은행이 2012년에 가상화폐를 무엇이라 정의하였는가?
#
# 유럽중앙은행이 2012년에 가상화폐를 무엇이라 정의하였는가?
#
# 암호화폐가 재화성을 함께 가지는 특수한 지급수단이라 할 수 있는 것은?
#
# 암호화폐가 재화성을 함께 가지는 특수한 지급수단이라 할 수 있는 것은?
#
# 암호화폐가 재화성을 함께 가지는 특수한 지급수단이라 할 수 있는 것은?
#
# 암호화폐가 재화성을 함께 가지는 특수한 지급수단이라 할 수 있는 것은?
#
# 암호화폐가 재화성을 함께 가지는 특수한 지급수단이라 할 수 있는 것은?
#
# 암호화폐가 재화성을 함께 가지는 특수한 지급수단이라 할 수 있는 것은?
#
# 암호화폐가 재화성을 함께 가지는 특수한 지급수단이라 할 수 있는 것은?
#
# 암호화폐를 발행하고 관리하는 핵심 기법은?
#
# 암호화폐를 발행하고 관리하는 핵심 기법은?
#
# 암호화폐를 발행하고 관리하는 핵심 기법은?
#
# 암호화폐를 발행하고 관리하는 핵심 기법은?
#
# 암호화폐를 발행하고 관리하는 핵심 기법은?
#
# 암호화폐를 발행하고 관리하는 핵심 기법은?
#
# 암호화폐를 발행하고 관리하는 핵심 기법은?
#
# 비트코인을 디지털 화폐로 인정해 제도권으로 끌어들임과 동시에 런던을 디지털 금융의 중심지로 키우는 정책을 채택한 나라는?
#
# 비트코인을 디지털 화폐로 인정해 제도권으로 끌어들임과 동시에 런던을 디지털 금융의 중심지로 키우는 정책을 채택한 나라는?
#
# 비트코인을 디지털 화폐로 인정해 제도권으로 끌어들임과 동시에 런던을 디지털 금융의 중심지로 키우는 정책을 채택한 나라는?
#
# 비트코인을 디지털 화폐로 인정해 제도권으로 끌어들임과 동시에 런던을 디지털 금융의 중심지로 키우는 정책을 채택한 나라는?
#
# 비트코인을 디지털 화폐로 인정해 제도권으로 끌어들임과 동시에 런던을 디지털 금융의 중심지로 키우는 정책을 채택한 나라는?
#
# 비트코인을 디지털 화폐로 인정해 제도권으로 끌어들임과 동시에 런던을 디지털 금융의 중심지로 키우는 정책을 채택한 나라는?
#
# 엑스박스 FS, 엑스박스 넥스트, 넥스트박스 엑스박스 2, 제논 등으로 불린 것은?
#
# 엑스박스 FS, 엑스박스 넥스트, 넥스트박스 엑스박스 2, 제논 등으로 불린 것은?
#
# 엑스박스 FS, 엑스박스 넥스트, 넥스트박스 엑스박스 2, 제논 등으로 불린 것은?
#
# 엑스박스 FS, 엑스박스 넥스트, 넥스트박스 엑스박스 2, 제논 등으로 불린 것은?
#
# 엑스박스 FS, 엑스박스 넥스트, 넥스트박스 엑스박스 2, 제논 등으로 불린 것은?
#
# 엑스박스 FS, 엑스박스 넥스트, 넥스트박스 엑스박스 2, 제논 등으로 불린 것은?
#
# 엑스박스 FS, 엑스박스 넥스트, 넥스트박스 엑스박스 2, 제논 등으로 불린 것은?
#
# 엑스박스 FS, 엑스박스 넥스트, 넥스트박스 엑스박스 2, 제논 등으로 불린 것은?
#
# 엑스박스 360에서 사용할 수 있는 다양한 액세서리를 판매하고 있는 곳은?
#
# 엑스박스 360에서 사용할 수 있는 다양한 액세서리를 판매하고 있는 곳은?
#
# 엑스박스 360에서 사용할 수 있는 다양한 액세서리를 판매하고 있는 곳은?
#
# 엑스박스 360에서 사용할 수 있는 다양한 액세서리를 판매하고 있는 곳은?
#
# GUI 업데이트가 발표된 날짜는?
#
# GUI 업데이트가 발표된 날짜는?
#
# GUI 업데이트가 발표된 날짜는?
#
# GUI 업데이트가 발표된 날짜는?
#
# GUI 업데이트가 발표된 날짜는?
#
# GUI 업데이트가 발표된 날짜는?
#
# GUI 업데이트가 발표된 날짜는?
#
# 엑스박스 라이브 아케이드가 엑스박스 360 소유자에게 제공하는 온라인 서비스는?
#
# 엑스박스 라이브 아케이드가 엑스박스 360 소유자에게 제공하는 온라인 서비스는?
#
# 엑스박스 라이브 아케이드가 엑스박스 360 소유자에게 제공하는 온라인 서비스는?
#
# 엑스박스 라이브 아케이드가 엑스박스 360 소유자에게 제공하는 온라인 서비스는?
#
# 엑스박스 라이브 아케이드가 엑스박스 360 소유자에게 제공하는 온라인 서비스는?
#
# 엑스박스 라이브 아케이드가 엑스박스 360 소유자에게 제공하는 온라인 서비스는?
#
# 비버가 회사의 로고로 선택된 이유는?
#
# 비버가 회사의 로고로 선택된 이유는?
#
# 비버가 회사의 로고로 선택된 이유는?
#
# 비버가 회사의 로고로 선택된 이유는?
#
# 비버가 회사의 로고로 선택된 이유는?
#
# 비버가 회사의 로고로 선택된 이유는?
#
# 비버가 회사의 로고로 선택된 이유는?
#
# 비버가 회사의 로고로 선택된 이유는?
#
# 퀘백 주와 온타리오 주에 있는 공업업자들은 무엇을 통일된 대륙국가를 건설하는 데에 필수적이라고 여겼는가?
#
# 퀘백 주와 온타리오 주에 있는 공업업자들은 무엇을 통일된 대륙국가를 건설하는 데에 필수적이라고 여겼는가?
#
# 퀘백 주와 온타리오 주에 있는 공업업자들은 무엇을 통일된 대륙국가를 건설하는 데에 필수적이라고 여겼는가?
#
# 퀘백 주와 온타리오 주에 있는 공업업자들은 무엇을 통일된 대륙국가를 건설하는 데에 필수적이라고 여겼는가?
#
# 퀘백 주와 온타리오 주에 있는 공업업자들은 무엇을 통일된 대륙국가를 건설하는 데에 필수적이라고 여겼는가?
#
# 퀘백 주와 온타리오 주에 있는 공업업자들은 무엇을 통일된 대륙국가를 건설하는 데에 필수적이라고 여겼는가?
#
# 퀘백 주와 온타리오 주에 있는 공업업자들은 무엇을 통일된 대륙국가를 건설하는 데에 필수적이라고 여겼는가?
#
# 맥도날드가 재집권한 후 새로 집권한 자유당소속 수상인 알렉산더 매캔지는 어떤 구간의 건설을 시작하였는가?
#
# 맥도날드가 재집권한 후 새로 집권한 자유당소속 수상인 알렉산더 매캔지는 어떤 구간의 건설을 시작하였는가?
#
# 맥도날드가 재집권한 후 새로 집권한 자유당소속 수상인 알렉산더 매캔지는 어떤 구간의 건설을 시작하였는가?
#
# 맥도날드가 재집권한 후 새로 집권한 자유당소속 수상인 알렉산더 매캔지는 어떤 구간의 건설을 시작하였는가?
#
# 맥도날드가 재집권한 후 새로 집권한 자유당소속 수상인 알렉산더 매캔지는 어떤 구간의 건설을 시작하였는가?
#
# 지몬 장군이 계속 아이케 장군과 연락을 취했던 이유는?
#
# 지몬 장군이 계속 아이케 장군과 연락을 취했던 이유는?
#
# 지몬 장군이 계속 아이케 장군과 연락을 취했던 이유는?
#
# 지몬 장군이 계속 아이케 장군과 연락을 취했던 이유는?
#
# 지몬 장군이 계속 아이케 장군과 연락을 취했던 이유는?
#
# 지몬 장군이 계속 아이케 장군과 연락을 취했던 이유는?
#
# 지몬 장군이 계속 아이케 장군과 연락을 취했던 이유는?
#
# 아이케 장군이 지휘권을 인수한 10월부터 이듬해 2월까지 사단이 프랑스에 머물렀던 시기는?
#
# 아이케 장군이 지휘권을 인수한 10월부터 이듬해 2월까지 사단이 프랑스에 머물렀던 시기는?
#
# 아이케 장군이 지휘권을 인수한 10월부터 이듬해 2월까지 사단이 프랑스에 머물렀던 시기는?
#
# 아이케 장군이 지휘권을 인수한 10월부터 이듬해 2월까지 사단이 프랑스에 머물렀던 시기는?
#
# 아이케 장군이 지휘권을 인수한 10월부터 이듬해 2월까지 사단이 프랑스에 머물렀던 시기는?
#
# 아이케 장군이 지휘권을 인수한 10월부터 이듬해 2월까지 사단이 프랑스에 머물렀던 시기는?
#
# 아이케 장군이 지휘권을 인수한 10월부터 이듬해 2월까지 사단이 프랑스에 머물렀던 시기는?
#
# 제2차 하리코프 공방전에 참전했던 군단의 사단장은 누구인가?
#
# 제2차 하리코프 공방전에 참전했던 군단의 사단장은 누구인가?
#
# 제2차 하리코프 공방전에 참전했던 군단의 사단장은 누구인가?
#
# 제2차 하리코프 공방전에 참전했던 군단의 사단장은 누구인가?
#
# 제2차 하리코프 공방전에 참전했던 군단의 사단장은 누구인가?
#
# 제2차 하리코프 공방전에 참전했던 군단의 사단장은 누구인가?
#
# 제2차 하리코프 공방전에 참전했던 군단의 사단장은 누구인가?
#
# 허도환이 퓨처스 리그에 내려가서 4번 타자 및 포수로 출전한한 것은 언제인가?
#
# 허도환이 퓨처스 리그에 내려가서 4번 타자 및 포수로 출전한한 것은 언제인가?
#
# 허도환이 퓨처스 리그에 내려가서 4번 타자 및 포수로 출전한한 것은 언제인가?
#
# 허도환이 퓨처스 리그에 내려가서 4번 타자 및 포수로 출전한한 것은 언제인가?
#
# 허도환이 퓨처스 리그에 내려가서 4번 타자 및 포수로 출전한한 것은 언제인가?
#
# 허도환이 퓨처스 리그에 내려가서 4번 타자 및 포수로 출전한한 것은 언제인가?
#
# 기존의 내각 일원을 전면 교체하고 양당이 모두 내각에 참여하는 방향으로 개각하는 방안이 있는가?
#
# 기존의 내각 일원을 전면 교체하고 양당이 모두 내각에 참여하는 방향으로 개각하는 방안이 있는가?
#
# 기존의 내각 일원을 전면 교체하고 양당이 모두 내각에 참여하는 방향으로 개각하는 방안이 있는가?
#
# 기존의 내각 일원을 전면 교체하고 양당이 모두 내각에 참여하는 방향으로 개각하는 방안이 있는가?
#
# 국가의 체제 존립을 위해 의회의 모든 정당이 내각에 참여하는 경우를 무엇이라 하는가?
#
# 국가의 체제 존립을 위해 의회의 모든 정당이 내각에 참여하는 경우를 무엇이라 하는가?
#
# 국가의 체제 존립을 위해 의회의 모든 정당이 내각에 참여하는 경우를 무엇이라 하는가?
#
# 국가의 체제 존립을 위해 의회의 모든 정당이 내각에 참여하는 경우를 무엇이라 하는가?
#
# 국가의 체제 존립을 위해 의회의 모든 정당이 내각에 참여하는 경우를 무엇이라 하는가?
#
# 국가의 체제 존립을 위해 의회의 모든 정당이 내각에 참여하는 경우를 무엇이라 하는가?
#
# 국가의 체제 존립을 위해 의회의 모든 정당이 내각에 참여하는 경우를 무엇이라 하는가?
#
# 일본군 하사관 출신의 송요찬과 일본군 준위출신의 최경록의 후일 육군참모총장이 된 인물은?
#
# 일본군 하사관 출신의 송요찬과 일본군 준위출신의 최경록의 후일 육군참모총장이 된 인물은?
#
# 일본군 하사관 출신의 송요찬과 일본군 준위출신의 최경록의 후일 육군참모총장이 된 인물은?
#
# 일본군 하사관 출신의 송요찬과 일본군 준위출신의 최경록의 후일 육군참모총장이 된 인물은?
#
# 일본군 하사관 출신의 송요찬과 일본군 준위출신의 최경록의 후일 육군참모총장이 된 인물은?
#
# 일본군 하사관 출신의 송요찬과 일본군 준위출신의 최경록의 후일 육군참모총장이 된 인물은?
#
# 일본군 하사관 출신의 송요찬과 일본군 준위출신의 최경록의 후일 육군참모총장이 된 인물은?
#
# 일본군 하사관 출신의 송요찬과 일본군 준위출신의 최경록의 후일 육군참모총장이 된 인물은?
#
# 천안함 피격 사건은 2010년 3월 26일에 백령도 근처 해상에서 대한민국 해군의 초계함인 PCC-772 천안이 피격되어 침몰한 사건이라고 유엔 안전보장이사회의 안건으로 회부된 사건은?
#
# 천안함 피격 사건은 2010년 3월 26일에 백령도 근처 해상에서 대한민국 해군의 초계함인 PCC-772 천안이 피격되어 침몰한 사건이라고 유엔 안전보장이사회의 안건으로 회부된 사건은?
#
# 천안함 피격 사건은 2010년 3월 26일에 백령도 근처 해상에서 대한민국 해군의 초계함인 PCC-772 천안이 피격되어 침몰한 사건이라고 유엔 안전보장이사회의 안건으로 회부된 사건은?
#
# 천안함 피격 사건은 2010년 3월 26일에 백령도 근처 해상에서 대한민국 해군의 초계함인 PCC-772 천안이 피격되어 침몰한 사건이라고 유엔 안전보장이사회의 안건으로 회부된 사건은?
#
# 천안함 피격 사건은 2010년 3월 26일에 백령도 근처 해상에서 대한민국 해군의 초계함인 PCC-772 천안이 피격되어 침몰한 사건이라고 유엔 안전보장이사회의 안건으로 회부된 사건은?
#
# 천안함 피격 사건은 2010년 3월 26일에 백령도 근처 해상에서 대한민국 해군의 초계함인 PCC-772 천안이 피격되어 침몰한 사건이라고 유엔 안전보장이사회의 안건으로 회부된 사건은?
#
# 잠수사들이 선체의 구멍을 조사하기 위해 현장 해역에 긴급 투입된 것은 언제인가?
#
# 잠수사들이 선체의 구멍을 조사하기 위해 현장 해역에 긴급 투입된 것은 언제인가?
#
# 잠수사들이 선체의 구멍을 조사하기 위해 현장 해역에 긴급 투입된 것은 언제인가?
#
# 잠수사들이 선체의 구멍을 조사하기 위해 현장 해역에 긴급 투입된 것은 언제인가?
#
# 잠수사들이 선체의 구멍을 조사하기 위해 현장 해역에 긴급 투입된 것은 언제인가?
#
# 2010년 7월 8일 한겨레 신문은 러시아 소식통을 인용해 조사팀은 무엇에 의한 침몰로 볼 수 없다고 결론 내렸다고 보도하였는가?
#
# 2010년 7월 8일 한겨레 신문은 러시아 소식통을 인용해 조사팀은 무엇에 의한 침몰로 볼 수 없다고 결론 내렸다고 보도하였는가?
#
# 2010년 7월 8일 한겨레 신문은 러시아 소식통을 인용해 조사팀은 무엇에 의한 침몰로 볼 수 없다고 결론 내렸다고 보도하였는가?
#
# 2010년 7월 8일 한겨레 신문은 러시아 소식통을 인용해 조사팀은 무엇에 의한 침몰로 볼 수 없다고 결론 내렸다고 보도하였는가?
#
# 2010년 7월 8일 한겨레 신문은 러시아 소식통을 인용해 조사팀은 무엇에 의한 침몰로 볼 수 없다고 결론 내렸다고 보도하였는가?
#
# 2010년 7월 27일 한겨레의 보도와 관련해, 러시아 대사관측은 아직 조사가 진행 중이라고 밝히며 무엇을 한국 정부에 전달한 사실이 없다고 밝혔는가?
#
# 2010년 7월 27일 한겨레의 보도와 관련해, 러시아 대사관측은 아직 조사가 진행 중이라고 밝히며 무엇을 한국 정부에 전달한 사실이 없다고 밝혔는가?
#
# 2010년 7월 27일 한겨레의 보도와 관련해, 러시아 대사관측은 아직 조사가 진행 중이라고 밝히며 무엇을 한국 정부에 전달한 사실이 없다고 밝혔는가?
#
# 2010년 7월 27일 한겨레의 보도와 관련해, 러시아 대사관측은 아직 조사가 진행 중이라고 밝히며 무엇을 한국 정부에 전달한 사실이 없다고 밝혔는가?
#
# 도널드 그레그 전 주한 미국대사의 이름은?
#
# 도널드 그레그 전 주한 미국대사의 이름은?
#
# 도널드 그레그 전 주한 미국대사의 이름은?
#
# 도널드 그레그 전 주한 미국대사의 이름은?
#
# UN 안보리 의장 성명은 균형 잡히고 객관적이라고 러시아 정부가 판단하고 있는 것은?
#
# UN 안보리 의장 성명은 균형 잡히고 객관적이라고 러시아 정부가 판단하고 있는 것은?
#
# UN 안보리 의장 성명은 균형 잡히고 객관적이라고 러시아 정부가 판단하고 있는 것은?
#
# UN 안보리 의장 성명은 균형 잡히고 객관적이라고 러시아 정부가 판단하고 있는 것은?
#
# UN 안보리 의장 성명은 균형 잡히고 객관적이라고 러시아 정부가 판단하고 있는 것은?
#
# 박길연은 유엔 총회 연설에서 천안함 사건을 이용해 미국과 남한이 한반도와 주변지역에서 무력 군사위협을 벌이는 점을 들어 "미국은 평화의 수호자가 아니라 파괴자라고 비판한 사람은?
#
# 박길연은 유엔 총회 연설에서 천안함 사건을 이용해 미국과 남한이 한반도와 주변지역에서 무력 군사위협을 벌이는 점을 들어 "미국은 평화의 수호자가 아니라 파괴자라고 비판한 사람은?
#
# 박길연은 유엔 총회 연설에서 천안함 사건을 이용해 미국과 남한이 한반도와 주변지역에서 무력 군사위협을 벌이는 점을 들어 "미국은 평화의 수호자가 아니라 파괴자라고 비판한 사람은?
#
# 박길연은 유엔 총회 연설에서 천안함 사건을 이용해 미국과 남한이 한반도와 주변지역에서 무력 군사위협을 벌이는 점을 들어 "미국은 평화의 수호자가 아니라 파괴자라고 비판한 사람은?
#
# 박길연은 유엔 총회 연설에서 천안함 사건을 이용해 미국과 남한이 한반도와 주변지역에서 무력 군사위협을 벌이는 점을 들어 "미국은 평화의 수호자가 아니라 파괴자라고 비판한 사람은?
#
# 기뢰에 의한 사고의 경우 북한이 고의적으로 매설한 기뢰라고 보아 조선민주주의인민공화국의 공격으로 볼 수 있다는 주장으로 나뉜다.
#
# 기뢰에 의한 사고의 경우 북한이 고의적으로 매설한 기뢰라고 보아 조선민주주의인민공화국의 공격으로 볼 수 있다는 주장으로 나뉜다.
#
# 기뢰에 의한 사고의 경우 북한이 고의적으로 매설한 기뢰라고 보아 조선민주주의인민공화국의 공격으로 볼 수 있다는 주장으로 나뉜다.
#
# 기뢰에 의한 사고의 경우 북한이 고의적으로 매설한 기뢰라고 보아 조선민주주의인민공화국의 공격으로 볼 수 있다는 주장으로 나뉜다.
#
# 기뢰에 의한 사고의 경우 북한이 고의적으로 매설한 기뢰라고 보아 조선민주주의인민공화국의 공격으로 볼 수 있다는 주장으로 나뉜다.
#
# 어뢰공격설은 북한 잠수정에 의한 어뢰공격과 인간어뢰에 의한 공격까지 포함하고있는가?
#
# 어뢰공격설은 북한 잠수정에 의한 어뢰공격과 인간어뢰에 의한 공격까지 포함하고있는가?
#
# 어뢰공격설은 북한 잠수정에 의한 어뢰공격과 인간어뢰에 의한 공격까지 포함하고있는가?
#
# 어뢰공격설은 북한 잠수정에 의한 어뢰공격과 인간어뢰에 의한 공격까지 포함하고있는가?
#
# 어뢰공격설은 북한 잠수정에 의한 어뢰공격과 인간어뢰에 의한 공격까지 포함하고있는가?
#
# 백령도 근해에 매설되었으나 미처 제거하지 않은 기뢰에 의해 천안함이 침몰했다는 주장의 근거는?
#
# 백령도 근해에 매설되었으나 미처 제거하지 않은 기뢰에 의해 천안함이 침몰했다는 주장의 근거는?
#
# 박선원 박사는 손석희의 시선집중에 출연하여 무엇을 공개하지 않은 자료는 미국이 다 갖고 있다고 하였는가?
#
# 박선원 박사는 손석희의 시선집중에 출연하여 무엇을 공개하지 않은 자료는 미국이 다 갖고 있다고 하였는가?
#
# 박선원 박사는 손석희의 시선집중에 출연하여 무엇을 공개하지 않은 자료는 미국이 다 갖고 있다고 하였는가?
#
# 박선원 박사는 손석희의 시선집중에 출연하여 무엇을 공개하지 않은 자료는 미국이 다 갖고 있다고 하였는가?
#
# 박선원 박사는 손석희의 시선집중에 출연하여 무엇을 공개하지 않은 자료는 미국이 다 갖고 있다고 하였는가?
#
# 박선원 박사는 손석희의 시선집중에 출연하여 무엇을 공개하지 않은 자료는 미국이 다 갖고 있다고 하였는가?
#
# 함정이 진행하면서 내는 소음은 10km 이내에서 이뤄져야 감지되는데 이 소음은 저주파로 10km이상 퍼져나간다고 주장한 사람은?
#
# 함정이 진행하면서 내는 소음은 10km 이내에서 이뤄져야 감지되는데 이 소음은 저주파로 10km이상 퍼져나간다고 주장한 사람은?
#
# 함정이 진행하면서 내는 소음은 10km 이내에서 이뤄져야 감지되는데 이 소음은 저주파로 10km이상 퍼져나간다고 주장한 사람은?
#
# 함정이 진행하면서 내는 소음은 10km 이내에서 이뤄져야 감지되는데 이 소음은 저주파로 10km이상 퍼져나간다고 주장한 사람은?
#
# 튜브형 금속 조형물 축 진동의 고유 진동수 스펙트럼과 지진파 관측 결과가 어떻게 일치하는가?
#
# 튜브형 금속 조형물 축 진동의 고유 진동수 스펙트럼과 지진파 관측 결과가 어떻게 일치하는가?
#
# 튜브형 금속 조형물 축 진동의 고유 진동수 스펙트럼과 지진파 관측 결과가 어떻게 일치하는가?
#
# 튜브형 금속 조형물 축 진동의 고유 진동수 스펙트럼과 지진파 관측 결과가 어떻게 일치하는가?
#
# 튜브형 금속 조형물 축 진동의 고유 진동수 스펙트럼과 지진파 관측 결과가 어떻게 일치하는가?
#
# 해군 2함대가 전파한 군 문자정보망 교신 내역을 공개한 것은 언제인가?
#
# 해군 2함대가 전파한 군 문자정보망 교신 내역을 공개한 것은 언제인가?
#
# 해군 2함대가 전파한 군 문자정보망 교신 내역을 공개한 것은 언제인가?
#
# 해군 2함대가 전파한 군 문자정보망 교신 내역을 공개한 것은 언제인가?
#
# 해군 2함대가 전파한 군 문자정보망 교신 내역을 공개한 것은 언제인가?
#
# <sep>조사단의 구성원 문제나 은폐 가능성을 제기했던 신상철에 대한 비판은?
#
# <sep>조사단의 구성원 문제나 은폐 가능성을 제기했던 신상철에 대한 비판은?
#
# <sep>조사단의 구성원 문제나 은폐 가능성을 제기했던 신상철에 대한 비판은?
#
# <sep>조사단의 구성원 문제나 은폐 가능성을 제기했던 신상철에 대한 비판은?
#
# <sep>조사단의 구성원 문제나 은폐 가능성을 제기했던 신상철에 대한 비판은?
#
# 국방부로부터 고소를 당한 박선원 전 청와대 비서는 어뢰피격설이나 암초설을 주장한 적이 없다며 누구에게 고소를 당했는가?
#
# 국방부로부터 고소를 당한 박선원 전 청와대 비서는 어뢰피격설이나 암초설을 주장한 적이 없다며 누구에게 고소를 당했는가?
#
# 국방부로부터 고소를 당한 박선원 전 청와대 비서는 어뢰피격설이나 암초설을 주장한 적이 없다며 누구에게 고소를 당했는가?
#
# 국방부로부터 고소를 당한 박선원 전 청와대 비서는 어뢰피격설이나 암초설을 주장한 적이 없다며 누구에게 고소를 당했는가?
#
# 천안함 침몰 사건에 대한 성금 모금이 진행된 날짜는?
#
# 천안함 침몰 사건에 대한 성금 모금이 진행된 날짜는?
#
# 천안함 침몰 사건에 대한 성금 모금이 진행된 날짜는?
#
# 천안함 침몰 사건에 대한 성금 모금이 진행된 날짜는?
#
# 천안함 침몰 사건에 대한 성금 모금이 진행된 날짜는?
#
# 북한의 책임론을 주장하며 비판적인 성향을 가진 보수주의자들을 결집시키는 결과를 불러올 수 있는것은?
#
# 북한의 책임론을 주장하며 비판적인 성향을 가진 보수주의자들을 결집시키는 결과를 불러올 수 있는것은?
#
# 북한의 책임론을 주장하며 비판적인 성향을 가진 보수주의자들을 결집시키는 결과를 불러올 수 있는것은?
#
# 북한의 책임론을 주장하며 비판적인 성향을 가진 보수주의자들을 결집시키는 결과를 불러올 수 있는것은?
#
# 북한의 책임론을 주장하며 비판적인 성향을 가진 보수주의자들을 결집시키는 결과를 불러올 수 있는것은?
#
# 최종보고서의 내용을 신뢰하지 않는다는 답변이 가장 많았던 여론조사는 언제 실시되었는가?
#
# 최종보고서의 내용을 신뢰하지 않는다는 답변이 가장 많았던 여론조사는 언제 실시되었는가?
#
# 최종보고서의 내용을 신뢰하지 않는다는 답변이 가장 많았던 여론조사는 언제 실시되었는가?
#
# 최종보고서의 내용을 신뢰하지 않는다는 답변이 가장 많았던 여론조사는 언제 실시되었는가?
#
# 최종보고서의 내용을 신뢰하지 않는다는 답변이 가장 많았던 여론조사는 언제 실시되었는가?
#
# 윤덕용 천안함 사건 민.군 합동조사단장이 안보리 이사회에 참석한 날은?
#
# 윤덕용 천안함 사건 민.군 합동조사단장이 안보리 이사회에 참석한 날은?
#
# 윤덕용 천안함 사건 민.군 합동조사단장이 안보리 이사회에 참석한 날은?
#
# 윤덕용 천안함 사건 민.군 합동조사단장이 안보리 이사회에 참석한 날은?
#
# 윤덕용 천안함 사건 민.군 합동조사단장이 안보리 이사회에 참석한 날은?
#
# 참여연대는 천안함 침몰 사건의 조사결과에 대한 의문점을 담은 서한을 안전보장이사회와 이사국들에게 보낸것은?
#
# 참여연대는 천안함 침몰 사건의 조사결과에 대한 의문점을 담은 서한을 안전보장이사회와 이사국들에게 보낸것은?
#
# 참여연대는 천안함 침몰 사건의 조사결과에 대한 의문점을 담은 서한을 안전보장이사회와 이사국들에게 보낸것은?
#
# 참여연대는 천안함 침몰 사건의 조사결과에 대한 의문점을 담은 서한을 안전보장이사회와 이사국들에게 보낸것은?
#
# 참여연대는 천안함 침몰 사건의 조사결과에 대한 의문점을 담은 서한을 안전보장이사회와 이사국들에게 보낸것은?
#
# 군의 대응실태를 조사한 감사원은 허위보고, 음주근무 등 초기 대응에서의 총체적 문제점이 드러나 합참의장 등 장성급 장교들을 포함해 총 25명에 대해 징계를 요청하였는데 이 중 몇명이 형사처벌이 필요하다고 밝혔는가?
#
# 군의 대응실태를 조사한 감사원은 허위보고, 음주근무 등 초기 대응에서의 총체적 문제점이 드러나 합참의장 등 장성급 장교들을 포함해 총 25명에 대해 징계를 요청하였는데 이 중 몇명이 형사처벌이 필요하다고 밝혔는가?
#
# 군의 대응실태를 조사한 감사원은 허위보고, 음주근무 등 초기 대응에서의 총체적 문제점이 드러나 합참의장 등 장성급 장교들을 포함해 총 25명에 대해 징계를 요청하였는데 이 중 몇명이 형사처벌이 필요하다고 밝혔는가?
#
# 군의 대응실태를 조사한 감사원은 허위보고, 음주근무 등 초기 대응에서의 총체적 문제점이 드러나 합참의장 등 장성급 장교들을 포함해 총 25명에 대해 징계를 요청하였는데 이 중 몇명이 형사처벌이 필요하다고 밝혔는가?
#
# 군의 대응실태를 조사한 감사원은 허위보고, 음주근무 등 초기 대응에서의 총체적 문제점이 드러나 합참의장 등 장성급 장교들을 포함해 총 25명에 대해 징계를 요청하였는데 이 중 몇명이 형사처벌이 필요하다고 밝혔는가?
#
# 김현웅 전 장관은 몇년도에 변호사 등록을 신청하였는가?
#
# 김현웅 전 장관은 몇년도에 변호사 등록을 신청하였는가?
#
# 김현웅 전 장관은 몇년도에 변호사 등록을 신청하였는가?
#
# 김현웅 전 장관은 몇년도에 변호사 등록을 신청하였는가?
#
# 김현웅 전 장관은 몇년도에 변호사 등록을 신청하였는가?
#
# 김현웅 전 장관은 몇년도에 변호사 등록을 신청하였는가?
#
# 김현웅 전 장관은 몇년도에 변호사 등록을 신청하였는가?
#
# 로빈 안틴이 1995년 처음으로 공연을 한 곳은 어디인가?
#
# 로빈 안틴이 1995년 처음으로 공연을 한 곳은 어디인가?
#
# 로빈 안틴이 1995년 처음으로 공연을 한 곳은 어디인가?
#
# 로빈 안틴이 1995년 처음으로 공연을 한 곳은 어디인가?
#
# 로빈 안틴이 1995년 처음으로 공연을 한 곳은 어디인가?
#
# 에덴스 크러쉬의 전 멤버였던 니콜 셰르징거가 푸시캣 돌스의 리드보컬로 영입된 곡은?
#
# 에덴스 크러쉬의 전 멤버였던 니콜 셰르징거가 푸시캣 돌스의 리드보컬로 영입된 곡은?
#
# 에덴스 크러쉬의 전 멤버였던 니콜 셰르징거가 푸시캣 돌스의 리드보컬로 영입된 곡은?
#
# 에덴스 크러쉬의 전 멤버였던 니콜 셰르징거가 푸시캣 돌스의 리드보컬로 영입된 곡은?
#
# 에덴스 크러쉬의 전 멤버였던 니콜 셰르징거가 푸시캣 돌스의 리드보컬로 영입된 곡은?
#
# 에덴스 크러쉬의 전 멤버였던 니콜 셰르징거가 푸시캣 돌스의 리드보컬로 영입된 곡은?
#
# 푸시캣 돌스의 첫 번째 정규 음반 PCD가 빌보드 핫 100 차트에서 몇 위까지 올라갔는가?
#
# 푸시캣 돌스의 첫 번째 정규 음반 PCD가 빌보드 핫 100 차트에서 몇 위까지 올라갔는가?
#
# 푸시캣 돌스의 첫 번째 정규 음반 PCD가 빌보드 핫 100 차트에서 몇 위까지 올라갔는가?
#
# 푸시캣 돌스의 첫 번째 정규 음반 PCD가 빌보드 핫 100 차트에서 몇 위까지 올라갔는가?
#
# 푸시캣 돌스의 첫 번째 정규 음반 PCD가 빌보드 핫 100 차트에서 몇 위까지 올라갔는가?
#
# 푸시캣 돌스의 첫 번째 정규 음반 PCD가 빌보드 핫 100 차트에서 몇 위까지 올라갔는가?
#
# 푸시캣 돌스의 여섯 번째 싱글이 피쳐링한 곡은?
#
# 푸시캣 돌스의 여섯 번째 싱글이 피쳐링한 곡은?
#
# 푸시캣 돌스의 여섯 번째 싱글이 피쳐링한 곡은?
#
# 푸시캣 돌스의 여섯 번째 싱글이 피쳐링한 곡은?
#
# 푸시캣 돌스의 여섯 번째 싱글이 피쳐링한 곡은?
#
# 푸시캣 돌스의 여섯 번째 싱글이 피쳐링한 곡은?
#
# Pussycat Dolls Present: The Search For the Next Doll의 최종 우승자는?
#
# Pussycat Dolls Present: The Search For the Next Doll의 최종 우승자는?
#
# Pussycat Dolls Present: The Search For the Next Doll의 최종 우승자는?
#
# Pussycat Dolls Present: The Search For the Next Doll의 최종 우승자는?
#
# Pussycat Dolls Present: The Search For the Next Doll의 최종 우승자는?
#
# 2008년 5월 27일 발표한 푸시캣 돌스의 새 싱글은?
#
# 2008년 5월 27일 발표한 푸시캣 돌스의 새 싱글은?
#
# 2008년 5월 27일 발표한 푸시캣 돌스의 새 싱글은?
#
# 2008년 5월 27일 발표한 푸시캣 돌스의 새 싱글은?
#
# 2008년 5월 27일 발표한 푸시캣 돌스의 새 싱글은?
#
# 2008년 5월 27일 발표한 푸시캣 돌스의 새 싱글은?
#
# MTV 아시아 뮤직 어워드에서 오프닝 무대를 장식한 그룹은?
#
# MTV 아시아 뮤직 어워드에서 오프닝 무대를 장식한 그룹은?
#
# MTV 아시아 뮤직 어워드에서 오프닝 무대를 장식한 그룹은?
#
# MTV 아시아 뮤직 어워드에서 오프닝 무대를 장식한 그룹은?
#
# MTV 아시아 뮤직 어워드에서 오프닝 무대를 장식한 그룹은?
#
# MTV 아시아 뮤직 어워드에서 오프닝 무대를 장식한 그룹은?
#
# Doll Domination 2.0이 재발매된 날짜는?
#
# Doll Domination 2.0이 재발매된 날짜는?
#
# Doll Domination 2.0이 재발매된 날짜는?
#
# Doll Domination 2.0이 재발매된 날짜는?
#
# Doll Domination 2.0이 재발매된 날짜는?
#
# 킴벌리 와이어트가 그룹을 떠났다는 사실을 확인했다고 보도한 잡지의 이름은?
#
# 킴벌리 와이어트가 그룹을 떠났다는 사실을 확인했다고 보도한 잡지의 이름은?
#
# 킴벌리 와이어트가 그룹을 떠났다는 사실을 확인했다고 보도한 잡지의 이름은?
#
# 킴벌리 와이어트가 그룹을 떠났다는 사실을 확인했다고 보도한 잡지의 이름은?
#
# 킴벌리 와이어트가 그룹을 떠났다는 사실을 확인했다고 보도한 잡지의 이름은?
#
# Entertainment Weekly의 마고 왓슨은 리드보컬 니콜 셰르징거에 대한 지나친 부각을 누구에 대한 지나친 부각을 강하게 비판하고 나섰는가?
#
# Entertainment Weekly의 마고 왓슨은 리드보컬 니콜 셰르징거에 대한 지나친 부각을 누구에 대한 지나친 부각을 강하게 비판하고 나섰는가?
#
# Entertainment Weekly의 마고 왓슨은 리드보컬 니콜 셰르징거에 대한 지나친 부각을 누구에 대한 지나친 부각을 강하게 비판하고 나섰는가?
#
# Entertainment Weekly의 마고 왓슨은 리드보컬 니콜 셰르징거에 대한 지나친 부각을 누구에 대한 지나친 부각을 강하게 비판하고 나섰는가?
#
# Entertainment Weekly의 마고 왓슨은 리드보컬 니콜 셰르징거에 대한 지나친 부각을 누구에 대한 지나친 부각을 강하게 비판하고 나섰는가?
#
# ESP가 미국 뉴욕에 설립한 리페어 샵의 이름은?
#
# ESP가 미국 뉴욕에 설립한 리페어 샵의 이름은?
#
# ESP가 미국 뉴욕에 설립한 리페어 샵의 이름은?
#
# ESP가 미국 뉴욕에 설립한 리페어 샵의 이름은?
#
# ESP가 미국 뉴욕에 설립한 리페어 샵의 이름은?
#
# ESP가 미국 뉴욕에 설립한 리페어 샵의 이름은?
#
# ESP가 미국 뉴욕에 설립한 리페어 샵의 이름은?
#
# ESP가 미국 뉴욕에 설립한 리페어 샵의 이름은?
#
# ESP의 첫 시그네처 기타의 이름은?
#
# ESP의 첫 시그네처 기타의 이름은?
#
# ESP의 첫 시그네처 기타의 이름은?
#
# ESP의 첫 시그네처 기타의 이름은?
#
# ESP의 첫 시그네처 기타의 이름은?
#
# ESP의 첫 시그네처 기타의 이름은?
#
# ESP의 첫 시그네처 기타의 이름은?
#
# ESP의 첫 시그네처 기타의 이름은?
#
# Standard Series가 단종된 해는?
#
# Standard Series가 단종된 해는?
#
# Standard Series가 단종된 해는?
#
# Standard Series가 단종된 해는?
#
# Standard Series가 단종된 해는?
#
# Standard Series가 단종된 해는?
#
# Standard Series가 단종된 해는?
#
# Standard Series가 단종된 해는?
#
# 승리가 오디션 프로그램 '레츠 코크플레이 배틀신화'에 지원한 것은 언제인가?
#
# 승리가 오디션 프로그램 '레츠 코크플레이 배틀신화'에 지원한 것은 언제인가?
#
# 승리가 오디션 프로그램 '레츠 코크플레이 배틀신화'에 지원한 것은 언제인가?
#
# 승리가 오디션 프로그램 '레츠 코크플레이 배틀신화'에 지원한 것은 언제인가?
#
# 승리가 오디션 프로그램 '레츠 코크플레이 배틀신화'에 지원한 것은 언제인가?
#
# 승리가 오디션 프로그램 '레츠 코크플레이 배틀신화'에 지원한 것은 언제인가?
#
# 승리가 오디션 프로그램 '레츠 코크플레이 배틀신화'에 지원한 것은 언제인가?
#
# 승리가 오디션 프로그램 '레츠 코크플레이 배틀신화'에 지원한 것은 언제인가?
#
# 승리가 오디션 프로그램 '레츠 코크플레이 배틀신화'에 지원한 것은 언제인가?
#
# 빅뱅의 첫 번째 정규 음반의 제목은?
#
# 빅뱅의 첫 번째 정규 음반의 제목은?
#
# 빅뱅의 첫 번째 정규 음반의 제목은?
#
# 빅뱅의 첫 번째 정규 음반의 제목은?
#
# 빅뱅의 첫 번째 정규 음반의 제목은?
#
# 빅뱅의 첫 번째 정규 음반의 제목은?
#
# 빅뱅의 첫 번째 정규 음반의 제목은?
#
# 빅뱅의 첫 번째 정규 음반의 제목은?
#
# 빅뱅의 첫 번째 정규 음반의 제목은?
#
# 승리가 출연한 빅뱅의 두 번째 정규 음반의 이름은?
#
# 승리가 출연한 빅뱅의 두 번째 정규 음반의 이름은?
#
# 승리가 출연한 빅뱅의 두 번째 정규 음반의 이름은?
#
# 승리가 출연한 빅뱅의 두 번째 정규 음반의 이름은?
#
# 승리가 출연한 빅뱅의 두 번째 정규 음반의 이름은?
#
# 승리가 출연한 빅뱅의 두 번째 정규 음반의 이름은?
#
# 승리가 출연한 빅뱅의 두 번째 정규 음반의 이름은?
#
# 승리가 출연한 빅뱅의 두 번째 정규 음반의 이름은?
#
# 승리가 출연한 빅뱅의 두 번째 정규 음반의 이름은?
#
# 빅뱅의 멤버 대성이 스페셜 MC를 맡은 프로그램은?
#
# 빅뱅의 멤버 대성이 스페셜 MC를 맡은 프로그램은?
#
# 빅뱅의 멤버 대성이 스페셜 MC를 맡은 프로그램은?
#
# 빅뱅의 멤버 대성이 스페셜 MC를 맡은 프로그램은?
#
# 빅뱅의 멤버 대성이 스페셜 MC를 맡은 프로그램은?
#
# 빅뱅의 멤버 대성이 스페셜 MC를 맡은 프로그램은?
#
# 빅뱅의 멤버 대성이 스페셜 MC를 맡은 프로그램은?
#
# 빅뱅의 멤버 대성이 스페셜 MC를 맡은 프로그램은?
#
# 유비코이~ 그대에게 보내는 메시지'의 주제가로 기용된 사람은?
#
# 유비코이~ 그대에게 보내는 메시지'의 주제가로 기용된 사람은?
#
# 유비코이~ 그대에게 보내는 메시지'의 주제가로 기용된 사람은?
#
# 유비코이~ 그대에게 보내는 메시지'의 주제가로 기용된 사람은?
#
# 유비코이~ 그대에게 보내는 메시지'의 주제가로 기용된 사람은?
#
# 유비코이~ 그대에게 보내는 메시지'의 주제가로 기용된 사람은?
#
# 유비코이~ 그대에게 보내는 메시지'의 주제가로 기용된 사람은?
#
# 종합편성채널에 법적 근거를 부여하는 방송법 개정안이 국회를 통과한 시기는?
#
# 종합편성채널에 법적 근거를 부여하는 방송법 개정안이 국회를 통과한 시기는?
#
# 종합편성채널에 법적 근거를 부여하는 방송법 개정안이 국회를 통과한 시기는?
#
# 종합편성채널에 법적 근거를 부여하는 방송법 개정안이 국회를 통과한 시기는?
#
# 종합편성채널에 법적 근거를 부여하는 방송법 개정안이 국회를 통과한 시기는?
#
# 종합편성채널에 법적 근거를 부여하는 방송법 개정안이 국회를 통과한 시기는?
#
# 종합편성채널에 법적 근거를 부여하는 방송법 개정안이 국회를 통과한 시기는?
#
# 지상파급 막대한 투자를 하다보니 과유불급인지 2012년 영업손실이 가장 높은 것으로 집계된것은?
#
# 지상파급 막대한 투자를 하다보니 과유불급인지 2012년 영업손실이 가장 높은 것으로 집계된것은?
#
# 지상파급 막대한 투자를 하다보니 과유불급인지 2012년 영업손실이 가장 높은 것으로 집계된것은?
#
# 지상파급 막대한 투자를 하다보니 과유불급인지 2012년 영업손실이 가장 높은 것으로 집계된것은?
#
# 지상파급 막대한 투자를 하다보니 과유불급인지 2012년 영업손실이 가장 높은 것으로 집계된것은?
#
# 지상파급 막대한 투자를 하다보니 과유불급인지 2012년 영업손실이 가장 높은 것으로 집계된것은?
#
# 모션 그래픽스란 개념은 움직이지 않는 그래픽과 시간의 경과에 따라 그 형태가 구체적으로 표현되지 않더라도 형상이 변화하는 그래픽을 구분하기에 유용한가?
#
# ...
#
# 갤럭시 노트7과 갤럭시 노트7 엣지에 탑재된 카메라의 화소는?
#
# 엘리너 루이지 코웰이 태어난 해는?
#
# 엘리너 루이지 코웰이 태어난 해는?
#
# 엘리너 루이지 코웰이 태어난 해는?
#
# 엘리너 루이지 코웰이 태어난 해는?
#
# 엘리너 루이지 코웰이 태어난 해는?
#
# 엘리너 루이지 코웰이 태어난 해는?
#
# 엘리너 루이지 코웰이 태어난 해는?
#
# 엘리너 루이지 코웰이 태어난 해는?
#
# 번디의 어머니는 누구인가?
#
# 번디의 어머니는 누구인가?
#
# 번디의 어머니는 누구인가?
#
# 번디의 어머니는 누구인가?
#
# 번디의 어머니는 누구인가?
#
# 번디의 어머니는 누구인가?
#
# 번디의 어머니는 누구인가?
#
# 번디의 외조부가 누구를 때리고 꼬리를 잡고 휘둘렀다고 했는가?
#
# 번디의 외조부가 누구를 때리고 꼬리를 잡고 휘둘렀다고 했는가?
#
# 번디의 외조부가 누구를 때리고 꼬리를 잡고 휘둘렀다고 했는가?
#
# 번디의 외조부가 누구를 때리고 꼬리를 잡고 휘둘렀다고 했는가?
#
# 번디의 외조부가 누구를 때리고 꼬리를 잡고 휘둘렀다고 했는가?
#
# 번디의 외조부가 누구를 때리고 꼬리를 잡고 휘둘렀다고 했는가?
#
# 번디의 외조부가 누구를 때리고 꼬리를 잡고 휘둘렀다고 했는가?
#
# 번디의 외조부가 누구를 때리고 꼬리를 잡고 휘둘렀다고 했는가?
#
# 번디의 외조부가 누구를 때리고 꼬리를 잡고 휘둘렀다고 했는가?
#
# 테드는 훗날 자신의 여자친구에게 조니에 대해서 자신의 진짜 아버지가 아니라고 말했는가?
#
# 테드는 훗날 자신의 여자친구에게 조니에 대해서 자신의 진짜 아버지가 아니라고 말했는가?
#
# 테드는 훗날 자신의 여자친구에게 조니에 대해서 자신의 진짜 아버지가 아니라고 말했는가?
#
# 테드는 훗날 자신의 여자친구에게 조니에 대해서 자신의 진짜 아버지가 아니라고 말했는가?
#
# 테드는 훗날 자신의 여자친구에게 조니에 대해서 자신의 진짜 아버지가 아니라고 말했는가?
#
# 테드는 훗날 자신의 여자친구에게 조니에 대해서 자신의 진짜 아버지가 아니라고 말했는가?
#
# 테드는 훗날 자신의 여자친구에게 조니에 대해서 자신의 진짜 아버지가 아니라고 말했는가?
#
# 테드는 훗날 자신의 여자친구에게 조니에 대해서 자신의 진짜 아버지가 아니라고 말했는가?
#
# 테드는 훗날 자신의 여자친구에게 조니에 대해서 자신의 진짜 아버지가 아니라고 말했는가?
#
# 미쇼와 애인스워스와 대화 중 번디는 무엇을 찾기위해 쓰레기 통을 찔러보면서 이웃집들을 돌아다녔다고 했는가?
#
# 미쇼와 애인스워스와 대화 중 번디는 무엇을 찾기위해 쓰레기 통을 찔러보면서 이웃집들을 돌아다녔다고 했는가?
#
# 미쇼와 애인스워스와 대화 중 번디는 무엇을 찾기위해 쓰레기 통을 찔러보면서 이웃집들을 돌아다녔다고 했는가?
#
# 미쇼와 애인스워스와 대화 중 번디는 무엇을 찾기위해 쓰레기 통을 찔러보면서 이웃집들을 돌아다녔다고 했는가?
#
# 미쇼와 애인스워스와 대화 중 번디는 무엇을 찾기위해 쓰레기 통을 찔러보면서 이웃집들을 돌아다녔다고 했는가?
#
# 미쇼와 애인스워스와 대화 중 번디는 무엇을 찾기위해 쓰레기 통을 찔러보면서 이웃집들을 돌아다녔다고 했는가?
#
# 미쇼와 애인스워스와 대화 중 번디는 무엇을 찾기위해 쓰레기 통을 찔러보면서 이웃집들을 돌아다녔다고 했는가?
#
# 미쇼와 애인스워스와 대화 중 번디는 무엇을 찾기위해 쓰레기 통을 찔러보면서 이웃집들을 돌아다녔다고 했는가?
#
# 미쇼와 애인스워스와 대화 중 번디는 무엇을 찾기위해 쓰레기 통을 찔러보면서 이웃집들을 돌아다녔다고 했는가?
#
# 넬슨 록펠러의 대선 캠페인을 위해 시애틀 사무소에서 자원해서 일하기도 한 사람은?
#
# 넬슨 록펠러의 대선 캠페인을 위해 시애틀 사무소에서 자원해서 일하기도 한 사람은?
#
# 넬슨 록펠러의 대선 캠페인을 위해 시애틀 사무소에서 자원해서 일하기도 한 사람은?
#
# 넬슨 록펠러의 대선 캠페인을 위해 시애틀 사무소에서 자원해서 일하기도 한 사람은?
#
# 넬슨 록펠러의 대선 캠페인을 위해 시애틀 사무소에서 자원해서 일하기도 한 사람은?
#
# 넬슨 록펠러의 대선 캠페인을 위해 시애틀 사무소에서 자원해서 일하기도 한 사람은?
#
# 넬슨 록펠러의 대선 캠페인을 위해 시애틀 사무소에서 자원해서 일하기도 한 사람은?
#
# 넬슨 록펠러의 대선 캠페인을 위해 시애틀 사무소에서 자원해서 일하기도 한 사람은?
#
# 넬슨 록펠러의 대선 캠페인을 위해 시애틀 사무소에서 자원해서 일하기도 한 사람은?
#
# 시애틀 자살 핫라인 위기 센터에서 일을 구한 사람은?
#
# 시애틀 자살 핫라인 위기 센터에서 일을 구한 사람은?
#
# 시애틀 자살 핫라인 위기 센터에서 일을 구한 사람은?
#
# 시애틀 자살 핫라인 위기 센터에서 일을 구한 사람은?
#
# 시애틀 자살 핫라인 위기 센터에서 일을 구한 사람은?
#
# 시애틀 자살 핫라인 위기 센터에서 일을 구한 사람은?
#
# 시애틀 자살 핫라인 위기 센터에서 일을 구한 사람은?
#
# 시애틀 자살 핫라인 위기 센터에서 일을 구한 사람은?
#
# 시애틀 자살 핫라인 위기 센터에서 일을 구한 사람은?
#
# 에반스가 재선에 성공한 후 번디가 워싱턴 주 공화당 의장인 로스 데이비스에게 사무보조원으로 고용된 것은 언제인가?
#
# 에반스가 재선에 성공한 후 번디가 워싱턴 주 공화당 의장인 로스 데이비스에게 사무보조원으로 고용된 것은 언제인가?
#
# 에반스가 재선에 성공한 후 번디가 워싱턴 주 공화당 의장인 로스 데이비스에게 사무보조원으로 고용된 것은 언제인가?
#
# 에반스가 재선에 성공한 후 번디가 워싱턴 주 공화당 의장인 로스 데이비스에게 사무보조원으로 고용된 것은 언제인가?
#
# 에반스가 재선에 성공한 후 번디가 워싱턴 주 공화당 의장인 로스 데이비스에게 사무보조원으로 고용된 것은 언제인가?
#
# 에반스가 재선에 성공한 후 번디가 워싱턴 주 공화당 의장인 로스 데이비스에게 사무보조원으로 고용된 것은 언제인가?
#
# 에반스가 재선에 성공한 후 번디가 워싱턴 주 공화당 의장인 로스 데이비스에게 사무보조원으로 고용된 것은 언제인가?
#
# 에반스가 재선에 성공한 후 번디가 워싱턴 주 공화당 의장인 로스 데이비스에게 사무보조원으로 고용된 것은 언제인가?
#
# 에반스가 재선에 성공한 후 번디가 워싱턴 주 공화당 의장인 로스 데이비스에게 사무보조원으로 고용된 것은 언제인가?
#
# 밸러리 번디가 캘리포니아행 공화당 출장기간에 번디에게 보낸 편지는?
#
# 밸러리 번디가 캘리포니아행 공화당 출장기간에 번디에게 보낸 편지는?
#
# 밸러리 번디가 캘리포니아행 공화당 출장기간에 번디에게 보낸 편지는?
#
# 밸러리 번디가 캘리포니아행 공화당 출장기간에 번디에게 보낸 편지는?
#
# 밸러리 번디가 캘리포니아행 공화당 출장기간에 번디에게 보낸 편지는?
#
# 밸러리 번디가 캘리포니아행 공화당 출장기간에 번디에게 보낸 편지는?
#
# 밸러리 번디가 캘리포니아행 공화당 출장기간에 번디에게 보낸 편지는?
#
# 밸러리 번디가 캘리포니아행 공화당 출장기간에 번디에게 보낸 편지는?
#
# 밸러리 번디가 캘리포니아행 공화당 출장기간에 번디에게 보낸 편지는?
#
# 넬슨에게 1969년 시애틀에서 살인을 저지르기 전까지 누구도 죽이지 않았다고 말한 사람은?
#
# 넬슨에게 1969년 시애틀에서 살인을 저지르기 전까지 누구도 죽이지 않았다고 말한 사람은?
#
# 넬슨에게 1969년 시애틀에서 살인을 저지르기 전까지 누구도 죽이지 않았다고 말한 사람은?
#
# 넬슨에게 1969년 시애틀에서 살인을 저지르기 전까지 누구도 죽이지 않았다고 말한 사람은?
#
# 넬슨에게 1969년 시애틀에서 살인을 저지르기 전까지 누구도 죽이지 않았다고 말한 사람은?
#
# 넬슨에게 1969년 시애틀에서 살인을 저지르기 전까지 누구도 죽이지 않았다고 말한 사람은?
#
# 넬슨에게 1969년 시애틀에서 살인을 저지르기 전까지 누구도 죽이지 않았다고 말한 사람은?
#
# 넬슨에게 1969년 시애틀에서 살인을 저지르기 전까지 누구도 죽이지 않았다고 말한 사람은?
#
# 넬슨에게 1969년 시애틀에서 살인을 저지르기 전까지 누구도 죽이지 않았다고 말한 사람은?
#
# 시애틀에서 남쪽으로 260마일 떨어진 코밸리스 소재 오리건 주립 대학교는?
#
# 시애틀에서 남쪽으로 260마일 떨어진 코밸리스 소재 오리건 주립 대학교는?
#
# 시애틀에서 남쪽으로 260마일 떨어진 코밸리스 소재 오리건 주립 대학교는?
#
# 시애틀에서 남쪽으로 260마일 떨어진 코밸리스 소재 오리건 주립 대학교는?
#
# 시애틀에서 남쪽으로 260마일 떨어진 코밸리스 소재 오리건 주립 대학교는?
#
# 시애틀에서 남쪽으로 260마일 떨어진 코밸리스 소재 오리건 주립 대학교는?
#
# 시애틀에서 남쪽으로 260마일 떨어진 코밸리스 소재 오리건 주립 대학교는?
#
# 시애틀에서 남쪽으로 260마일 떨어진 코밸리스 소재 오리건 주립 대학교는?
#
# 브렌다 캐롤 볼이 시애틀-터고마 국제 공항인근 버리엔에 있는 플레임 여관을 떠난 뒤에 사라진 사람은?
#
# 브렌다 캐롤 볼이 시애틀-터고마 국제 공항인근 버리엔에 있는 플레임 여관을 떠난 뒤에 사라진 사람은?
#
# 브렌다 캐롤 볼이 시애틀-터고마 국제 공항인근 버리엔에 있는 플레임 여관을 떠난 뒤에 사라진 사람은?
#
# 브렌다 캐롤 볼이 시애틀-터고마 국제 공항인근 버리엔에 있는 플레임 여관을 떠난 뒤에 사라진 사람은?
#
# 브렌다 캐롤 볼이 시애틀-터고마 국제 공항인근 버리엔에 있는 플레임 여관을 떠난 뒤에 사라진 사람은?
#
# 브렌다 캐롤 볼이 시애틀-터고마 국제 공항인근 버리엔에 있는 플레임 여관을 떠난 뒤에 사라진 사람은?
#
# 브렌다 캐롤 볼이 시애틀-터고마 국제 공항인근 버리엔에 있는 플레임 여관을 떠난 뒤에 사라진 사람은?
#
# 여성 실종자 6명과 스팍스의 끔찍한 폭행 사건에 관한 기사들이 워싱턴주와 오리건 전역에 신문과 텔레비전으로 보도된 시기는?
#
# 여성 실종자 6명과 스팍스의 끔찍한 폭행 사건에 관한 기사들이 워싱턴주와 오리건 전역에 신문과 텔레비전으로 보도된 시기는?
#
# 여성 실종자 6명과 스팍스의 끔찍한 폭행 사건에 관한 기사들이 워싱턴주와 오리건 전역에 신문과 텔레비전으로 보도된 시기는?
#
# 여성 실종자 6명과 스팍스의 끔찍한 폭행 사건에 관한 기사들이 워싱턴주와 오리건 전역에 신문과 텔레비전으로 보도된 시기는?
#
# 여성 실종자 6명과 스팍스의 끔찍한 폭행 사건에 관한 기사들이 워싱턴주와 오리건 전역에 신문과 텔레비전으로 보도된 시기는?
#
# 여성 실종자 6명과 스팍스의 끔찍한 폭행 사건에 관한 기사들이 워싱턴주와 오리건 전역에 신문과 텔레비전으로 보도된 시기는?
#
# 여성 실종자 6명과 스팍스의 끔찍한 폭행 사건에 관한 기사들이 워싱턴주와 오리건 전역에 신문과 텔레비전으로 보도된 시기는?
#
# 여성 실종자 6명과 스팍스의 끔찍한 폭행 사건에 관한 기사들이 워싱턴주와 오리건 전역에 신문과 텔레비전으로 보도된 시기는?
#
# 여성 실종자 6명과 스팍스의 끔찍한 폭행 사건에 관한 기사들이 워싱턴주와 오리건 전역에 신문과 텔레비전으로 보도된 시기는?
#
# 시애틀 동쪽 20마일(32 km) 떨어진 레이크 새머미시 주립 공원에서 2명의 여성 유괴사건의 목격자는?
#
# 시애틀 동쪽 20마일(32 km) 떨어진 레이크 새머미시 주립 공원에서 2명의 여성 유괴사건의 목격자는?
#
# 시애틀 동쪽 20마일(32 km) 떨어진 레이크 새머미시 주립 공원에서 2명의 여성 유괴사건의 목격자는?
#
# 시애틀 동쪽 20마일(32 km) 떨어진 레이크 새머미시 주립 공원에서 2명의 여성 유괴사건의 목격자는?
#
# 시애틀 동쪽 20마일(32 km) 떨어진 레이크 새머미시 주립 공원에서 2명의 여성 유괴사건의 목격자는?
#
# 시애틀 동쪽 20마일(32 km) 떨어진 레이크 새머미시 주립 공원에서 2명의 여성 유괴사건의 목격자는?
#
# 시애틀 동쪽 20마일(32 km) 떨어진 레이크 새머미시 주립 공원에서 2명의 여성 유괴사건의 목격자는?
#
# 시애틀 동쪽 20마일(32 km) 떨어진 레이크 새머미시 주립 공원에서 2명의 여성 유괴사건의 목격자는?
#
# 시애틀 동쪽 20마일(32 km) 떨어진 레이크 새머미시 주립 공원에서 2명의 여성 유괴사건의 목격자는?
#
# 테드는 낸시 윌콕스를 납치해서 어디에서 교살했는가?
#
# 테드는 낸시 윌콕스를 납치해서 어디에서 교살했는가?
#
# 테드는 낸시 윌콕스를 납치해서 어디에서 교살했는가?
#
# 테드는 낸시 윌콕스를 납치해서 어디에서 교살했는가?
#
# 테드는 낸시 윌콕스를 납치해서 어디에서 교살했는가?
#
# 테드는 낸시 윌콕스를 납치해서 어디에서 교살했는가?
#
# 테드는 낸시 윌콕스를 납치해서 어디에서 교살했는가?
#
# 테드는 낸시 윌콕스를 납치해서 어디에서 교살했는가?
#
# 윤정훈이 목회자로써 맡고 있는 것은?
#
# 윤정훈이 목회자로써 맡고 있는 것은?
#
# 윤정훈이 목회자로써 맡고 있는 것은?
#
# 윤정훈이 목회자로써 맡고 있는 것은?
#
# 윤정훈이 목회자로써 맡고 있는 것은?
#
# 윤정훈이 목회자로써 맡고 있는 것은?
#
# 윤정훈이 목회자로써 맡고 있는 것은?
#
# 윤정훈의 사무실에서 압수된 파일철에 새마음포럼이라는 제목이 붙은 파일철이 발견되었다. 이 파일철이 발견된 곳은?
#
# 윤정훈의 사무실에서 압수된 파일철에 새마음포럼이라는 제목이 붙은 파일철이 발견되었다. 이 파일철이 발견된 곳은?
#
# 윤정훈의 사무실에서 압수된 파일철에 새마음포럼이라는 제목이 붙은 파일철이 발견되었다. 이 파일철이 발견된 곳은?
#
# 윤정훈의 사무실에서 압수된 파일철에 새마음포럼이라는 제목이 붙은 파일철이 발견되었다. 이 파일철이 발견된 곳은?
#
# 윤정훈의 사무실에서 압수된 파일철에 새마음포럼이라는 제목이 붙은 파일철이 발견되었다. 이 파일철이 발견된 곳은?
#
# 윤정훈의 사무실에서 압수된 파일철에 새마음포럼이라는 제목이 붙은 파일철이 발견되었다. 이 파일철이 발견된 곳은?
#
# 윤정훈의 사무실에서 압수된 파일철에 새마음포럼이라는 제목이 붙은 파일철이 발견되었다. 이 파일철이 발견된 곳은?
#
# 제나 기즈는 어느 병원에 입원했을 때 광견병 감염이 확인되었는가?
#
# 제나 기즈는 어느 병원에 입원했을 때 광견병 감염이 확인되었는가?
#
# 제나 기즈는 어느 병원에 입원했을 때 광견병 감염이 확인되었는가?
#
# 제나 기즈는 어느 병원에 입원했을 때 광견병 감염이 확인되었는가?
#
# 제나 기즈는 어느 병원에 입원했을 때 광견병 감염이 확인되었는가?
#
# 제나 기즈는 어느 병원에 입원했을 때 광견병 감염이 확인되었는가?
#
# 제나 기즈는 어느 병원에 입원했을 때 광견병 감염이 확인되었는가?
#
# 윌로우바이의 연구팀이 제나에게 투여한 항바이러스제는?
#
# 윌로우바이의 연구팀이 제나에게 투여한 항바이러스제는?
#
# 윌로우바이의 연구팀이 제나에게 투여한 항바이러스제는?
#
# 윌로우바이의 연구팀이 제나에게 투여한 항바이러스제는?
#
# 윌로우바이의 연구팀이 제나에게 투여한 항바이러스제는?
#
# 윌로우바이의 연구팀이 제나에게 투여한 항바이러스제는?
#
# 제나가 병원에 들어온 후 31일이 지나야 제나가 자신의 신체에서 광견병 바이러스가 사라졌다고 공식적으로 인정받았을 때 사용한 것은?
#
# 제나가 병원에 들어온 후 31일이 지나야 제나가 자신의 신체에서 광견병 바이러스가 사라졌다고 공식적으로 인정받았을 때 사용한 것은?
#
# 제나가 병원에 들어온 후 31일이 지나야 제나가 자신의 신체에서 광견병 바이러스가 사라졌다고 공식적으로 인정받았을 때 사용한 것은?
#
# 제나가 병원에 들어온 후 31일이 지나야 제나가 자신의 신체에서 광견병 바이러스가 사라졌다고 공식적으로 인정받았을 때 사용한 것은?
#
# 갤럭시 노트6와 갤럭시 S6 엣지와 패밀리룩을 이루고 있는 모델은?
#
# 갤럭시 노트6와 갤럭시 S6 엣지와 패밀리룩을 이루고 있는 모델은?
#
# 갤럭시 노트6와 갤럭시 S6 엣지와 패밀리룩을 이루고 있는 모델은?
#
# 갤럭시 노트6와 갤럭시 S6 엣지와 패밀리룩을 이루고 있는 모델은?
#
# 갤럭시 노트6와 갤럭시 S6 엣지와 패밀리룩을 이루고 있는 모델은?
#
# 갤럭시 노트6와 갤럭시 S6 엣지와 패밀리룩을 이루고 있는 모델은?
#
# 갤럭시 노트6와 갤럭시 S6 엣지와 패밀리룩을 이루고 있는 모델은?
#
# 갤럭시 노트6와 갤럭시 S6 엣지와 패밀리룩을 이루고 있는 모델은?
#
# 베르나도트가 후계자로 지명된 조약은?
#
# 베르나도트가 후계자로 지명된 조약은?
#
# 베르나도트가 후계자로 지명된 조약은?
#
# 베르나도트가 후계자로 지명된 조약은?
#
# 베르나도트가 후계자로 지명된 조약은?
#
# 베르나도트가 후계자로 지명된 조약은?
#
# 베르나도트가 후계자로 지명된 조약은?
#
# 드사 전투에서 후퇴한 후 알렉산드르 1세가 데 톨리에게 총지휘권을 넘겨주고 모스크바를 경유해 상트페테르부르크로 이동한 곳은?
#
# 드사 전투에서 후퇴한 후 알렉산드르 1세가 데 톨리에게 총지휘권을 넘겨주고 모스크바를 경유해 상트페테르부르크로 이동한 곳은?
#
# 드사 전투에서 후퇴한 후 알렉산드르 1세가 데 톨리에게 총지휘권을 넘겨주고 모스크바를 경유해 상트페테르부르크로 이동한 곳은?
#
# 드사 전투에서 후퇴한 후 알렉산드르 1세가 데 톨리에게 총지휘권을 넘겨주고 모스크바를 경유해 상트페테르부르크로 이동한 곳은?
#
# 드사 전투에서 후퇴한 후 알렉산드르 1세가 데 톨리에게 총지휘권을 넘겨주고 모스크바를 경유해 상트페테르부르크로 이동한 곳은?
#
# 드사 전투에서 후퇴한 후 알렉산드르 1세가 데 톨리에게 총지휘권을 넘겨주고 모스크바를 경유해 상트페테르부르크로 이동한 곳은?
#
# 드사 전투에서 후퇴한 후 알렉산드르 1세가 데 톨리에게 총지휘권을 넘겨주고 모스크바를 경유해 상트페테르부르크로 이동한 곳은?
#
# 나폴레옹군 본대가 수가 급속도로 줄어든 이유는?
#
# 나폴레옹군 본대가 수가 급속도로 줄어든 이유는?
#
# 나폴레옹군 본대가 수가 급속도로 줄어든 이유는?
#
# 나폴레옹군 본대가 수가 급속도로 줄어든 이유는?
#
# 나폴레옹군 본대가 수가 급속도로 줄어든 이유는?
#
# 나폴레옹군 본대가 수가 급속도로 줄어든 이유는?
#
# 나폴레옹군 본대가 수가 급속도로 줄어든 이유는?
#
# 마힐루에서 다부가 이끄는 프랑스군과 바그라티온의 러시아군 사이에 전투가 벌어져 바그라티온의 군대가 패하고 비텝스크로 향한 곳은?
#
# 마힐루에서 다부가 이끄는 프랑스군과 바그라티온의 러시아군 사이에 전투가 벌어져 바그라티온의 군대가 패하고 비텝스크로 향한 곳은?
#
# 마힐루에서 다부가 이끄는 프랑스군과 바그라티온의 러시아군 사이에 전투가 벌어져 바그라티온의 군대가 패하고 비텝스크로 향한 곳은?
#
# 마힐루에서 다부가 이끄는 프랑스군과 바그라티온의 러시아군 사이에 전투가 벌어져 바그라티온의 군대가 패하고 비텝스크로 향한 곳은?
#
# 마힐루에서 다부가 이끄는 프랑스군과 바그라티온의 러시아군 사이에 전투가 벌어져 바그라티온의 군대가 패하고 비텝스크로 향한 곳은?
#
# 마힐루에서 다부가 이끄는 프랑스군과 바그라티온의 러시아군 사이에 전투가 벌어져 바그라티온의 군대가 패하고 비텝스크로 향한 곳은?
#
# 8월 중반 스몰렌스크 전투가 벌어진 장소는?
#
# 8월 중반 스몰렌스크 전투가 벌어진 장소는?
#
# 8월 중반 스몰렌스크 전투가 벌어진 장소는?
#
# 8월 중반 스몰렌스크 전투가 벌어진 장소는?
#
# 8월 중반 스몰렌스크 전투가 벌어진 장소는?
#
# 8월 중반 스몰렌스크 전투가 벌어진 장소는?
#
# 8월 중반 스몰렌스크 전투가 벌어진 장소는?
#
# 포니아토프스키의 기병대가 러시아군 좌익을 우회하는 것을 방해받아 결국 정면 공격만 남게 된 전투의 이름은?
#
# 포니아토프스키의 기병대가 러시아군 좌익을 우회하는 것을 방해받아 결국 정면 공격만 남게 된 전투의 이름은?
#
# 포니아토프스키의 기병대가 러시아군 좌익을 우회하는 것을 방해받아 결국 정면 공격만 남게 된 전투의 이름은?
#
# 포니아토프스키의 기병대가 러시아군 좌익을 우회하는 것을 방해받아 결국 정면 공격만 남게 된 전투의 이름은?
#
# 포니아토프스키의 기병대가 러시아군 좌익을 우회하는 것을 방해받아 결국 정면 공격만 남게 된 전투의 이름은?
#
# 포니아토프스키의 기병대가 러시아군 좌익을 우회하는 것을 방해받아 결국 정면 공격만 남게 된 전투의 이름은?
#
# 포니아토프스키의 기병대가 러시아군 좌익을 우회하는 것을 방해받아 결국 정면 공격만 남게 된 전투의 이름은?
#
# 러시아가 프랑스와 강화를 맺는 것을 막기 위해 러시아에 대한 자금과 물자 지원을 아끼지 않았던 나라는?
#
# 러시아가 프랑스와 강화를 맺는 것을 막기 위해 러시아에 대한 자금과 물자 지원을 아끼지 않았던 나라는?
#
# 러시아가 프랑스와 강화를 맺는 것을 막기 위해 러시아에 대한 자금과 물자 지원을 아끼지 않았던 나라는?
#
# 러시아가 프랑스와 강화를 맺는 것을 막기 위해 러시아에 대한 자금과 물자 지원을 아끼지 않았던 나라는?
#
# 러시아가 프랑스와 강화를 맺는 것을 막기 위해 러시아에 대한 자금과 물자 지원을 아끼지 않았던 나라는?
#
# 러시아가 프랑스와 강화를 맺는 것을 막기 위해 러시아에 대한 자금과 물자 지원을 아끼지 않았던 나라는?
#
# 러시아가 프랑스와 강화를 맺는 것을 막기 위해 러시아에 대한 자금과 물자 지원을 아끼지 않았던 나라는?
#
# 나폴레옹군 본대는 대략 몇 명 정도였는가?
#
# 나폴레옹군 본대는 대략 몇 명 정도였는가?
#
# 나폴레옹군 본대는 대략 몇 명 정도였는가?
#
# 나폴레옹군 본대는 대략 몇 명 정도였는가?
#
# 나폴레옹군 본대는 대략 몇 명 정도였는가?
#
# 나폴레옹군 본대는 대략 몇 명 정도였는가?
#
# 나폴레옹군 본대는 대략 몇 명 정도였는가?
#
# 11월 초 비아즈마에서 밀로라도비치 장군이 지휘하는 한 러시아 군대가 다부의 후위대를 가로막고 전투를 벌인 시기는?
#
# 11월 초 비아즈마에서 밀로라도비치 장군이 지휘하는 한 러시아 군대가 다부의 후위대를 가로막고 전투를 벌인 시기는?
#
# 11월 초 비아즈마에서 밀로라도비치 장군이 지휘하는 한 러시아 군대가 다부의 후위대를 가로막고 전투를 벌인 시기는?
#
# 11월 초 비아즈마에서 밀로라도비치 장군이 지휘하는 한 러시아 군대가 다부의 후위대를 가로막고 전투를 벌인 시기는?
#
# 11월 초 비아즈마에서 밀로라도비치 장군이 지휘하는 한 러시아 군대가 다부의 후위대를 가로막고 전투를 벌인 시기는?
#
# 11월 초 비아즈마에서 밀로라도비치 장군이 지휘하는 한 러시아 군대가 다부의 후위대를 가로막고 전투를 벌인 시기는?
#
# 11월 초 비아즈마에서 밀로라도비치 장군이 지휘하는 한 러시아 군대가 다부의 후위대를 가로막고 전투를 벌인 시기는?
#
# 크라스니 마을로 들어가는 것을 방치한 나폴레옹이 근위대와 함께 중계점인 크라스니 마을로 들어가는 것을 방치한 것은 누구인가?
#
# 크라스니 마을로 들어가는 것을 방치한 나폴레옹이 근위대와 함께 중계점인 크라스니 마을로 들어가는 것을 방치한 것은 누구인가?
#
# 크라스니 마을로 들어가는 것을 방치한 나폴레옹이 근위대와 함께 중계점인 크라스니 마을로 들어가는 것을 방치한 것은 누구인가?
#
# 크라스니 마을로 들어가는 것을 방치한 나폴레옹이 근위대와 함께 중계점인 크라스니 마을로 들어가는 것을 방치한 것은 누구인가?
#
# 크라스니 마을로 들어가는 것을 방치한 나폴레옹이 근위대와 함께 중계점인 크라스니 마을로 들어가는 것을 방치한 것은 누구인가?
#
# 크라스니 마을로 들어가는 것을 방치한 나폴레옹이 근위대와 함께 중계점인 크라스니 마을로 들어가는 것을 방치한 것은 누구인가?
#
# 크라스니 마을로 들어가는 것을 방치한 나폴레옹이 근위대와 함께 중계점인 크라스니 마을로 들어가는 것을 방치한 것은 누구인가?
#
# 나폴레옹이 휘하 군대를 독려해 최대한 빨리 서쪽으로 가 바리사우에서 베레지나 강을 건너려고 한 것은?
#
# 나폴레옹이 휘하 군대를 독려해 최대한 빨리 서쪽으로 가 바리사우에서 베레지나 강을 건너려고 한 것은?
#
# 나폴레옹이 휘하 군대를 독려해 최대한 빨리 서쪽으로 가 바리사우에서 베레지나 강을 건너려고 한 것은?
#
# 나폴레옹이 휘하 군대를 독려해 최대한 빨리 서쪽으로 가 바리사우에서 베레지나 강을 건너려고 한 것은?
#
# 치챠고프가 군대를 이끌고 민스크를 떠나 공격한 곳은?
#
# 치챠고프가 군대를 이끌고 민스크를 떠나 공격한 곳은?
#
# 치챠고프가 군대를 이끌고 민스크를 떠나 공격한 곳은?
#
# 치챠고프가 군대를 이끌고 민스크를 떠나 공격한 곳은?
#
# 치챠고프가 군대를 이끌고 민스크를 떠나 공격한 곳은?
#
# 치챠고프가 군대를 이끌고 민스크를 떠나 공격한 곳은?
#
# 나폴레옹이 외젠 드 보아르네에게 총지휘권을 넘겨주고 떠난 곳은?
#
# 나폴레옹이 외젠 드 보아르네에게 총지휘권을 넘겨주고 떠난 곳은?
#
# 나폴레옹이 외젠 드 보아르네에게 총지휘권을 넘겨주고 떠난 곳은?
#
# 나폴레옹이 외젠 드 보아르네에게 총지휘권을 넘겨주고 떠난 곳은?
#
# 나폴레옹이 외젠 드 보아르네에게 총지휘권을 넘겨주고 떠난 곳은?
#
# 나폴레옹이 외젠 드 보아르네에게 총지휘권을 넘겨주고 떠난 곳은?
#
# 메테르니히는 라인 동맹의 해체와 18세기 말까지 오스트리아의 세력권이었던 이탈리아 북부도 요구했는가?
#
# 메테르니히는 라인 동맹의 해체와 18세기 말까지 오스트리아의 세력권이었던 이탈리아 북부도 요구했는가?
#
# 메테르니히는 라인 동맹의 해체와 18세기 말까지 오스트리아의 세력권이었던 이탈리아 북부도 요구했는가?
#
# 메테르니히는 라인 동맹의 해체와 18세기 말까지 오스트리아의 세력권이었던 이탈리아 북부도 요구했는가?
#
# 고다이고 천황은 퇴각한 이후 어디에서 남조를 수립하였는가?
#
# 고다이고 천황은 퇴각한 이후 어디에서 남조를 수립하였는가?
#
# 고다이고 천황은 퇴각한 이후 어디에서 남조를 수립하였는가?
#
# 고다이고 천황은 퇴각한 이후 어디에서 남조를 수립하였는가?
#
# 고다이고 천황은 퇴각한 이후 어디에서 남조를 수립하였는가?
#
# 고다이고 천황은 퇴각한 이후 어디에서 남조를 수립하였는가?
#
# 고다이고 천황은 퇴각한 이후 어디에서 남조를 수립하였는가?
#
# 고다이고 천황은 퇴각한 이후 어디에서 남조를 수립하였는가?
#
# 고다이고 천황은 퇴각한 이후 어디에서 남조를 수립하였는가?
#
# 고다이고 천황의 군대를 격파한 아시카가 다카우지가 세운 것은?
#
# 고다이고 천황의 군대를 격파한 아시카가 다카우지가 세운 것은?
#
# 고다이고 천황의 군대를 격파한 아시카가 다카우지가 세운 것은?
#
# 고다이고 천황의 군대를 격파한 아시카가 다카우지가 세운 것은?
#
# 고다이고 천황의 군대를 격파한 아시카가 다카우지가 세운 것은?
#
# 고다이고 천황의 군대를 격파한 아시카가 다카우지가 세운 것은?
#
# 고코곤 천황은 수세에 몰리자 아시카가 다카우지와 화친을 맺은 뒤 무엇을 건네주었는가?
#
# 고코곤 천황은 수세에 몰리자 아시카가 다카우지와 화친을 맺은 뒤 무엇을 건네주었는가?
#
# 고코곤 천황은 수세에 몰리자 아시카가 다카우지와 화친을 맺은 뒤 무엇을 건네주었는가?
#
# 고코곤 천황은 수세에 몰리자 아시카가 다카우지와 화친을 맺은 뒤 무엇을 건네주었는가?
#
# 고코곤 천황은 수세에 몰리자 아시카가 다카우지와 화친을 맺은 뒤 무엇을 건네주었는가?
#
# 일본제국 시절 동안 공식적으로 남조가 정통성 있는 정권으로 규정된 것은?
#
# 일본제국 시절 동안 공식적으로 남조가 정통성 있는 정권으로 규정된 것은?
#
# 일본제국 시절 동안 공식적으로 남조가 정통성 있는 정권으로 규정된 것은?
#
# 일본제국 시절 동안 공식적으로 남조가 정통성 있는 정권으로 규정된 것은?
#
# 일본제국 시절 동안 공식적으로 남조가 정통성 있는 정권으로 규정된 것은?
#
# 일본제국 시절 동안 공식적으로 남조가 정통성 있는 정권으로 규정된 것은?
#
# 일본제국 시절 동안 공식적으로 남조가 정통성 있는 정권으로 규정된 것은?
#
# 영생교에서 사람의 실체는 원래 신이었기 때문에 현재의 사람이 원래의 실체로 돌아가면 즉 신이 되면 죽지 않는 불사의 영생체가 된다고 해석하는 것은?
#
# 영생교에서 사람의 실체는 원래 신이었기 때문에 현재의 사람이 원래의 실체로 돌아가면 즉 신이 되면 죽지 않는 불사의 영생체가 된다고 해석하는 것은?
#
# 영생교에서 사람의 실체는 원래 신이었기 때문에 현재의 사람이 원래의 실체로 돌아가면 즉 신이 되면 죽지 않는 불사의 영생체가 된다고 해석하는 것은?
#
# 영생교에서 사람의 실체는 원래 신이었기 때문에 현재의 사람이 원래의 실체로 돌아가면 즉 신이 되면 죽지 않는 불사의 영생체가 된다고 해석하는 것은?
#
# 영생교에서 사람의 실체는 원래 신이었기 때문에 현재의 사람이 원래의 실체로 돌아가면 즉 신이 되면 죽지 않는 불사의 영생체가 된다고 해석하는 것은?
#
# 영생교에서 사람의 실체는 원래 신이었기 때문에 현재의 사람이 원래의 실체로 돌아가면 즉 신이 되면 죽지 않는 불사의 영생체가 된다고 해석하는 것은?
#
# 영생교에서 사람의 실체는 원래 신이었기 때문에 현재의 사람이 원래의 실체로 돌아가면 즉 신이 되면 죽지 않는 불사의 영생체가 된다고 해석하는 것은?
#
# 수원지방법원은 혐의를 완강하게 부인하던 교주 조희성과 누구에게 사형을 선고하였는가?
#
# 수원지방법원은 혐의를 완강하게 부인하던 교주 조희성과 누구에게 사형을 선고하였는가?
#
# 수원지방법원은 혐의를 완강하게 부인하던 교주 조희성과 누구에게 사형을 선고하였는가?
#
# 수원지방법원은 혐의를 완강하게 부인하던 교주 조희성과 누구에게 사형을 선고하였는가?
#
# 수원지방법원은 혐의를 완강하게 부인하던 교주 조희성과 누구에게 사형을 선고하였는가?
#
# 수원지방법원은 혐의를 완강하게 부인하던 교주 조희성과 누구에게 사형을 선고하였는가?
#
# 수원지방법원은 혐의를 완강하게 부인하던 교주 조희성과 누구에게 사형을 선고하였는가?
#
# 수원지방법원은 혐의를 완강하게 부인하던 교주 조희성과 누구에게 사형을 선고하였는가?
#
# 갤럭시 노트7은 모든 기기의 통신 모뎀 솔루션이 모바일 AP에 내장된 최초의 갤럭시 노트7 중 하나인가?
#
# 갤럭시 노트7은 모든 기기의 통신 모뎀 솔루션이 모바일 AP에 내장된 최초의 갤럭시 노트7 중 하나인가?
#
# 갤럭시 노트7은 모든 기기의 통신 모뎀 솔루션이 모바일 AP에 내장된 최초의 갤럭시 노트7 중 하나인가?
#
# 갤럭시 노트7은 모든 기기의 통신 모뎀 솔루션이 모바일 AP에 내장된 최초의 갤럭시 노트7 중 하나인가?
#
# 갤럭시 노트7은 모든 기기의 통신 모뎀 솔루션이 모바일 AP에 내장된 최초의 갤럭시 노트7 중 하나인가?
#
# 갤럭시 노트7은 모든 기기의 통신 모뎀 솔루션이 모바일 AP에 내장된 최초의 갤럭시 노트7 중 하나인가?
#
# 갤럭시 노트7은 모든 기기의 통신 모뎀 솔루션이 모바일 AP에 내장된 최초의 갤럭시 노트7 중 하나인가?
#
# 갤럭시 노트7사건으로 출력량을 완전히 줄여버려서 고속무선충전이라는 말이 의미가 없어진것 같다.
#
# 갤럭시 노트7사건으로 출력량을 완전히 줄여버려서 고속무선충전이라는 말이 의미가 없어진것 같다.
#
# 갤럭시 노트7사건으로 출력량을 완전히 줄여버려서 고속무선충전이라는 말이 의미가 없어진것 같다.
#
# 갤럭시 노트7사건으로 출력량을 완전히 줄여버려서 고속무선충전이라는 말이 의미가 없어진것 같다.
#
# 갤럭시 노트7사건으로 출력량을 완전히 줄여버려서 고속무선충전이라는 말이 의미가 없어진것 같다.
#
# 갤럭시 노트7사건으로 출력량을 완전히 줄여버려서 고속무선충전이라는 말이 의미가 없어진것 같다.
#
# 갤럭시 노트7사건으로 출력량을 완전히 줄여버려서 고속무선충전이라는 말이 의미가 없어진것 같다.
#
# 갤럭시 노트7사건으로 출력량을 완전히 줄여버려서 고속무선충전이라는 말이 의미가 없어진것 같다.
#
# 갤럭시 노트6 엣지와 갤럭시 S6 엣지+보다 약 25%가량 커진 갤럭시 노트7의 전면 카메라 화소는?
#
# 갤럭시 노트6 엣지와 갤럭시 S6 엣지+보다 약 25%가량 커진 갤럭시 노트7의 전면 카메라 화소는?
#
# 갤럭시 노트6 엣지와 갤럭시 S6 엣지+보다 약 25%가량 커진 갤럭시 노트7의 전면 카메라 화소는?
#
# 갤럭시 노트6 엣지와 갤럭시 S6 엣지+보다 약 25%가량 커진 갤럭시 노트7의 전면 카메라 화소는?
#
# 갤럭시 노트6 엣지와 갤럭시 S6 엣지+보다 약 25%가량 커진 갤럭시 노트7의 전면 카메라 화소는?
#
# 갤럭시 노트6 엣지와 갤럭시 S6 엣지+보다 약 25%가량 커진 갤럭시 노트7의 전면 카메라 화소는?
#
# 갤럭시 노트6 엣지와 갤럭시 S6 엣지+보다 약 25%가량 커진 갤럭시 노트7의 전면 카메라 화소는?
#
# 갤럭시 노트6 엣지와 갤럭시 S6 엣지+보다 약 25%가량 커진 갤럭시 노트7의 전면 카메라 화소는?
#
# 갤럭시 노트5에 탑재되었다가 갤럭시 S6/S6 엣지에서 도로 삭제되었던 방수 방진을 다시 지원한 것은?
#
# 갤럭시 노트5에 탑재되었다가 갤럭시 S6/S6 엣지에서 도로 삭제되었던 방수 방진을 다시 지원한 것은?
#
# 갤럭시 노트5에 탑재되었다가 갤럭시 S6/S6 엣지에서 도로 삭제되었던 방수 방진을 다시 지원한 것은?
#
# 갤럭시 노트5에 탑재되었다가 갤럭시 S6/S6 엣지에서 도로 삭제되었던 방수 방진을 다시 지원한 것은?
#
# 갤럭시 노트5에 탑재되었다가 갤럭시 S6/S6 엣지에서 도로 삭제되었던 방수 방진을 다시 지원한 것은?
#
# 갤럭시 노트5에 탑재되었다가 갤럭시 S6/S6 엣지에서 도로 삭제되었던 방수 방진을 다시 지원한 것은?
#
# 갤럭시 노트5에 탑재되었다가 갤럭시 S6/S6 엣지에서 도로 삭제되었던 방수 방진을 다시 지원한 것은?
#
# 갤럭시 노트7 엣지가 폭발한 것은 언제인가?
#
# 갤럭시 노트7 엣지가 폭발한 것은 언제인가?
#
# 갤럭시 노트7 엣지가 폭발한 것은 언제인가?
#
# 갤럭시 노트7 엣지가 폭발한 것은 언제인가?
#
# 갤럭시 노트7 엣지가 폭발한 것은 언제인가?
#
# 갤럭시 노트7 엣지가 폭발한 것은 언제인가?
#
# 갤럭시 노트7 엣지가 폭발한 것은 언제인가?
# 100%|██████████| 5774/5774 [00:02<00:00, 2319.14it/s]
# bleu1:  14.042919400242466
# bleu2:  9.935410876515414
# bleu3:  7.109965319189469
# bleu4:  4.878432230342916

# %% [markdown]
# bleu1:  14.471179482680984
# bleu2:  10.184096950121232
# bleu3:  7.191299425874609
# bleu4:  4.979940999307239

# %%
data = pd.read_csv(dev_path, sep='\t')

data['generated_question'] = generated_question

data.head()
# Out:
#                                              content
# 0  1989년 2월 15일 여의도 농민 폭력 시위를 주도한 혐의(폭력행위등처벌에관한법률...  \
# 1  1989년 2월 15일 여의도 농민 폭력 시위를 주도한 혐의(폭력행위등처벌에관한법률...
# 2  1989년 2월 15일 여의도 농민 폭력 시위를 주도한 혐의(폭력행위등처벌에관한법률...
# 3  1989년 2월 15일 여의도 농민 폭력 시위를 주도한 혐의(폭력행위등처벌에관한법률...
# 4  1989년 2월 15일 여의도 농민 폭력 시위를 주도한 혐의(폭력행위등처벌에관한법률...
#
#                                 question
# 0  임종석이 여의도 농민 폭력 시위를 주도한 혐의로 지명수배 된 날은?  \
# 1       1989년 6월 30일 평양축전에 대표로 파견 된 인물은?
# 2  임종석이 여의도 농민 폭력 시위를 주도한 혐의로 지명수배된 연도는?
# 3               임종석을 검거한 장소는 경희대 내 어디인가?
# 4              임종석이 조사를 받은 뒤 인계된 곳은 어딘가?
#
#                       generated_question
# 0    서울지방검찰청에서 임종석의 사전구속영장을 발부 받은 날짜는?\n
# 1  서울지방검찰청 공안부가 임종석의 사전구속영장을 발부받은 날짜는?\n
# 2     서울지방검찰청에서 임종석의 사전구속영장을 발부받은 날짜는?\n
# 3  서울지방검찰청 공안부가 임종석의 사전구속영장을 발부받은 날짜는?\n
# 4     서울지방검찰청이 임종석의 사전구속영장을 발부 받은 날짜는?\n

# %%
data.to_csv("/home/josh/Desktop/school/outputs/human_eval.csv")
